# %% [markdown]
# # Electoral College Data ETL

# %% [markdown]
# The purpose of this project is to analyze the how the electoral college votes were distributed after the 2010 census, look at how the redistribution of population (by estimate) has shifted over time until today, and what that means for the voter per electoral college vote in each state. I will also analyze how we expect the electoral college to be redistributed after the 2020 census, given census bureau predictions.
#
# An analysis will also be performed on the percentage likelihood of each state giving its electoral college votes to a particular party and their respective nominees, based purely on historical data. The aim is to demonstrate which states have the greatest power per vote, given both their current electoral votes allotted and the likelihood of that state assigning thier votes to either candidate.

# %% [markdown]
# ## Import

# %%
#import necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
import json
import copy

from bs4 import BeautifulSoup
import re

import sqlite3
# %matplotlib inline

# %% [markdown]
# ## Support Functions

# %%
#define how to retrieve api keys

def get_keys(path):
    """
    Pulls necessary api keys from designated path
    """
    with open(path) as f:
        return json.load(f)

# %%
def reciprocal_geometric_mean(next_house_seat):
    """
    Calculates the reciprocal geometric mean for the next house seat a state could potentially receive
    """
    return 1 / np.sqrt(next_house_seat*(next_house_seat-1))

# %%
def priority_value(state_pop, next_house_seat):
    """
    Calculates the priority value a state has for receiving another house seat.
    The highest priority value state gets the next house seat available.
    """
    return int(round(state_pop * reciprocal_geometric_mean(next_house_seat), 0))

# %%
def state_status_scrape(state_start):
    """
    From a beautiful soup webscrape, takes the tag just prior to the first state with NPVIC information
    and iterates through all siblings to make and return a dictionary of all states and their NPVIC status
    """
    state_npvic_status = {}
    for p in state_start.find_next_siblings():
        if p.contents == [] or p.contents == ['\xa0']:
            break

        soup_state_status = p.get_text().replace('\xa0', ' ')
        if '-' not in soup_state_status:
            state = soup_state_status
            status = ''
        else:
            dash_index = soup_state_status.index('-')
            state = soup_state_status[:dash_index-1]
            status = soup_state_status[dash_index+2:]

        state_npvic_status.update({state: status})
        
    return state_npvic_status

# %%
def state_status_to_numerical(state_npvic_status):
    """
    Takes all phrases from dictionary and assigns a value for how close the state is to joining the NPVIC
    Joined (passed legislature and signed by governor): 1.0
    Passed by one or two branches of state legislature: 0.5
    Approved by house committee:                        0.25
    States with no movement:                            0
    """
    for state in state_npvic_status.keys():
        if 'Enacted into law' in state_npvic_status[state]:
            state_npvic_status[state] = 1.0
        elif 'Passed' in state_npvic_status[state]:
            state_npvic_status[state] = 0.5
        elif 'approved' in state_npvic_status[state]:
            state_npvic_status[state] = 0.25
        else:
            state_npvic_status[state] = 0

    return state_npvic_status

# %%
def sql_table_creation(connection, cursor, table_name, *argv):
    var_string = argv[0]
    var_list = argv[0].split(' ')[0]
    for arg in argv[1:]:
        var_string += ', ' + arg
        var_list += ', ' + arg.split(' ')[0]
        
    try:
        c.execute('CREATE TABLE {} ({})'.format(table_name, var_string))
        conn.commit()
        print('{} Table created ({})'.format(table_name, var_list))
    except:
        c.execute('DROP TABLE {}'.format(table_name))
        print('{} table dropped'.format(table_name))
        c.execute('CREATE TABLE {} ({})'.format(table_name, var_string))
        conn.commit()
        print('{} table created ({})'.format(table_name, var_list))

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### API Request

# %%
#get key for census bureau api
key_path = "/Users/flatironschool/.secret/census_api.json"
keys = get_keys(key_path)

api_key = keys['api_key']

# %%
#make and print request for census count and estimates from 2010-2019 for all states
year = '2019'

url = 'https://api.census.gov/data/{}/pep/population'.format(year)

variables = ['DATE_CODE', 'DATE_DESC', 'POP', 'NAME']

granularity = 'state:*'

params = {'get': ','.join(variables), 'for': granularity, 'key': api_key}

r = requests.get(url, params=params)
print(r.url)
print(r)
print(r.text[:1000])
# Out:
# https://api.census.gov/data/2019/pep/population?get=DATE_CODE%2CDATE_DESC%2CPOP%2CNAME&for=state%3A%2A&key=b7961d22ec04ff1777be8a0450921d3f28af8315
# <Response [200]>
# [["DATE_CODE","DATE_DESC","POP","NAME","state"],
# ["1","4/1/2010 Census population","5303925","Minnesota","27"],
# ["2","4/1/2010 population estimates base","5303927","Minnesota","27"],
# ["3","7/1/2010 population estimate","5310828","Minnesota","27"],
# ["4","7/1/2011 population estimate","5346143","Minnesota","27"],
# ["5","7/1/2012 population estimate","5376643","Minnesota","27"],
# ["6","7/1/2013 population estimate","5413479","Minnesota","27"],
# ["7","7/1/2014 population estimate","5451079","Minnesota","27"],
# ["8","7/1/2015 population estimate","5482032","Minnesota","27"],
# ["9","7/1/2016 population estimate","5522744","Minnesota","27"],
# ["10","7/1/2017 population estimate","5566230","Minnesota","27"],
# ["11","7/1/2018 population estimate","5606249","Minnesota","27"],
# ["12","7/1/2019 population estimate","5639632","Minnesota","27"],
# ["1","4/1/2010 Census population","2967297","Mississippi","28"],
# ["2","4/1/2010 population estimates base","2968130","Mississippi","28"],
# ["3","7/1/2010 population

# %%
#take the api response, turn it into a json, then parse that json into a pandas dataframe
data = r.json()
pop_df = pd.DataFrame(data[1:], columns=data[0])

#cut down the date column to just the year
pop_df['YEAR'] = pop_df.DATE_DESC.apply(lambda x: x[4:8])

#eliminate the census population estimate for the same year it was recorded and the July date of that same year
pop_df.drop(pop_df[(pop_df.DATE_CODE == '2') | (pop_df.DATE_CODE == '3')].index, inplace=True)

#drop unnecessary columns and reset the index
pop_df.drop(['state','DATE_CODE', 'DATE_DESC'], axis=1, inplace=True)
pop_df.reset_index(drop=True, inplace=True)

#set the population to an integer val, reorder and rename the columns
pop_df['POP'] = pop_df.POP.astype('int64')
pop_df = pop_df[['YEAR', 'NAME', 'POP']]
pop_df.columns = ['Year', 'State', 'Population']

display(pop_df.head(15))
display(pop_df.info())
# Out:
#     Year        State  Population
# 0   2010    Minnesota     5303925
# 1   2011    Minnesota     5346143
# 2   2012    Minnesota     5376643
# 3   2013    Minnesota     5413479
# 4   2014    Minnesota     5451079
# 5   2015    Minnesota     5482032
# 6   2016    Minnesota     5522744
# 7   2017    Minnesota     5566230
# 8   2018    Minnesota     5606249
# 9   2019    Minnesota     5639632
# 10  2010  Mississippi     2967297
# 11  2011  Mississippi     2978731
# 12  2012  Mississippi     2983816
# 13  2013  Mississippi     2988711
# 14  2014  Mississippi     2990468
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 3 columns):
# Year          520 non-null object
# State         520 non-null object
# Population    520 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 12.3+ KB
# None

# %% [markdown]
# ### Overseas Population Import

# %%
overseas_df = pd.read_excel('Overseas Population 2010.xls', skiprows=7)
overseas_df.dropna(inplace=True)
overseas_df.columns = ['State', 'Overseas_pop']
overseas_df['Year'] = '2010'
overseas_df['Overseas_pop'] = overseas_df['Overseas_pop'].astype('int64')
overseas_df.reset_index(drop=True, inplace=True)

display(overseas_df.head())
display(overseas_df.info())
# Out:
#         State  Overseas_pop  Year
# 0     Alabama         23246  2010
# 1      Alaska         11292  2010
# 2     Arizona         20683  2010
# 3    Arkansas         10311  2010
# 4  California         88033  2010
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State           52 non-null object
# Overseas_pop    52 non-null int64
# Year            52 non-null object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB
# None

# %%
#merge the overseas data with the main population estimates table and extrapolate overseas estimates based on 
#percentage change in the population year over year

#merge the population estimates with overseas data on State and Year
merged_df = pop_df.merge(overseas_df, how='left', on=['State','Year'])

#create our Percent change in population column
merged_df['Percent_change'] = (merged_df.Population - merged_df.Population.shift(1)) / merged_df.Population.shift(1)

#iterate through the missing data in overseas population, calculating the next missing value from the previous known
#(from the 2010 census) or from the last calculated value based on percentage change in that state
for i in range(len(merged_df)):
    if pd.isna(merged_df.iloc[i]['Overseas_pop']):
        merged_df.at[i,'Overseas_pop'] = round(merged_df.iloc[i]['Percent_change'] * \
                                               merged_df.iloc[i-1]['Overseas_pop'] + \
                                               merged_df.iloc[i-1]['Overseas_pop'], 0)
        
merged_df.drop('Percent_change', axis=1, inplace=True)        
merged_df['Overseas_pop'] = merged_df.Overseas_pop.astype('int64')
merged_df['Year'] = merged_df.Year.astype('int64')

display(merged_df.head(25))
display(merged_df.info())
# Out:
#     Year        State  Population  Overseas_pop
# 0   2010    Minnesota     5303925         10954
# 1   2011    Minnesota     5346143         11041
# 2   2012    Minnesota     5376643         11104
# 3   2013    Minnesota     5413479         11180
# 4   2014    Minnesota     5451079         11258
# 5   2015    Minnesota     5482032         11322
# 6   2016    Minnesota     5522744         11406
# 7   2017    Minnesota     5566230         11496
# 8   2018    Minnesota     5606249         11579
# 9   2019    Minnesota     5639632         11648
# 10  2010  Mississippi     2967297         10943
# 11  2011  Mississippi     2978731         10985
# 12  2012  Mississippi     2983816         11004
# 13  2013  Mississippi     2988711         11022
# 14  2014  Mississippi     2990468         11028
# 15  2015  Mississippi     2988471         11021
# 16  2016  Mississippi     2987938         11019
# 17  2017  Mississippi     2988510         11021
# 18  2018  Mississippi     2981020         10993
# 19  2019  Mississippi     2976149         10975
# 20  2010     Missouri     5988927         22551
# 21  2011     Missouri     6010275         22631
# 22  2012     Missouri     6024367         22684
# 23  2013     Missouri     6040715         22746
# 24  2014     Missouri     6056202         22804
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 520 entries, 0 to 519
# Data columns (total 4 columns):
# Year            520 non-null int64
# State           520 non-null object
# Population      520 non-null int64
# Overseas_pop    520 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 40.3+ KB
# None

# %% [markdown]
# ### Scraping National Popular Vote Interstate Compact State Status

# %%
url = "https://www.nationalpopularvote.com/state-status"
req = requests.get(url)
soup = BeautifulSoup(req.content, 'html.parser')

# %%
#skips over the initial list (and links) of states at the top of the page
init_state_skip = soup.find("p", text=re.compile("On the map below"))

# %%
#brings us to the tag just before the states and their current NPVIC status
tag_before_states = init_state_skip.find_next_sibling().find_next_sibling()

print(tag_before_states)
print(tag_before_states.find_next_sibling())
# Out:
# <p> </p>
# <p><a class="menu__link" href="/state/ak">Alaska</a></p>

# %%
#scrape the site for NPVIC status of each state
npvic_word_status = state_status_scrape(tag_before_states)
#make the status numerical
npvic_num_status = state_status_to_numerical(npvic_word_status)

#turns dict into pandas dataframe
npvic_df = pd.DataFrame.from_dict(npvic_num_status, orient='index')
npvic_df.reset_index(inplace=True)
npvic_df.columns = ['State', 'NPVIC_num']

display(npvic_df.head())
display(npvic_df.info())
# Out:
#         State  NPVIC_num
# 0      Alaska        0.0
# 1     Alabama        0.0
# 2    Arkansas        0.5
# 3     Arizona        0.5
# 4  California        1.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
# State        51 non-null object
# NPVIC_num    51 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 944.0+ bytes
# None

# %% [markdown]
# ### Election History Data

# %% [markdown]
# Some things of note:
# - In exploration of the data, there was a "democrat/republican" that someone once ran as (James Gritz, only in CO, and in 1992) but that was excluded from the purely democrat/republican divide I want to study here
# - Any write in candidates were also not considered, as they are effectively outliers for this study
# - This dataset was only for US Presidential elections, so the office column is superfluous
# - In 2000, 2004, 2012, nominees Al Gore, John Kerry and Barack Obama had to run under the 'democratic-farmer-labor' party. For analysis, that party name has been changed to 'democrat' for ease of analysis

# %%
vote_history = pd.read_csv('1976-2016-president.csv')

#changing the democratic-farmer-labor party to just democrat for 2000, 2004, and 2012
vote_history.replace(to_replace='democratic-farmer-labor', value='democrat', inplace=True)

#drop anything that's a write in, or not in the main two parties, and reset the index
vote_history = vote_history[(vote_history['party'].isin(['democrat', 'republican'])) & 
                            (vote_history['writein'] == False)]
vote_history.reset_index(drop=True, inplace=True)

#get rid of unnecessary columns
drop_vote_history_cols = ['state_po', 'state_fips', 'state_cen', 'writein', 'state_ic', 'office', 'version', 'notes']
vote_history.drop(drop_vote_history_cols, axis=1, inplace=True)

display(vote_history.head(10))
display(vote_history.info())
# Out:
#    year       state      candidate       party  candidatevotes  totalvotes
# 0  1976     Alabama  Carter, Jimmy    democrat          659170     1182850
# 1  1976     Alabama   Ford, Gerald  republican          504070     1182850
# 2  1976      Alaska   Ford, Gerald  republican           71555      123574
# 3  1976      Alaska  Carter, Jimmy    democrat           44058      123574
# 4  1976     Arizona   Ford, Gerald  republican          418642      742719
# 5  1976     Arizona  Carter, Jimmy    democrat          295602      742719
# 6  1976    Arkansas  Carter, Jimmy    democrat          498604      767535
# 7  1976    Arkansas   Ford, Gerald  republican          267903      767535
# 8  1976  California   Ford, Gerald  republican         3882244     7803770
# 9  1976  California  Carter, Jimmy    democrat         3742284     7803770
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122 entries, 0 to 1121
# Data columns (total 6 columns):
# year              1122 non-null int64
# state             1122 non-null object
# candidate         1122 non-null object
# party             1122 non-null object
# candidatevotes    1122 non-null int64
# totalvotes        1122 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 52.7+ KB
# None

# %% [markdown]
# ### Merging all data into SQL Database

# %%
#put all data into SQL database for retrieval in analysis
conn = sqlite3.connect('census_pop_data.db')
c = conn.cursor()

# %% [markdown]
# #### Population Data

# %%
sql_table_creation(conn, c, 'Population', 'Year integer', 'State text', 'Pop integer', 'Overseas_pop integer')
# Out:
# Population Table created (Year, State, Pop, Overseas_pop)

# %%
merged_df.to_sql(name='Population', con=conn, if_exists='replace')

# %% [markdown]
# #### NPVIC Status

# %%
sql_table_creation(conn, c, 'NPVIC_status', 'State text', 'Status real')
# Out:
# NPVIC_status Table created (State, Status)

# %%
npvic_df.to_sql(name='NPVIC_status', con=conn, if_exists='replace')

# %% [markdown]
# #### Election Results

# %%
sql_table_creation(conn, c, 'Election_results', 'Year integer', 'State text', 'Candidate text', 
                    'Party text', 'Candidatevotes integer', 'Totalvotes integer')
# Out:
# Election_results table dropped
# Election_results table created (Year, State, Candidate, Party, Candidatevotes, Totalvotes)

# %%
vote_history.to_sql(name='Election_results', con=conn, if_exists='replace')

# %% [markdown]
# ### Check the input

# %%
c.execute('SELECT * FROM population')
for row in c.fetchall():
    print(row)
# Out:
# (0, 2010, 'Minnesota', 5303925, 10954)
# (1, 2011, 'Minnesota', 5346143, 11041)
# (2, 2012, 'Minnesota', 5376643, 11104)
# (3, 2013, 'Minnesota', 5413479, 11180)
# (4, 2014, 'Minnesota', 5451079, 11258)
# (5, 2015, 'Minnesota', 5482032, 11322)
# (6, 2016, 'Minnesota', 5522744, 11406)
# (7, 2017, 'Minnesota', 5566230, 11496)
# (8, 2018, 'Minnesota', 5606249, 11579)
# (9, 2019, 'Minnesota', 5639632, 11648)
# (10, 2010, 'Mississippi', 2967297, 10943)
# (11, 2011, 'Mississippi', 2978731, 10985)
# (12, 2012, 'Mississippi', 2983816, 11004)
# (13, 2013, 'Mississippi', 2988711, 11022)
# (14, 2014, 'Mississippi', 2990468, 11028)
# (15, 2015, 'Mississippi', 2988471, 11021)
# (16, 2016, 'Mississippi', 2987938, 11019)
# (17, 2017, 'Mississippi', 2988510, 11021)
# (18, 2018, 'Mississippi', 2981020, 10993)
# (19, 2019, 'Mississippi', 2976149, 10975)
# (20, 2010, 'Missouri', 5988927, 22551)
# (21, 2011, 'Missouri', 6010275, 22631)
# (22, 2012, 'Missouri', 6024367, 22684)
# (23, 2013, 'Missouri', 6040715, 22746)
# (24, 2014, 'Missouri', 6056202, 22804)
# (25, 2015, 'Missouri', 6071732, 22862)
# (26, 2016, 'Missouri', 6087135, 22920)
# (27, 2017, 'Missouri', 6106670, 22994)
# (28, 2018, 'Missouri', 6121623, 23050)
# (29, 2019, 'Missouri', 6137428, 23110)
# (30, 2010, 'Montana', 989415, 5001)
# (31, 2011, 'Montana', 997316, 5041)
# (32, 2012, 'Montana', 1003783, 5074)
# (33, 2013, 'Montana', 1013569, 5123)
# (34, 2014, 'Montana', 1021869, 5165)
# (35, 2015, 'Montana', 1030475, 5208)
# (36, 2016, 'Montana', 1040859, 5260)
# (37, 2017, 'Montana', 1052482, 5319)
# (38, 2018, 'Montana', 1060665, 5360)
# (39, 2019, 'Montana', 1068778, 5401)
# (40, 2010, 'Nebraska', 1826341, 5484)
# (41, 2011, 'Nebraska', 1840672, 5527)
# (42, 2012, 'Nebraska', 1853303, 5565)
# (43, 2013, 'Nebraska', 1865279, 5601)
# (44, 2014, 'Nebraska', 1879321, 5643)
# (45, 2015, 'Nebraska', 1891277, 5679)
# (46, 2016, 'Nebraska', 1905616, 5722)
# (47, 2017, 'Nebraska', 1915947, 5753)
# (48, 2018, 'Nebraska', 1925614, 5782)
# (49, 2019, 'Nebraska', 1934408, 5808)
# (50, 2010, 'Nevada', 2700551, 8881)
# (51, 2011, 'Nevada', 2712730, 8921)
# (52, 2012, 'Nevada', 2743996, 9024)
# (53, 2013, 'Nevada', 2775970, 9129)
# (54, 2014, 'Nevada', 2817628, 9266)
# (55, 2015, 'Nevada', 2866939, 9428)
# (56, 2016, 'Nevada', 2917563, 9594)
# (57, 2017, 'Nevada', 2969905, 9766)
# (58, 2018, 'Nevada', 3027341, 9955)
# (59, 2019, 'Nevada', 3080156, 10129)
# (60, 2010, 'New Hampshire', 1316470, 4975)
# (61, 2011, 'New Hampshire', 1320202, 4989)
# (62, 2012, 'New Hampshire', 1324232, 5004)
# (63, 2013, 'New Hampshire', 1326622, 5013)
# (64, 2014, 'New Hampshire', 1333341, 5038)
# (65, 2015, 'New Hampshire', 1336350, 5049)
# (66, 2016, 'New Hampshire', 1342307, 5072)
# (67, 2017, 'New Hampshire', 1348787, 5096)
# (68, 2018, 'New Hampshire', 1353465, 5114)
# (69, 2019, 'New Hampshire', 1359711, 5138)
# (70, 2010, 'New Jersey', 8791894, 15607)
# (71, 2011, 'New Jersey', 8828117, 15671)
# (72, 2012, 'New Jersey', 8844942, 15701)
# (73, 2013, 'New Jersey', 8856972, 15722)
# (74, 2014, 'New Jersey', 8864525, 15735)
# (75, 2015, 'New Jersey', 8867949, 15741)
# (76, 2016, 'New Jersey', 8870827, 15746)
# (77, 2017, 'New Jersey', 8885525, 15772)
# (78, 2018, 'New Jersey', 8886025, 15773)
# (79, 2019, 'New Jersey', 8882190, 15766)
# (80, 2010, 'New Mexico', 2059179, 8094)
# (81, 2011, 'New Mexico', 2080450, 8178)
# (82, 2012, 'New Mexico', 2087309, 8205)
# (83, 2013, 'New Mexico', 2092273, 8225)
# (84, 2014, 'New Mexico', 2089568, 8214)
# (85, 2015, 'New Mexico', 2089291, 8213)
# (86, 2016, 'New Mexico', 2091630, 8222)
# (87, 2017, 'New Mexico', 2091784, 8223)
# (88, 2018, 'New Mexico', 2092741, 8227)
# (89, 2019, 'New Mexico', 2096829, 8243)
# (90, 2010, 'New York', 19378102, 42953)
# (91, 2011, 'New York', 19499241, 43222)
# (92, 2012, 'New York', 19572932, 43385)
# (93, 2013, 'New York', 19624447, 43499)
# (94, 2014, 'New York', 19651049, 43558)
# (95, 2015, 'New York', 19654666, 43566)
# (96, 2016, 'New York', 19633428, 43519)
# (97, 2017, 'New York', 19589572, 43422)
# (98, 2018, 'New York', 19530351, 43291)
# (99, 2019, 'New York', 19453561, 43121)
# (100, 2010, 'North Carolina', 9535483, 30298)
# (101, 2011, 'North Carolina', 9657592, 30686)
# (102, 2012, 'North Carolina', 9749476, 30978)
# (103, 2013, 'North Carolina', 9843336, 31276)
# (104, 2014, 'North Carolina', 9932887, 31561)
# (105, 2015, 'North Carolina', 10031646, 31875)
# (106, 2016, 'North Carolina', 10154788, 32266)
# (107, 2017, 'North Carolina', 10268233, 32626)
# (108, 2018, 'North Carolina', 10381615, 32986)
# (109, 2019, 'North Carolina', 10488084, 33324)
# (110, 2010, 'North Dakota', 672591, 3314)
# (111, 2011, 'North Dakota', 685225, 3376)
# (112, 2012, 'North Dakota', 701176, 3455)
# (113, 2013, 'North Dakota', 722036, 3558)
# (114, 2014, 'North Dakota', 737401, 3634)
# (115, 2015, 'North Dakota', 754066, 3716)
# (116, 2016, 'North Dakota', 754434, 3718)
# (117, 2017, 'North Dakota', 754942, 3721)
# (118, 2018, 'North Dakota', 758080, 3736)
# (119, 2019, 'North Dakota', 762062, 3756)
# (120, 2010, 'Ohio', 11536504, 31991)
# (121, 2011, 'Ohio', 11544663, 32014)
# (122, 2012, 'Ohio', 11548923, 32026)
# (123, 2013, 'Ohio', 11576684, 32103)
# (124, 2014, 'Ohio', 11602700, 32175)
# (125, 2015, 'Ohio', 11617527, 32216)
# (126, 2016, 'Ohio', 11634370, 32263)
# (127, 2017, 'Ohio', 11659650, 32333)
# (128, 2018, 'Ohio', 11676341, 32379)
# (129, 2019, 'Ohio', 11689100, 32414)
# (130, 2010, 'Oklahoma', 3751351, 13531)
# (131, 2011, 'Oklahoma', 3788379, 13665)
# (132, 2012, 'Oklahoma', 3818814, 13775)
# (133, 2013, 'Oklahoma', 3853214, 13899)
# (134, 2014, 'Oklahoma', 3878187, 13989)
# (135, 2015, 'Oklahoma', 3909500, 14102)
# (136, 2016, 'Oklahoma', 3926331, 14163)
# (137, 2017, 'Oklahoma', 3931316, 14181)
# (138, 2018, 'Oklahoma', 3940235, 14213)
# (139, 2019, 'Oklahoma', 3956971, 14273)
# (140, 2010, 'Oregon', 3831074, 17532)
# (141, 2011, 'Oregon', 3872036, 17719)
# (142, 2012, 'Oregon', 3899001, 17842)
# (143, 2013, 'Oregon', 3922468, 17949)
# (144, 2014, 'Oregon', 3963244, 18136)
# (145, 2015, 'Oregon', 4015792, 18376)
# (146, 2016, 'Oregon', 4089976, 18715)
# (147, 2017, 'Oregon', 4143625, 18960)
# (148, 2018, 'Oregon', 4181886, 19135)
# (149, 2019, 'Oregon', 4217737, 19299)
# (150, 2010, 'Pennsylvania', 12702379, 32526)
# (151, 2011, 'Pennsylvania', 12745815, 32637)
# (152, 2012, 'Pennsylvania', 12767118, 32692)
# (153, 2013, 'Pennsylvania', 12776309, 32716)
# (154, 2014, 'Pennsylvania', 12788313, 32747)
# (155, 2015, 'Pennsylvania', 12784826, 32738)
# (156, 2016, 'Pennsylvania', 12782275, 32731)
# (157, 2017, 'Pennsylvania', 12787641, 32745)
# (158, 2018, 'Pennsylvania', 12800922, 32779)
# (159, 2019, 'Pennsylvania', 12801989, 32782)
# (160, 2010, 'Rhode Island', 1052567, 2680)
# (161, 2011, 'Rhode Island', 1053649, 2683)
# (162, 2012, 'Rhode Island', 1054621, 2685)
# (163, 2013, 'Rhode Island', 1055081, 2686)
# (164, 2014, 'Rhode Island', 1055936, 2688)
# (165, 2015, 'Rhode Island', 1056065, 2688)
# (166, 2016, 'Rhode Island', 1056770, 2690)
# (167, 2017, 'Rhode Island', 1055673, 2687)
# (168, 2018, 'Rhode Island', 1058287, 2694)
# (169, 2019, 'Rhode Island', 1059361, 2697)
# (170, 2010, 'South Carolina', 4625364, 20611)
# (171, 2011, 'South Carolina', 4671994, 20819)
# (172, 2012, 'South Carolina', 4717354, 21021)
# (173, 2013, 'South Carolina', 4764080, 21229)
# (174, 2014, 'South Carolina', 4823617, 21494)
# (175, 2015, 'South Carolina', 4891938, 21798)
# (176, 2016, 'South Carolina', 4957968, 22092)
# (177, 2017, 'South Carolina', 5021268, 22374)
# (178, 2018, 'South Carolina', 5084156, 22654)
# (179, 2019, 'South Carolina', 5148714, 22942)
# (180, 2010, 'South Dakota', 814180, 5581)
# (181, 2011, 'South Dakota', 823579, 5645)
# (182, 2012, 'South Dakota', 833566, 5713)
# (183, 2013, 'South Dakota', 842316, 5773)
# (184, 2014, 'South Dakota', 849129, 5820)
# (185, 2015, 'South Dakota', 853988, 5853)
# (186, 2016, 'South Dakota', 862996, 5915)
# (187, 2017, 'South Dakota', 872868, 5983)
# (188, 2018, 'South Dakota', 878698, 6023)
# (189, 2019, 'South Dakota', 884659, 6064)
# (190, 2010, 'Tennessee', 6346105, 29326)
# (191, 2011, 'Tennessee', 6399291, 29572)
# (192, 2012, 'Tennessee', 6453898, 29824)
# (193, 2013, 'Tennessee', 6494340, 30011)
# (194, 2014, 'Tennessee', 6541223, 30228)
# (195, 2015, 'Tennessee', 6591170, 30459)
# (196, 2016, 'Tennessee', 6646010, 30712)
# (197, 2017, 'Tennessee', 6708799, 31002)
# (198, 2018, 'Tennessee', 6771631, 31292)
# (199, 2019, 'Tennessee', 6829174, 31558)
# (200, 2010, 'Texas', 25145561, 122857)
# (201, 2011, 'Texas', 25645629, 125300)
# (202, 2012, 'Texas', 26084481, 127444)
# (203, 2013, 'Texas', 26480266, 129378)
# (204, 2014, 'Texas', 26964333, 131743)
# (205, 2015, 'Texas', 27470056, 134214)
# (206, 2016, 'Texas', 27914410, 136385)
# (207, 2017, 'Texas', 28295273, 138246)
# (208, 2018, 'Texas', 28628666, 139875)
# (209, 2019, 'Texas', 28995881, 141669)
# (210, 2010, 'Utah', 2763885, 6880)
# (211, 2011, 'Utah', 2814384, 7006)
# (212, 2012, 'Utah', 2853375, 7103)
# (213, 2013, 'Utah', 2897640, 7213)
# (214, 2014, 'Utah', 2936879, 7311)
# (215, 2015, 'Utah', 2981835, 7423)
# (216, 2016, 'Utah', 3041868, 7572)
# (217, 2017, 'Utah', 3101042, 7719)
# (218, 2018, 'Utah', 3153550, 7850)
# (219, 2019, 'Utah', 3205958, 7980)
# (220, 2010, 'Vermont', 625741, 4596)
# (221, 2011, 'Vermont', 627049, 4606)
# (222, 2012, 'Vermont', 626090, 4599)
# (223, 2013, 'Vermont', 626210, 4600)
# (224, 2014, 'Vermont', 625214, 4593)
# (225, 2015, 'Vermont', 625216, 4593)
# (226, 2016, 'Vermont', 623657, 4582)
# (227, 2017, 'Vermont', 624344, 4587)
# (228, 2018, 'Vermont', 624358, 4587)
# (229, 2019, 'Vermont', 623989, 4584)
# (230, 2010, 'Virginia', 8001024, 36712)
# (231, 2011, 'Virginia', 8101155, 37171)
# (232, 2012, 'Virginia', 8185080, 37556)
# (233, 2013, 'Virginia', 8252427, 37865)
# (234, 2014, 'Virginia', 8310993, 38134)
# (235, 2015, 'Virginia', 8361808, 38367)
# (236, 2016, 'Virginia', 8410106, 38589)
# (237, 2017, 'Virginia', 8463587, 38834)
# (238, 2018, 'Virginia', 8501286, 39007)
# (239, 2019, 'Virginia', 8535519, 39164)
# (240, 2010, 'West Virginia', 1852994, 6821)
# (241, 2011, 'West Virginia', 1856301, 6833)
# (242, 2012, 'West Virginia', 1856872, 6835)
# (243, 2013, 'West Virginia', 1853914, 6824)
# (244, 2014, 'West Virginia', 1849489, 6808)
# (245, 2015, 'West Virginia', 1842050, 6781)
# (246, 2016, 'West Virginia', 1831023, 6740)
# (247, 2017, 'West Virginia', 1817004, 6688)
# (248, 2018, 'West Virginia', 1804291, 6641)
# (249, 2019, 'West Virginia', 1792147, 6596)
# (250, 2010, 'Washington', 6724540, 28829)
# (251, 2011, 'Washington', 6826627, 29267)
# (252, 2012, 'Washington', 6897058, 29569)
# (253, 2013, 'Washington', 6963985, 29856)
# (254, 2014, 'Washington', 7054655, 30245)
# (255, 2015, 'Washington', 7163657, 30712)
# (256, 2016, 'Washington', 7294771, 31274)
# (257, 2017, 'Washington', 7423362, 31825)
# (258, 2018, 'Washington', 7523869, 32256)
# (259, 2019, 'Washington', 7614893, 32646)
# (260, 2010, 'Wisconsin', 5686986, 11244)
# (261, 2011, 'Wisconsin', 5705288, 11280)
# (262, 2012, 'Wisconsin', 5719960, 11309)
# (263, 2013, 'Wisconsin', 5736754, 11342)
# (264, 2014, 'Wisconsin', 5751525, 11371)
# (265, 2015, 'Wisconsin', 5760940, 11390)
# (266, 2016, 'Wisconsin', 5772628, 11413)
# (267, 2017, 'Wisconsin', 5790186, 11448)
# (268, 2018, 'Wisconsin', 5807406, 11482)
# (269, 2019, 'Wisconsin', 5822434, 11512)
# (270, 2010, 'Wyoming', 563626, 4674)
# (271, 2011, 'Wyoming', 567299, 4704)
# (272, 2012, 'Wyoming', 576305, 4779)
# (273, 2013, 'Wyoming', 582122, 4827)
# (274, 2014, 'Wyoming', 582531, 4830)
# (275, 2015, 'Wyoming', 585613, 4856)
# (276, 2016, 'Wyoming', 584215, 4844)
# (277, 2017, 'Wyoming', 578931, 4800)
# (278, 2018, 'Wyoming', 577601, 4789)
# (279, 2019, 'Wyoming', 578759, 4799)
# (280, 2010, 'Puerto Rico', 3725789, 30894)
# (281, 2011, 'Puerto Rico', 3678732, 30504)
# (282, 2012, 'Puerto Rico', 3634488, 30137)
# (283, 2013, 'Puerto Rico', 3593077, 29794)
# (284, 2014, 'Puerto Rico', 3534874, 29311)
# (285, 2015, 'Puerto Rico', 3473232, 28800)
# (286, 2016, 'Puerto Rico', 3406672, 28248)
# (287, 2017, 'Puerto Rico', 3325286, 27573)
# (288, 2018, 'Puerto Rico', 3193354, 26479)
# (289, 2019, 'Puerto Rico', 3193694, 26482)
# (290, 2010, 'Alabama', 4779736, 23246)
# (291, 2011, 'Alabama', 4799069, 23340)
# (292, 2012, 'Alabama', 4815588, 23420)
# (293, 2013, 'Alabama', 4830081, 23490)
# (294, 2014, 'Alabama', 4841799, 23547)
# (295, 2015, 'Alabama', 4852347, 23598)
# (296, 2016, 'Alabama', 4863525, 23652)
# (297, 2017, 'Alabama', 4874486, 23705)
# (298, 2018, 'Alabama', 4887681, 23769)
# (299, 2019, 'Alabama', 4903185, 23844)
# (300, 2010, 'Alaska', 710231, 11292)
# (301, 2011, 'Alaska', 722128, 11481)
# (302, 2012, 'Alaska', 730443, 11613)
# (303, 2013, 'Alaska', 737068, 11718)
# (304, 2014, 'Alaska', 736283, 11706)
# (305, 2015, 'Alaska', 737498, 11725)
# (306, 2016, 'Alaska', 741456, 11788)
# (307, 2017, 'Alaska', 739700, 11760)
# (308, 2018, 'Alaska', 735139, 11687)
# (309, 2019, 'Alaska', 731545, 11630)
# (310, 2010, 'Arizona', 6392017, 20683)
# (311, 2011, 'Arizona', 6472643, 20944)
# (312, 2012, 'Arizona', 6554978, 21210)
# (313, 2013, 'Arizona', 6632764, 21462)
# (314, 2014, 'Arizona', 6730413, 21778)
# (315, 2015, 'Arizona', 6829676, 22099)
# (316, 2016, 'Arizona', 6941072, 22459)
# (317, 2017, 'Arizona', 7044008, 22792)
# (318, 2018, 'Arizona', 7158024, 23161)
# (319, 2019, 'Arizona', 7278717, 23552)
# (320, 2010, 'Arkansas', 2915918, 10311)
# (321, 2011, 'Arkansas', 2940667, 10399)
# (322, 2012, 'Arkansas', 2952164, 10440)
# (323, 2013, 'Arkansas', 2959400, 10466)
# (324, 2014, 'Arkansas', 2967392, 10494)
# (325, 2015, 'Arkansas', 2978048, 10532)
# (326, 2016, 'Arkansas', 2989918, 10574)
# (327, 2017, 'Arkansas', 3001345, 10614)
# (328, 2018, 'Arkansas', 3009733, 10644)
# (329, 2019, 'Arkansas', 3017804, 10673)
# (330, 2010, 'California', 37253956, 88033)
# (331, 2011, 'California', 37638369, 88941)
# (332, 2012, 'California', 37948800, 89675)
# (333, 2013, 'California', 38260787, 90412)
# (334, 2014, 'California', 38596972, 91206)
# (335, 2015, 'California', 38918045, 91965)
# (336, 2016, 'California', 39167117, 92554)
# (337, 2017, 'California', 39358497, 93006)
# (338, 2018, 'California', 39461588, 93250)
# (339, 2019, 'California', 39512223, 93370)
# (340, 2010, 'Colorado', 5029196, 15734)
# (341, 2011, 'Colorado', 5121108, 16022)
# (342, 2012, 'Colorado', 5192647, 16246)
# (343, 2013, 'Colorado', 5269035, 16485)
# (344, 2014, 'Colorado', 5350101, 16739)
# (345, 2015, 'Colorado', 5450623, 17054)
# (346, 2016, 'Colorado', 5539215, 17331)
# (347, 2017, 'Colorado', 5611885, 17558)
# (348, 2018, 'Colorado', 5691287, 17806)
# (349, 2019, 'Colorado', 5758736, 18017)
# (350, 2010, 'Connecticut', 3574097, 7531)
# (351, 2011, 'Connecticut', 3588283, 7561)
# (352, 2012, 'Connecticut', 3594547, 7574)
# (353, 2013, 'Connecticut', 3594841, 7575)
# (354, 2014, 'Connecticut', 3594524, 7574)
# (355, 2015, 'Connecticut', 3587122, 7558)
# (356, 2016, 'Connecticut', 3578141, 7539)
# (357, 2017, 'Connecticut', 3573297, 7529)
# (358, 2018, 'Connecticut', 3571520, 7525)
# (359, 2019, 'Connecticut', 3565287, 7512)
# (360, 2010, 'Delaware', 897934, 2943)
# (361, 2011, 'Delaware', 907381, 2974)
# (362, 2012, 'Delaware', 915179, 3000)
# (363, 2013, 'Delaware', 923576, 3028)
# (364, 2014, 'Delaware', 932487, 3057)
# (365, 2015, 'Delaware', 941252, 3086)
# (366, 2016, 'Delaware', 948921, 3111)
# (367, 2017, 'Delaware', 956823, 3137)
# (368, 2018, 'Delaware', 965479, 3165)
# (369, 2019, 'Delaware', 973764, 3192)
# (370, 2010, 'District of Columbia', 601723, 2875)
# (371, 2011, 'District of Columbia', 619800, 2961)
# (372, 2012, 'District of Columbia', 634924, 3033)
# (373, 2013, 'District of Columbia', 650581, 3108)
# (374, 2014, 'District of Columbia', 662328, 3164)
# (375, 2015, 'District of Columbia', 675400, 3226)
# (376, 2016, 'District of Columbia', 685815, 3276)
# (377, 2017, 'District of Columbia', 694906, 3319)
# (378, 2018, 'District of Columbia', 701547, 3351)
# (379, 2019, 'District of Columbia', 705749, 3371)
# (380, 2010, 'Florida', 18801310, 99463)
# (381, 2011, 'Florida', 19053237, 100796)
# (382, 2012, 'Florida', 19297822, 102090)
# (383, 2013, 'Florida', 19545621, 103401)
# (384, 2014, 'Florida', 19845911, 104990)
# (385, 2015, 'Florida', 20209042, 106911)
# (386, 2016, 'Florida', 20613477, 109051)
# (387, 2017, 'Florida', 20963613, 110903)
# (388, 2018, 'Florida', 21244317, 112388)
# (389, 2019, 'Florida', 21477737, 113623)
# (390, 2010, 'Georgia', 9687653, 39913)
# (391, 2011, 'Georgia', 9802431, 40386)
# (392, 2012, 'Georgia', 9901430, 40794)
# (393, 2013, 'Georgia', 9972479, 41087)
# (394, 2014, 'Georgia', 10067278, 41478)
# (395, 2015, 'Georgia', 10178447, 41936)
# (396, 2016, 'Georgia', 10301890, 42445)
# (397, 2017, 'Georgia', 10410330, 42892)
# (398, 2018, 'Georgia', 10511131, 43307)
# (399, 2019, 'Georgia', 10617423, 43745)
# (400, 2010, 'Idaho', 1567582, 5917)
# (401, 2011, 'Idaho', 1583910, 5979)
# (402, 2012, 'Idaho', 1595324, 6022)
# (403, 2013, 'Idaho', 1611206, 6082)
# (404, 2014, 'Idaho', 1631112, 6157)
# (405, 2015, 'Idaho', 1651059, 6232)
# (406, 2016, 'Idaho', 1682380, 6350)
# (407, 2017, 'Idaho', 1717715, 6483)
# (408, 2018, 'Idaho', 1750536, 6607)
# (409, 2019, 'Idaho', 1787065, 6745)
# (410, 2010, 'Hawaii', 1360301, 6561)
# (411, 2011, 'Hawaii', 1379329, 6653)
# (412, 2012, 'Hawaii', 1394804, 6728)
# (413, 2013, 'Hawaii', 1408243, 6793)
# (414, 2014, 'Hawaii', 1414538, 6823)
# (415, 2015, 'Hawaii', 1422052, 6859)
# (416, 2016, 'Hawaii', 1427559, 6886)
# (417, 2017, 'Hawaii', 1424393, 6871)
# (418, 2018, 'Hawaii', 1420593, 6853)
# (419, 2019, 'Hawaii', 1415872, 6830)
# (420, 2010, 'Illinois', 12830632, 33748)
# (421, 2011, 'Illinois', 12867454, 33845)
# (422, 2012, 'Illinois', 12882510, 33885)
# (423, 2013, 'Illinois', 12895129, 33918)
# (424, 2014, 'Illinois', 12884493, 33890)
# (425, 2015, 'Illinois', 12858913, 33823)
# (426, 2016, 'Illinois', 12820527, 33722)
# (427, 2017, 'Illinois', 12778828, 33612)
# (428, 2018, 'Illinois', 12723071, 33465)
# (429, 2019, 'Illinois', 12671821, 33330)
# (430, 2010, 'Indiana', 6483802, 17780)
# (431, 2011, 'Indiana', 6516528, 17870)
# (432, 2012, 'Indiana', 6537703, 17928)
# (433, 2013, 'Indiana', 6568713, 18013)
# (434, 2014, 'Indiana', 6593644, 18081)
# (435, 2015, 'Indiana', 6608422, 18122)
# (436, 2016, 'Indiana', 6634304, 18193)
# (437, 2017, 'Indiana', 6658078, 18258)
# (438, 2018, 'Indiana', 6695497, 18361)
# (439, 2019, 'Indiana', 6732219, 18462)
# (440, 2010, 'Iowa', 3046355, 7432)
# (441, 2011, 'Iowa', 3066336, 7481)
# (442, 2012, 'Iowa', 3076190, 7505)
# (443, 2013, 'Iowa', 3092997, 7546)
# (444, 2014, 'Iowa', 3109350, 7586)
# (445, 2015, 'Iowa', 3120960, 7614)
# (446, 2016, 'Iowa', 3131371, 7639)
# (447, 2017, 'Iowa', 3141550, 7664)
# (448, 2018, 'Iowa', 3148618, 7681)
# (449, 2019, 'Iowa', 3155070, 7697)
# (450, 2010, 'Kansas', 2853118, 10695)
# (451, 2011, 'Kansas', 2869225, 10755)
# (452, 2012, 'Kansas', 2885257, 10815)
# (453, 2013, 'Kansas', 2893212, 10845)
# (454, 2014, 'Kansas', 2900475, 10872)
# (455, 2015, 'Kansas', 2909011, 10904)
# (456, 2016, 'Kansas', 2910844, 10911)
# (457, 2017, 'Kansas', 2908718, 10903)
# (458, 2018, 'Kansas', 2911359, 10913)
# (459, 2019, 'Kansas', 2913314, 10920)
# (460, 2010, 'Kentucky', 4339367, 11239)
# (461, 2011, 'Kentucky', 4369821, 11318)
# (462, 2012, 'Kentucky', 4386346, 11361)
# (463, 2013, 'Kentucky', 4404659, 11408)
# (464, 2014, 'Kentucky', 4414349, 11433)
# (465, 2015, 'Kentucky', 4425976, 11463)
# (466, 2016, 'Kentucky', 4438182, 11495)
# (467, 2017, 'Kentucky', 4452268, 11531)
# (468, 2018, 'Kentucky', 4461153, 11554)
# (469, 2019, 'Kentucky', 4467673, 11571)
# (470, 2010, 'Louisiana', 4533372, 20590)
# (471, 2011, 'Louisiana', 4575625, 20782)
# (472, 2012, 'Louisiana', 4600972, 20897)
# (473, 2013, 'Louisiana', 4624527, 21004)
# (474, 2014, 'Louisiana', 4644013, 21093)
# (475, 2015, 'Louisiana', 4664628, 21187)
# (476, 2016, 'Louisiana', 4678135, 21248)
# (477, 2017, 'Louisiana', 4670560, 21214)
# (478, 2018, 'Louisiana', 4659690, 21165)
# (479, 2019, 'Louisiana', 4648794, 21116)
# (480, 2010, 'Maine', 1328361, 4713)
# (481, 2011, 'Maine', 1328284, 4713)
# (482, 2012, 'Maine', 1327729, 4711)
# (483, 2013, 'Maine', 1328009, 4712)
# (484, 2014, 'Maine', 1330513, 4721)
# (485, 2015, 'Maine', 1328262, 4713)
# (486, 2016, 'Maine', 1331317, 4724)
# (487, 2017, 'Maine', 1334612, 4736)
# (488, 2018, 'Maine', 1339057, 4752)
# (489, 2019, 'Maine', 1344212, 4770)
# (490, 2010, 'Maryland', 5773552, 16377)
# (491, 2011, 'Maryland', 5839419, 16564)
# (492, 2012, 'Maryland', 5886992, 16699)
# (493, 2013, 'Maryland', 5923188, 16802)
# (494, 2014, 'Maryland', 5957283, 16899)
# (495, 2015, 'Maryland', 5985562, 16979)
# (496, 2016, 'Maryland', 6003323, 17029)
# (497, 2017, 'Maryland', 6023868, 17087)
# (498, 2018, 'Maryland', 6035802, 17121)
# (499, 2019, 'Maryland', 6045680, 17149)
# (500, 2010, 'Massachusetts', 6547629, 12015)
# (501, 2011, 'Massachusetts', 6613583, 12136)
# (502, 2012, 'Massachusetts', 6663005, 12227)
# (503, 2013, 'Massachusetts', 6713315, 12319)
# (504, 2014, 'Massachusetts', 6762596, 12409)
# (505, 2015, 'Massachusetts', 6794228, 12467)
# (506, 2016, 'Massachusetts', 6823608, 12521)
# (507, 2017, 'Massachusetts', 6859789, 12587)
# (508, 2018, 'Massachusetts', 6882635, 12629)
# (509, 2019, 'Massachusetts', 6892503, 12647)
# (510, 2010, 'Michigan', 9883640, 27986)
# (511, 2011, 'Michigan', 9882412, 27983)
# (512, 2012, 'Michigan', 9897145, 28025)
# (513, 2013, 'Michigan', 9913065, 28070)
# (514, 2014, 'Michigan', 9929848, 28118)
# (515, 2015, 'Michigan', 9931715, 28123)
# (516, 2016, 'Michigan', 9950571, 28176)
# (517, 2017, 'Michigan', 9973114, 28240)
# (518, 2018, 'Michigan', 9984072, 28271)
# (519, 2019, 'Michigan', 9986857, 28279)

# %%
c.execute('SELECT * FROM npvic_status')
for row in c.fetchall():
    print(row)
# Out:
# (0, 'Alaska', 0.0)
# (1, 'Alabama', 0.0)
# (2, 'Arkansas', 0.5)
# (3, 'Arizona', 0.5)
# (4, 'California', 1.0)
# (5, 'Colorado', 1.0)
# (6, 'Connecticut', 1.0)
# (7, 'District of Columbia', 1.0)
# (8, 'Delaware', 1.0)
# (9, 'Florida', 0.0)
# (10, 'Georgia', 0.25)
# (11, 'Hawaii', 1.0)
# (12, 'Iowa', 0.0)
# (13, 'Idaho', 0.0)
# (14, 'Illinois', 1.0)
# (15, 'Indiana', 0.0)
# (16, 'Kansas', 0.0)
# (17, 'Kentucky', 0.0)
# (18, 'Louisiana', 0.0)
# (19, 'Massachusetts', 1.0)
# (20, 'Maryland', 1.0)
# (21, 'Maine', 0.5)
# (22, 'Michigan', 0.5)
# (23, 'Minnesota', 0.5)
# (24, 'Missouri', 0.25)
# (25, 'Mississippi', 0.0)
# (26, 'Montana', 0.0)
# (27, 'North Carolina', 0.5)
# (28, 'North Dakota', 0.0)
# (29, 'Nebraska', 0.0)
# (30, 'New Hampshire', 0.0)
# (31, 'New Jersey', 1.0)
# (32, 'New Mexico', 1.0)
# (33, 'Nevada', 0.5)
# (34, 'New York', 1.0)
# (35, 'Ohio', 0.0)
# (36, 'Oklahoma', 0.5)
# (37, 'Oregon', 1.0)
# (38, 'Pennsylvania', 0.0)
# (39, 'Rhode Island', 1.0)
# (40, 'South Carolina', 0.0)
# (41, 'South Dakota', 0.0)
# (42, 'Tennessee', 0.0)
# (43, 'Texas', 0.0)
# (44, 'Utah', 0.0)
# (45, 'Virginia', 0.0)
# (46, 'Vermont', 1.0)
# (47, 'Washington', 1.0)
# (48, 'Wisconsin', 0.0)
# (49, 'West Virginia', 0.0)
# (50, 'Wyoming', 0.0)

# %%
c.execute('SELECT * FROM election_results')
for row in c.fetchall():
    print(row)
# Out:
# (0, 1976, 'Alabama', 'Carter, Jimmy', 'democrat', 659170, 1182850)
# (1, 1976, 'Alabama', 'Ford, Gerald', 'republican', 504070, 1182850)
# (2, 1976, 'Alaska', 'Ford, Gerald', 'republican', 71555, 123574)
# (3, 1976, 'Alaska', 'Carter, Jimmy', 'democrat', 44058, 123574)
# (4, 1976, 'Arizona', 'Ford, Gerald', 'republican', 418642, 742719)
# (5, 1976, 'Arizona', 'Carter, Jimmy', 'democrat', 295602, 742719)
# (6, 1976, 'Arkansas', 'Carter, Jimmy', 'democrat', 498604, 767535)
# (7, 1976, 'Arkansas', 'Ford, Gerald', 'republican', 267903, 767535)
# (8, 1976, 'California', 'Ford, Gerald', 'republican', 3882244, 7803770)
# (9, 1976, 'California', 'Carter, Jimmy', 'democrat', 3742284, 7803770)
# (10, 1976, 'Colorado', 'Ford, Gerald', 'republican', 584278, 1081440)
# (11, 1976, 'Colorado', 'Carter, Jimmy', 'democrat', 460801, 1081440)
# (12, 1976, 'Connecticut', 'Ford, Gerald', 'republican', 719261, 1386355)
# (13, 1976, 'Connecticut', 'Carter, Jimmy', 'democrat', 647895, 1386355)
# (14, 1976, 'Delaware', 'Carter, Jimmy', 'democrat', 122461, 235642)
# (15, 1976, 'Delaware', 'Ford, Gerald', 'republican', 109780, 235642)
# (16, 1976, 'District of Columbia', 'Carter, Jimmy', 'democrat', 137818, 168830)
# (17, 1976, 'District of Columbia', 'Ford, Gerald', 'republican', 27873, 168830)
# (18, 1976, 'Florida', 'Carter, Jimmy', 'democrat', 1636000, 3150631)
# (19, 1976, 'Florida', 'Ford, Gerald', 'republican', 1469531, 3150631)
# (20, 1976, 'Georgia', 'Carter, Jimmy', 'democrat', 979409, 1463152)
# (21, 1976, 'Georgia', 'Ford, Gerald', 'republican', 483743, 1463152)
# (22, 1976, 'Hawaii', 'Carter, Jimmy', 'democrat', 147375, 291301)
# (23, 1976, 'Hawaii', 'Ford, Gerald', 'republican', 140003, 291301)
# (24, 1976, 'Idaho', 'Ford, Gerald', 'republican', 204151, 340932)
# (25, 1976, 'Idaho', 'Carter, Jimmy', 'democrat', 126549, 340932)
# (26, 1976, 'Illinois', 'Ford, Gerald', 'republican', 2364269, 4721282)
# (27, 1976, 'Illinois', 'Carter, Jimmy', 'democrat', 2271295, 4721282)
# (28, 1976, 'Indiana', 'Ford, Gerald', 'republican', 1183958, 2220362)
# (29, 1976, 'Indiana', 'Carter, Jimmy', 'democrat', 1014714, 2220362)
# (30, 1976, 'Iowa', 'Ford, Gerald', 'republican', 632864, 1279303)
# (31, 1976, 'Iowa', 'Carter, Jimmy', 'democrat', 619931, 1279303)
# (32, 1976, 'Kansas', 'Ford, Gerald', 'republican', 502752, 957845)
# (33, 1976, 'Kansas', 'Carter, Jimmy', 'democrat', 430421, 957845)
# (34, 1976, 'Kentucky', 'Carter, Jimmy', 'democrat', 615717, 1167142)
# (35, 1976, 'Kentucky', 'Ford, Gerald', 'republican', 531852, 1167142)
# (36, 1976, 'Louisiana', 'Carter, Jimmy', 'democrat', 661365, 1277383)
# (37, 1976, 'Louisiana', 'Ford, Gerald', 'republican', 587446, 1277383)
# (38, 1976, 'Maine', 'Ford, Gerald', 'republican', 236320, 482968)
# (39, 1976, 'Maine', 'Carter, Jimmy', 'democrat', 232279, 482968)
# (40, 1976, 'Maryland', 'Carter, Jimmy', 'democrat', 759612, 1432273)
# (41, 1976, 'Maryland', 'Ford, Gerald', 'republican', 672661, 1432273)
# (42, 1976, 'Massachusetts', 'Carter, Jimmy', 'democrat', 1429475, 2547558)
# (43, 1976, 'Massachusetts', 'Ford, Gerald', 'republican', 1030276, 2547558)
# (44, 1976, 'Michigan', 'Ford, Gerald', 'republican', 1893742, 3651590)
# (45, 1976, 'Michigan', 'Carter, Jimmy', 'democrat', 1696714, 3651590)
# (46, 1976, 'Minnesota', 'Carter, Jimmy', 'democrat', 1070440, 1949931)
# (47, 1976, 'Minnesota', 'Ford, Gerald', 'republican', 819395, 1949931)
# (48, 1976, 'Mississippi', 'Carter, Jimmy', 'democrat', 381329, 768390)
# (49, 1976, 'Mississippi', 'Ford, Gerald', 'republican', 366846, 768390)
# (50, 1976, 'Missouri', 'Carter, Jimmy', 'democrat', 998387, 1953600)
# (51, 1976, 'Missouri', 'Ford, Gerald', 'republican', 927443, 1953600)
# (52, 1976, 'Montana', 'Ford, Gerald', 'republican', 173703, 328734)
# (53, 1976, 'Montana', 'Carter, Jimmy', 'democrat', 149259, 328734)
# (54, 1976, 'Nebraska', 'Ford, Gerald', 'republican', 359219, 606749)
# (55, 1976, 'Nebraska', 'Carter, Jimmy', 'democrat', 233293, 606749)
# (56, 1976, 'Nevada', 'Ford, Gerald', 'republican', 101273, 201876)
# (57, 1976, 'Nevada', 'Carter, Jimmy', 'democrat', 92479, 201876)
# (58, 1976, 'New Hampshire', 'Ford, Gerald', 'republican', 185935, 339627)
# (59, 1976, 'New Hampshire', 'Carter, Jimmy', 'democrat', 147645, 339627)
# (60, 1976, 'New Jersey', 'Ford, Gerald', 'republican', 1509688, 3014472)
# (61, 1976, 'New Jersey', 'Carter, Jimmy', 'democrat', 1444653, 3014472)
# (62, 1976, 'New Mexico', 'Ford, Gerald', 'republican', 211419, 416590)
# (63, 1976, 'New Mexico', 'Carter, Jimmy', 'democrat', 201148, 416590)
# (64, 1976, 'New York', 'Carter, Jimmy', 'democrat', 3244165, 6668262)
# (65, 1976, 'New York', 'Ford, Gerald', 'republican', 2825913, 6668262)
# (66, 1976, 'North Carolina', 'Carter, Jimmy', 'democrat', 927365, 1677906)
# (67, 1976, 'North Carolina', 'Ford, Gerald', 'republican', 741960, 1677906)
# (68, 1976, 'North Dakota', 'Ford, Gerald', 'republican', 153684, 297308)
# (69, 1976, 'North Dakota', 'Carter, Jimmy', 'democrat', 136078, 297308)
# (70, 1976, 'Ohio', 'Carter, Jimmy', 'democrat', 2009959, 4110456)
# (71, 1976, 'Ohio', 'Ford, Gerald', 'republican', 2000626, 4110456)
# (72, 1976, 'Oklahoma', 'Ford, Gerald', 'republican', 545708, 1092251)
# (73, 1976, 'Oklahoma', 'Carter, Jimmy', 'democrat', 532442, 1092251)
# (74, 1976, 'Oregon', 'Ford, Gerald', 'republican', 492120, 1029876)
# (75, 1976, 'Oregon', 'Carter, Jimmy', 'democrat', 490407, 1029876)
# (76, 1976, 'Pennsylvania', 'Carter, Jimmy', 'democrat', 2328677, 4620787)
# (77, 1976, 'Pennsylvania', 'Ford, Gerald', 'republican', 2205604, 4620787)
# (78, 1976, 'Rhode Island', 'Carter, Jimmy', 'democrat', 227636, 410584)
# (79, 1976, 'Rhode Island', 'Ford, Gerald', 'republican', 181249, 410584)
# (80, 1976, 'South Carolina', 'Carter, Jimmy', 'democrat', 450807, 802583)
# (81, 1976, 'South Carolina', 'Ford, Gerald', 'republican', 346149, 802583)
# (82, 1976, 'South Dakota', 'Ford, Gerald', 'republican', 151505, 300678)
# (83, 1976, 'South Dakota', 'Carter, Jimmy', 'democrat', 147068, 300678)
# (84, 1976, 'Tennessee', 'Carter, Jimmy', 'democrat', 825879, 1476346)
# (85, 1976, 'Tennessee', 'Ford, Gerald', 'republican', 633969, 1476346)
# (86, 1976, 'Texas', 'Carter, Jimmy', 'democrat', 2082319, 4071884)
# (87, 1976, 'Texas', 'Ford, Gerald', 'republican', 1953300, 4071884)
# (88, 1976, 'Utah', 'Ford, Gerald', 'republican', 337908, 541218)
# (89, 1976, 'Utah', 'Carter, Jimmy', 'democrat', 182110, 541218)
# (90, 1976, 'Vermont', 'Ford, Gerald', 'republican', 100387, 183902)
# (91, 1976, 'Vermont', 'Carter, Jimmy', 'democrat', 77798, 183902)
# (92, 1976, 'Virginia', 'Ford, Gerald', 'republican', 836554, 1697094)
# (93, 1976, 'Virginia', 'Carter, Jimmy', 'democrat', 813896, 1697094)
# (94, 1976, 'Washington', 'Ford, Gerald', 'republican', 777732, 1555534)
# (95, 1976, 'Washington', 'Carter, Jimmy', 'democrat', 717323, 1555534)
# (96, 1976, 'West Virginia', 'Carter, Jimmy', 'democrat', 435864, 750590)
# (97, 1976, 'West Virginia', 'Ford, Gerald', 'republican', 314726, 750590)
# (98, 1976, 'Wisconsin', 'Carter, Jimmy', 'democrat', 1040232, 2101336)
# (99, 1976, 'Wisconsin', 'Ford, Gerald', 'republican', 1004987, 2101336)
# (100, 1976, 'Wyoming', 'Ford, Gerald', 'republican', 92717, 156343)
# (101, 1976, 'Wyoming', 'Carter, Jimmy', 'democrat', 62239, 156343)
# (102, 1980, 'Alabama', 'Reagan, Ronald', 'republican', 654192, 1341929)
# (103, 1980, 'Alabama', 'Carter, Jimmy', 'democrat', 636730, 1341929)
# (104, 1980, 'Alaska', 'Reagan, Ronald', 'republican', 86112, 158445)
# (105, 1980, 'Alaska', 'Carter, Jimmy', 'democrat', 41842, 158445)
# (106, 1980, 'Arizona', 'Reagan, Ronald', 'republican', 529688, 873945)
# (107, 1980, 'Arizona', 'Carter, Jimmy', 'democrat', 246843, 873945)
# (108, 1980, 'Arkansas', 'Reagan, Ronald', 'republican', 403164, 837582)
# (109, 1980, 'Arkansas', 'Carter, Jimmy', 'democrat', 398041, 837582)
# (110, 1980, 'California', 'Reagan, Ronald', 'republican', 4522994, 8582938)
# (111, 1980, 'California', 'Carter, Jimmy', 'democrat', 3082943, 8582938)
# (112, 1980, 'Colorado', 'Reagan, Ronald', 'republican', 652264, 1184450)
# (113, 1980, 'Colorado', 'Carter, Jimmy', 'democrat', 368009, 1184450)
# (114, 1980, 'Connecticut', 'Reagan, Ronald', 'republican', 677210, 1406285)
# (115, 1980, 'Connecticut', 'Carter, Jimmy', 'democrat', 541732, 1406285)
# (116, 1980, 'Delaware', 'Reagan, Ronald', 'republican', 111252, 235668)
# (117, 1980, 'Delaware', 'Carter, Jimmy', 'democrat', 105754, 235668)
# (118, 1980, 'District of Columbia', 'Carter, Jimmy', 'democrat', 130231, 173889)
# (119, 1980, 'District of Columbia', 'Reagan, Ronald', 'republican', 23313, 173889)
# (120, 1980, 'Florida', 'Reagan, Ronald', 'republican', 2046951, 3686927)
# (121, 1980, 'Florida', 'Carter, Jimmy', 'democrat', 1419475, 3686927)
# (122, 1980, 'Georgia', 'Carter, Jimmy', 'democrat', 890955, 1596805)
# (123, 1980, 'Georgia', 'Reagan, Ronald', 'republican', 654168, 1596805)
# (124, 1980, 'Hawaii', 'Carter, Jimmy', 'democrat', 135879, 303287)
# (125, 1980, 'Hawaii', 'Reagan, Ronald', 'republican', 130112, 303287)
# (126, 1980, 'Idaho', 'Reagan, Ronald', 'republican', 290699, 437431)
# (127, 1980, 'Idaho', 'Carter, Jimmy', 'democrat', 110192, 437431)
# (128, 1980, 'Illinois', 'Reagan, Ronald', 'republican', 2358049, 4749721)
# (129, 1980, 'Illinois', 'Carter, Jimmy', 'democrat', 1981413, 4749721)
# (130, 1980, 'Indiana', 'Reagan, Ronald', 'republican', 1255656, 2242033)
# (131, 1980, 'Indiana', 'Carter, Jimmy', 'democrat', 844197, 2242033)
# (132, 1980, 'Iowa', 'Reagan, Ronald', 'republican', 676026, 1317661)
# (133, 1980, 'Iowa', 'Carter, Jimmy', 'democrat', 508672, 1317661)
# (134, 1980, 'Kansas', 'Reagan, Ronald', 'republican', 566812, 979795)
# (135, 1980, 'Kansas', 'Carter, Jimmy', 'democrat', 326150, 979795)
# (136, 1980, 'Kentucky', 'Reagan, Ronald', 'republican', 635274, 1295627)
# (137, 1980, 'Kentucky', 'Carter, Jimmy', 'democrat', 617417, 1295627)
# (138, 1980, 'Louisiana', 'Reagan, Ronald', 'republican', 792853, 1548591)
# (139, 1980, 'Louisiana', 'Carter, Jimmy', 'democrat', 708453, 1548591)
# (140, 1980, 'Maine', 'Reagan, Ronald', 'republican', 238522, 523011)
# (141, 1980, 'Maine', 'Carter, Jimmy', 'democrat', 220974, 523011)
# (142, 1980, 'Maryland', 'Carter, Jimmy', 'democrat', 726161, 1540496)
# (143, 1980, 'Maryland', 'Reagan, Ronald', 'republican', 680606, 1540496)
# (144, 1980, 'Massachusetts', 'Reagan, Ronald', 'republican', 1057631, 2524090)
# (145, 1980, 'Massachusetts', 'Carter, Jimmy', 'democrat', 1053802, 2524090)
# (146, 1980, 'Michigan', 'Reagan, Ronald', 'republican', 1915225, 3909725)
# (147, 1980, 'Michigan', 'Carter, Jimmy', 'democrat', 1661532, 3909725)
# (148, 1980, 'Minnesota', 'Carter, Jimmy', 'democrat', 954173, 2051916)
# (149, 1980, 'Minnesota', 'Reagan, Ronald', 'republican', 873268, 2051916)
# (150, 1980, 'Mississippi', 'Reagan, Ronald', 'republican', 441089, 891750)
# (151, 1980, 'Mississippi', 'Carter, Jimmy', 'democrat', 429281, 891750)
# (152, 1980, 'Missouri', 'Reagan, Ronald', 'republican', 1074181, 2099824)
# (153, 1980, 'Missouri', 'Carter, Jimmy', 'democrat', 931182, 2099824)
# (154, 1980, 'Montana', 'Reagan, Ronald', 'republican', 206814, 363952)
# (155, 1980, 'Montana', 'Carter, Jimmy', 'democrat', 118032, 363952)
# (156, 1980, 'Nebraska', 'Reagan, Ronald', 'republican', 419214, 639533)
# (157, 1980, 'Nebraska', 'Carter, Jimmy', 'democrat', 166424, 639533)
# (158, 1980, 'Nevada', 'Reagan, Ronald', 'republican', 155017, 243692)
# (159, 1980, 'Nevada', 'Carter, Jimmy', 'democrat', 66666, 243692)
# (160, 1980, 'New Hampshire', 'Reagan, Ronald', 'republican', 221705, 383990)
# (161, 1980, 'New Hampshire', 'Carter, Jimmy', 'democrat', 108864, 383990)
# (162, 1980, 'New Jersey', 'Reagan, Ronald', 'republican', 1546557, 2975684)
# (163, 1980, 'New Jersey', 'Carter, Jimmy', 'democrat', 1147364, 2975684)
# (164, 1980, 'New Mexico', 'Reagan, Ronald', 'republican', 250779, 456237)
# (165, 1980, 'New Mexico', 'Carter, Jimmy', 'democrat', 167826, 456237)
# (166, 1980, 'New York', 'Carter, Jimmy', 'democrat', 2728372, 6201959)
# (167, 1980, 'New York', 'Reagan, Ronald', 'republican', 2637700, 6201959)
# (168, 1980, 'North Carolina', 'Reagan, Ronald', 'republican', 915018, 1855833)
# (169, 1980, 'North Carolina', 'Carter, Jimmy', 'democrat', 875635, 1855833)
# (170, 1980, 'North Dakota', 'Reagan, Ronald', 'republican', 193695, 301116)
# (171, 1980, 'North Dakota', 'Carter, Jimmy', 'democrat', 79189, 301116)
# (172, 1980, 'Ohio', 'Reagan, Ronald', 'republican', 2206545, 4283603)
# (173, 1980, 'Ohio', 'Carter, Jimmy', 'democrat', 1752414, 4283603)
# (174, 1980, 'Oklahoma', 'Reagan, Ronald', 'republican', 695570, 1149708)
# (175, 1980, 'Oklahoma', 'Carter, Jimmy', 'democrat', 402026, 1149708)
# (176, 1980, 'Oregon', 'Reagan, Ronald', 'republican', 571044, 1181516)
# (177, 1980, 'Oregon', 'Carter, Jimmy', 'democrat', 456890, 1181516)
# (178, 1980, 'Pennsylvania', 'Reagan, Ronald', 'republican', 2261872, 4561501)
# (179, 1980, 'Pennsylvania', 'Carter, Jimmy', 'democrat', 1937540, 4561501)
# (180, 1980, 'Rhode Island', 'Carter, Jimmy', 'democrat', 198342, 415967)
# (181, 1980, 'Rhode Island', 'Reagan, Ronald', 'republican', 154793, 415967)
# (182, 1980, 'South Carolina', 'Reagan, Ronald', 'republican', 439277, 888258)
# (183, 1980, 'South Carolina', 'Carter, Jimmy', 'democrat', 428220, 888258)
# (184, 1980, 'South Dakota', 'Reagan, Ronald', 'republican', 198343, 327703)
# (185, 1980, 'South Dakota', 'Carter, Jimmy', 'democrat', 103855, 327703)
# (186, 1980, 'Tennessee', 'Reagan, Ronald', 'republican', 787761, 1617616)
# (187, 1980, 'Tennessee', 'Carter, Jimmy', 'democrat', 783051, 1617616)
# (188, 1980, 'Texas', 'Reagan, Ronald', 'republican', 2510705, 4541636)
# (189, 1980, 'Texas', 'Carter, Jimmy', 'democrat', 1881147, 4541636)
# (190, 1980, 'Utah', 'Reagan, Ronald', 'republican', 439687, 604152)
# (191, 1980, 'Utah', 'Carter, Jimmy', 'democrat', 124266, 604152)
# (192, 1980, 'Vermont', 'Reagan, Ronald', 'republican', 94628, 213299)
# (193, 1980, 'Vermont', 'Carter, Jimmy', 'democrat', 81952, 213299)
# (194, 1980, 'Virginia', 'Reagan, Ronald', 'republican', 989609, 1866032)
# (195, 1980, 'Virginia', 'Carter, Jimmy', 'democrat', 752174, 1866032)
# (196, 1980, 'Washington', 'Reagan, Ronald', 'republican', 865244, 1742394)
# (197, 1980, 'Washington', 'Carter, Jimmy', 'democrat', 650193, 1742394)
# (198, 1980, 'West Virginia', 'Carter, Jimmy', 'democrat', 367462, 737715)
# (199, 1980, 'West Virginia', 'Reagan, Ronald', 'republican', 334206, 737715)
# (200, 1980, 'Wisconsin', 'Reagan, Ronald', 'republican', 1088845, 2273221)
# (201, 1980, 'Wisconsin', 'Carter, Jimmy', 'democrat', 981584, 2273221)
# (202, 1980, 'Wyoming', 'Reagan, Ronald', 'republican', 110700, 176713)
# (203, 1980, 'Wyoming', 'Carter, Jimmy', 'democrat', 49427, 176713)
# (204, 1984, 'Alabama', 'Reagan, Ronald', 'republican', 872849, 1441713)
# (205, 1984, 'Alabama', 'Mondale, Walter', 'democrat', 551899, 1441713)
# (206, 1984, 'Alaska', 'Reagan, Ronald', 'republican', 138377, 207605)
# (207, 1984, 'Alaska', 'Mondale, Walter', 'democrat', 62007, 207605)
# (208, 1984, 'Arizona', 'Reagan, Ronald', 'republican', 681416, 1025897)
# (209, 1984, 'Arizona', 'Mondale, Walter', 'democrat', 333854, 1025897)
# (210, 1984, 'Arkansas', 'Reagan, Ronald', 'republican', 534774, 884406)
# (211, 1984, 'Arkansas', 'Mondale, Walter', 'democrat', 338646, 884406)
# (212, 1984, 'California', 'Reagan, Ronald', 'republican', 5467009, 9505041)
# (213, 1984, 'California', 'Mondale, Walter', 'democrat', 3922519, 9505041)
# (214, 1984, 'Colorado', 'Reagan, Ronald', 'republican', 821817, 1295380)
# (215, 1984, 'Colorado', 'Mondale, Walter', 'democrat', 454975, 1295380)
# (216, 1984, 'Connecticut', 'Reagan, Ronald', 'republican', 890877, 1466900)
# (217, 1984, 'Connecticut', 'Mondale, Walter', 'democrat', 569597, 1466900)
# (218, 1984, 'Delaware', 'Reagan, Ronald', 'republican', 152190, 254572)
# (219, 1984, 'Delaware', 'Mondale, Walter', 'democrat', 101656, 254572)
# (220, 1984, 'District of Columbia', 'Mondale, Walter', 'democrat', 180408, 211288)
# (221, 1984, 'District of Columbia', 'Reagan, Ronald', 'republican', 29009, 211288)
# (222, 1984, 'Florida', 'Reagan, Ronald', 'republican', 2730350, 4180051)
# (223, 1984, 'Florida', 'Mondale, Walter', 'democrat', 1448816, 4180051)
# (224, 1984, 'Georgia', 'Reagan, Ronald', 'republican', 1068722, 1776103)
# (225, 1984, 'Georgia', 'Mondale, Walter', 'democrat', 706628, 1776103)
# (226, 1984, 'Hawaii', 'Reagan, Ronald', 'republican', 185050, 335846)
# (227, 1984, 'Hawaii', 'Mondale, Walter', 'democrat', 147154, 335846)
# (228, 1984, 'Idaho', 'Reagan, Ronald', 'republican', 297523, 411144)
# (229, 1984, 'Idaho', 'Mondale, Walter', 'democrat', 108510, 411144)
# (230, 1984, 'Illinois', 'Reagan, Ronald', 'republican', 2707103, 4819088)
# (231, 1984, 'Illinois', 'Mondale, Walter', 'democrat', 2086499, 4819088)
# (232, 1984, 'Indiana', 'Reagan, Ronald', 'republican', 1377230, 2233069)
# (233, 1984, 'Indiana', 'Mondale, Walter', 'democrat', 841481, 2233069)
# (234, 1984, 'Iowa', 'Reagan, Ronald', 'republican', 703088, 1319805)
# (235, 1984, 'Iowa', 'Mondale, Walter', 'democrat', 605620, 1319805)
# (236, 1984, 'Kansas', 'Reagan, Ronald', 'republican', 677296, 1021991)
# (237, 1984, 'Kansas', 'Mondale, Walter', 'democrat', 333149, 1021991)
# (238, 1984, 'Kentucky', 'Reagan, Ronald', 'republican', 821702, 1369345)
# (239, 1984, 'Kentucky', 'Mondale, Walter', 'democrat', 539539, 1369345)
# (240, 1984, 'Louisiana', 'Reagan, Ronald', 'republican', 1037299, 1706822)
# (241, 1984, 'Louisiana', 'Mondale, Walter', 'democrat', 651586, 1706822)
# (242, 1984, 'Maine', 'Reagan, Ronald', 'republican', 336500, 553144)
# (243, 1984, 'Maine', 'Mondale, Walter', 'democrat', 214515, 553144)
# (244, 1984, 'Maryland', 'Reagan, Ronald', 'republican', 879918, 1675873)
# (245, 1984, 'Maryland', 'Mondale, Walter', 'democrat', 787935, 1675873)
# (246, 1984, 'Massachusetts', 'Reagan, Ronald', 'republican', 1310936, 2559383)
# (247, 1984, 'Massachusetts', 'Mondale, Walter', 'democrat', 1239606, 2559383)
# (248, 1984, 'Michigan', 'Reagan, Ronald', 'republican', 2251571, 3801658)
# (249, 1984, 'Michigan', 'Mondale, Walter', 'democrat', 1529638, 3801658)
# (250, 1984, 'Minnesota', 'Mondale, Walter', 'democrat', 1036364, 2084449)
# (251, 1984, 'Minnesota', 'Reagan, Ronald', 'republican', 1032603, 2084449)
# (252, 1984, 'Mississippi', 'Reagan, Ronald', 'republican', 582377, 941104)
# (253, 1984, 'Mississippi', 'Mondale, Walter', 'democrat', 352192, 941104)
# (254, 1984, 'Missouri', 'Reagan, Ronald', 'republican', 1274188, 2122771)
# (255, 1984, 'Missouri', 'Mondale, Walter', 'democrat', 848583, 2122771)
# (256, 1984, 'Montana', 'Reagan, Ronald', 'republican', 232450, 384377)
# (257, 1984, 'Montana', 'Mondale, Walter', 'democrat', 146742, 384377)
# (258, 1984, 'Nebraska', 'Reagan, Ronald', 'republican', 460054, 652090)
# (259, 1984, 'Nebraska', 'Mondale, Walter', 'democrat', 187866, 652090)
# (260, 1984, 'Nevada', 'Reagan, Ronald', 'republican', 188770, 282717)
# (261, 1984, 'Nevada', 'Mondale, Walter', 'democrat', 91655, 282717)
# (262, 1984, 'New Hampshire', 'Reagan, Ronald', 'republican', 267050, 388904)
# (263, 1984, 'New Hampshire', 'Mondale, Walter', 'democrat', 120347, 388904)
# (264, 1984, 'New Jersey', 'Reagan, Ronald', 'republican', 1933630, 3217862)
# (265, 1984, 'New Jersey', 'Mondale, Walter', 'democrat', 1261323, 3217862)
# (266, 1984, 'New Mexico', 'Reagan, Ronald', 'republican', 307101, 514370)
# (267, 1984, 'New Mexico', 'Mondale, Walter', 'democrat', 201769, 514370)
# (268, 1984, 'New York', 'Reagan, Ronald', 'republican', 3376519, 6806810)
# (269, 1984, 'New York', 'Mondale, Walter', 'democrat', 3001285, 6806810)
# (270, 1984, 'North Carolina', 'Reagan, Ronald', 'republican', 1346481, 2175361)
# (271, 1984, 'North Carolina', 'Mondale, Walter', 'democrat', 824287, 2175361)
# (272, 1984, 'North Dakota', 'Reagan, Ronald', 'republican', 200336, 308971)
# (273, 1984, 'North Dakota', 'Mondale, Walter', 'democrat', 104429, 308971)
# (274, 1984, 'Ohio', 'Reagan, Ronald', 'republican', 2678559, 4563235)
# (275, 1984, 'Ohio', 'Mondale, Walter', 'democrat', 1825440, 4563235)
# (276, 1984, 'Oklahoma', 'Reagan, Ronald', 'republican', 861530, 1255676)
# (277, 1984, 'Oklahoma', 'Mondale, Walter', 'democrat', 385080, 1255676)
# (278, 1984, 'Oregon', 'Reagan, Ronald', 'republican', 685700, 1226527)
# (279, 1984, 'Oregon', 'Mondale, Walter', 'democrat', 536479, 1226527)
# (280, 1984, 'Pennsylvania', 'Reagan, Ronald', 'republican', 2584323, 4844903)
# (281, 1984, 'Pennsylvania', 'Mondale, Walter', 'democrat', 2228131, 4844903)
# (282, 1984, 'Rhode Island', 'Reagan, Ronald', 'republican', 212080, 410489)
# (283, 1984, 'Rhode Island', 'Mondale, Walter', 'democrat', 197106, 410489)
# (284, 1984, 'South Carolina', 'Reagan, Ronald', 'republican', 615539, 968529)
# (285, 1984, 'South Carolina', 'Mondale, Walter', 'democrat', 344459, 968529)
# (286, 1984, 'South Dakota', 'Reagan, Ronald', 'republican', 200267, 317867)
# (287, 1984, 'South Dakota', 'Mondale, Walter', 'democrat', 116113, 317867)
# (288, 1984, 'Tennessee', 'Reagan, Ronald', 'republican', 990212, 1711993)
# (289, 1984, 'Tennessee', 'Mondale, Walter', 'democrat', 711714, 1711993)
# (290, 1984, 'Texas', 'Reagan, Ronald', 'republican', 3433428, 5397571)
# (291, 1984, 'Texas', 'Mondale, Walter', 'democrat', 1949276, 5397571)
# (292, 1984, 'Utah', 'Reagan, Ronald', 'republican', 469105, 629656)
# (293, 1984, 'Utah', 'Mondale, Walter', 'democrat', 155369, 629656)
# (294, 1984, 'Vermont', 'Reagan, Ronald', 'republican', 135865, 234561)
# (295, 1984, 'Vermont', 'Mondale, Walter', 'democrat', 95730, 234561)
# (296, 1984, 'Virginia', 'Reagan, Ronald', 'republican', 1337078, 2146635)
# (297, 1984, 'Virginia', 'Mondale, Walter', 'democrat', 796250, 2146635)
# (298, 1984, 'Washington', 'Reagan, Ronald', 'republican', 1051670, 1874910)
# (299, 1984, 'Washington', 'Mondale, Walter', 'democrat', 798352, 1874910)
# (300, 1984, 'West Virginia', 'Reagan, Ronald', 'republican', 405483, 735742)
# (301, 1984, 'West Virginia', 'Mondale, Walter', 'democrat', 328125, 735742)
# (302, 1984, 'Wisconsin', 'Reagan, Ronald', 'republican', 1198584, 2211689)
# (303, 1984, 'Wisconsin', 'Mondale, Walter', 'democrat', 995740, 2211689)
# (304, 1984, 'Wyoming', 'Reagan, Ronald', 'republican', 133241, 188968)
# (305, 1984, 'Wyoming', 'Mondale, Walter', 'democrat', 53370, 188968)
# (306, 1988, 'Alabama', 'Bush, George H.W.', 'republican', 815576, 1378476)
# (307, 1988, 'Alabama', 'Dukakis, Michael', 'democrat', 549506, 1378476)
# (308, 1988, 'Alaska', 'Bush, George H.W.', 'republican', 119251, 200116)
# (309, 1988, 'Alaska', 'Dukakis, Michael', 'democrat', 72584, 200116)
# (310, 1988, 'Arizona', 'Bush, George H.W.', 'republican', 702541, 1171873)
# (311, 1988, 'Arizona', 'Dukakis, Michael', 'democrat', 454029, 1171873)
# (312, 1988, 'Arkansas', 'Bush, George H.W.', 'republican', 466578, 827738)
# (313, 1988, 'Arkansas', 'Dukakis, Michael', 'democrat', 349237, 827738)
# (314, 1988, 'California', 'Bush, George H.W.', 'republican', 5054917, 9887065)
# (315, 1988, 'California', 'Dukakis, Michael', 'democrat', 4702233, 9887065)
# (316, 1988, 'Colorado', 'Bush, George H.W.', 'republican', 728177, 1372394)
# (317, 1988, 'Colorado', 'Dukakis, Michael', 'democrat', 621453, 1372394)
# (318, 1988, 'Connecticut', 'Bush, George H.W.', 'republican', 750241, 1443394)
# (319, 1988, 'Connecticut', 'Dukakis, Michael', 'democrat', 676584, 1443394)
# (320, 1988, 'Delaware', 'Bush, George H.W.', 'republican', 139639, 249891)
# (321, 1988, 'Delaware', 'Dukakis, Michael', 'democrat', 108647, 249891)
# (322, 1988, 'District of Columbia', 'Dukakis, Michael', 'democrat', 159407, 192877)
# (323, 1988, 'District of Columbia', 'Bush, George H.W.', 'republican', 27590, 192877)
# (324, 1988, 'Florida', 'Bush, George H.W.', 'republican', 2618885, 4302313)
# (325, 1988, 'Florida', 'Dukakis, Michael', 'democrat', 1656701, 4302313)
# (326, 1988, 'Georgia', 'Bush, George H.W.', 'republican', 1081331, 1809672)
# (327, 1988, 'Georgia', 'Dukakis, Michael', 'democrat', 714792, 1809672)
# (328, 1988, 'Hawaii', 'Dukakis, Michael', 'democrat', 192364, 354461)
# (329, 1988, 'Hawaii', 'Bush, George H.W.', 'republican', 158625, 354461)
# (330, 1988, 'Idaho', 'Bush, George H.W.', 'republican', 253881, 408968)
# (331, 1988, 'Idaho', 'Dukakis, Michael', 'democrat', 147272, 408968)
# (332, 1988, 'Illinois', 'Bush, George H.W.', 'republican', 2310939, 4559120)
# (333, 1988, 'Illinois', 'Dukakis, Michael', 'democrat', 2215940, 4559120)
# (334, 1988, 'Indiana', 'Bush, George H.W.', 'republican', 1297763, 2168621)
# (335, 1988, 'Indiana', 'Dukakis, Michael', 'democrat', 860643, 2168621)
# (336, 1988, 'Iowa', 'Dukakis, Michael', 'democrat', 670557, 1225614)
# (337, 1988, 'Iowa', 'Bush, George H.W.', 'republican', 545355, 1225614)
# (338, 1988, 'Kansas', 'Bush, George H.W.', 'republican', 554049, 993044)
# (339, 1988, 'Kansas', 'Dukakis, Michael', 'democrat', 422636, 993044)
# (340, 1988, 'Kentucky', 'Bush, George H.W.', 'republican', 734281, 1322517)
# (341, 1988, 'Kentucky', 'Dukakis, Michael', 'democrat', 580368, 1322517)
# (342, 1988, 'Louisiana', 'Bush, George H.W.', 'republican', 883702, 1628202)
# (343, 1988, 'Louisiana', 'Dukakis, Michael', 'democrat', 717460, 1628202)
# (344, 1988, 'Maine', 'Bush, George H.W.', 'republican', 307131, 555035)
# (345, 1988, 'Maine', 'Dukakis, Michael', 'democrat', 243569, 555035)
# (346, 1988, 'Maryland', 'Bush, George H.W.', 'republican', 876167, 1714358)
# (347, 1988, 'Maryland', 'Dukakis, Michael', 'democrat', 826304, 1714358)
# (348, 1988, 'Massachusetts', 'Dukakis, Michael', 'democrat', 1401415, 2632801)
# (349, 1988, 'Massachusetts', 'Bush, George H.W.', 'republican', 1194635, 2632801)
# (350, 1988, 'Michigan', 'Bush, George H.W.', 'republican', 1965486, 3669163)
# (351, 1988, 'Michigan', 'Dukakis, Michael', 'democrat', 1675783, 3669163)
# (352, 1988, 'Minnesota', 'Dukakis, Michael', 'democrat', 1109471, 2096790)
# (353, 1988, 'Minnesota', 'Bush, George H.W.', 'republican', 962337, 2096790)
# (354, 1988, 'Mississippi', 'Bush, George H.W.', 'republican', 557890, 931527)
# (355, 1988, 'Mississippi', 'Dukakis, Michael', 'democrat', 363921, 931527)
# (356, 1988, 'Missouri', 'Bush, George H.W.', 'republican', 1084953, 2093228)
# (357, 1988, 'Missouri', 'Dukakis, Michael', 'democrat', 1001619, 2093228)
# (358, 1988, 'Montana', 'Bush, George H.W.', 'republican', 190412, 365674)
# (359, 1988, 'Montana', 'Dukakis, Michael', 'democrat', 168936, 365674)
# (360, 1988, 'Nebraska', 'Bush, George H.W.', 'republican', 397956, 661465)
# (361, 1988, 'Nebraska', 'Dukakis, Michael', 'democrat', 259235, 661465)
# (362, 1988, 'Nevada', 'Bush, George H.W.', 'republican', 206040, 343133)
# (363, 1988, 'Nevada', 'Dukakis, Michael', 'democrat', 132738, 343133)
# (364, 1988, 'New Hampshire', 'Bush, George H.W.', 'republican', 281537, 450525)
# (365, 1988, 'New Hampshire', 'Dukakis, Michael', 'democrat', 163696, 450525)
# (366, 1988, 'New Jersey', 'Bush, George H.W.', 'republican', 1743192, 3099553)
# (367, 1988, 'New Jersey', 'Dukakis, Michael', 'democrat', 1320352, 3099553)
# (368, 1988, 'New Mexico', 'Bush, George H.W.', 'republican', 270341, 521387)
# (369, 1988, 'New Mexico', 'Dukakis, Michael', 'democrat', 244497, 521387)
# (370, 1988, 'New York', 'Dukakis, Michael', 'democrat', 3255487, 6485683)
# (371, 1988, 'New York', 'Bush, George H.W.', 'republican', 2838414, 6485683)
# (372, 1988, 'North Carolina', 'Bush, George H.W.', 'republican', 1237258, 2134370)
# (373, 1988, 'North Carolina', 'Dukakis, Michael', 'democrat', 890167, 2134370)
# (374, 1988, 'North Dakota', 'Bush, George H.W.', 'republican', 166559, 297261)
# (375, 1988, 'North Dakota', 'Dukakis, Michael', 'democrat', 127739, 297261)
# (376, 1988, 'Ohio', 'Bush, George H.W.', 'republican', 2416549, 4393585)
# (377, 1988, 'Ohio', 'Dukakis, Michael', 'democrat', 1939629, 4393585)
# (378, 1988, 'Oklahoma', 'Bush, George H.W.', 'republican', 678367, 1171036)
# (379, 1988, 'Oklahoma', 'Dukakis, Michael', 'democrat', 483423, 1171036)
# (380, 1988, 'Oregon', 'Dukakis, Michael', 'democrat', 616206, 1201694)
# (381, 1988, 'Oregon', 'Bush, George H.W.', 'republican', 560126, 1201694)
# (382, 1988, 'Pennsylvania', 'Bush, George H.W.', 'republican', 2300087, 4536251)
# (383, 1988, 'Pennsylvania', 'Dukakis, Michael', 'democrat', 2194944, 4536251)
# (384, 1988, 'Rhode Island', 'Dukakis, Michael', 'democrat', 225123, 404622)
# (385, 1988, 'Rhode Island', 'Bush, George H.W.', 'republican', 177761, 404622)
# (386, 1988, 'South Carolina', 'Bush, George H.W.', 'republican', 606443, 986009)
# (387, 1988, 'South Carolina', 'Dukakis, Michael', 'democrat', 370554, 986009)
# (388, 1988, 'South Dakota', 'Bush, George H.W.', 'republican', 165415, 312991)
# (389, 1988, 'South Dakota', 'Dukakis, Michael', 'democrat', 145560, 312991)
# (390, 1988, 'Tennessee', 'Bush, George H.W.', 'republican', 947233, 1636250)
# (391, 1988, 'Tennessee', 'Dukakis, Michael', 'democrat', 679794, 1636250)
# (392, 1988, 'Texas', 'Bush, George H.W.', 'republican', 3036829, 5427410)
# (393, 1988, 'Texas', 'Dukakis, Michael', 'democrat', 2352748, 5427410)
# (394, 1988, 'Utah', 'Bush, George H.W.', 'republican', 428442, 647008)
# (395, 1988, 'Utah', 'Dukakis, Michael', 'democrat', 207343, 647008)
# (396, 1988, 'Vermont', 'Bush, George H.W.', 'republican', 124331, 243328)
# (397, 1988, 'Vermont', 'Dukakis, Michael', 'democrat', 115775, 243328)
# (398, 1988, 'Virginia', 'Bush, George H.W.', 'republican', 1309162, 2191609)
# (399, 1988, 'Virginia', 'Dukakis, Michael', 'democrat', 859799, 2191609)
# (400, 1988, 'Washington', 'Dukakis, Michael', 'democrat', 933516, 1865253)
# (401, 1988, 'Washington', 'Bush, George H.W.', 'republican', 903835, 1865253)
# (402, 1988, 'West Virginia', 'Dukakis, Michael', 'democrat', 341016, 653311)
# (403, 1988, 'West Virginia', 'Bush, George H.W.', 'republican', 310065, 653311)
# (404, 1988, 'Wisconsin', 'Dukakis, Michael', 'democrat', 1126794, 2191608)
# (405, 1988, 'Wisconsin', 'Bush, George H.W.', 'republican', 1047499, 2191608)
# (406, 1988, 'Wyoming', 'Bush, George H.W.', 'republican', 106867, 176551)
# (407, 1988, 'Wyoming', 'Dukakis, Michael', 'democrat', 67113, 176551)
# (408, 1992, 'Alabama', 'Bush, George H.W.', 'republican', 804283, 1688060)
# (409, 1992, 'Alabama', 'Clinton, Bill', 'democrat', 690080, 1688060)
# (410, 1992, 'Alaska', 'Bush, George H.W.', 'republican', 102000, 258506)
# (411, 1992, 'Alaska', 'Clinton, Bill', 'democrat', 78294, 258506)
# (412, 1992, 'Arizona', 'Bush, George H.W.', 'republican', 572086, 1486975)
# (413, 1992, 'Arizona', 'Clinton, Bill', 'democrat', 543050, 1486975)
# (414, 1992, 'Arkansas', 'Clinton, Bill', 'democrat', 505823, 950653)
# (415, 1992, 'Arkansas', 'Bush, George H.W.', 'republican', 337324, 950653)
# (416, 1992, 'California', 'Clinton, Bill', 'democrat', 5121325, 11131721)
# (417, 1992, 'California', 'Bush, George H.W.', 'republican', 3630574, 11131721)
# (418, 1992, 'Colorado', 'Clinton, Bill', 'democrat', 629681, 1569180)
# (419, 1992, 'Colorado', 'Bush, George H.W.', 'republican', 562850, 1569180)
# (420, 1992, 'Connecticut', 'Clinton, Bill', 'democrat', 682318, 1616156)
# (421, 1992, 'Connecticut', 'Bush, George H.W.', 'republican', 578313, 1616156)
# (422, 1992, 'Delaware', 'Clinton, Bill', 'democrat', 126054, 289620)
# (423, 1992, 'Delaware', 'Bush, George H.W.', 'republican', 102313, 289620)
# (424, 1992, 'District of Columbia', 'Clinton, Bill', 'democrat', 192619, 227572)
# (425, 1992, 'District of Columbia', 'Bush, George H.W.', 'republican', 20698, 227572)
# (426, 1992, 'Florida', 'Bush, George H.W.', 'republican', 2173310, 5313392)
# (427, 1992, 'Florida', 'Clinton, Bill', 'democrat', 2071698, 5313392)
# (428, 1992, 'Georgia', 'Clinton, Bill', 'democrat', 1008966, 2321133)
# (429, 1992, 'Georgia', 'Bush, George H.W.', 'republican', 995252, 2321133)
# (430, 1992, 'Hawaii', 'Clinton, Bill', 'democrat', 179310, 372842)
# (431, 1992, 'Hawaii', 'Bush, George H.W.', 'republican', 136822, 372842)
# (432, 1992, 'Idaho', 'Bush, George H.W.', 'republican', 202645, 482114)
# (433, 1992, 'Idaho', 'Clinton, Bill', 'democrat', 137013, 482114)
# (434, 1992, 'Illinois', 'Clinton, Bill', 'democrat', 2453350, 5050157)
# (435, 1992, 'Illinois', 'Bush, George H.W.', 'republican', 1734096, 5050157)
# (436, 1992, 'Indiana', 'Bush, George H.W.', 'republican', 989375, 2305871)
# (437, 1992, 'Indiana', 'Clinton, Bill', 'democrat', 848420, 2305871)
# (438, 1992, 'Iowa', 'Clinton, Bill', 'democrat', 586353, 1354607)
# (439, 1992, 'Iowa', 'Bush, George H.W.', 'republican', 504891, 1354607)
# (440, 1992, 'Kansas', 'Bush, George H.W.', 'republican', 449951, 1157236)
# (441, 1992, 'Kansas', 'Clinton, Bill', 'democrat', 390434, 1157236)
# (442, 1992, 'Kentucky', 'Clinton, Bill', 'democrat', 665104, 1492900)
# (443, 1992, 'Kentucky', 'Bush, George H.W.', 'republican', 617178, 1492900)
# (444, 1992, 'Louisiana', 'Clinton, Bill', 'democrat', 815971, 1790017)
# (445, 1992, 'Louisiana', 'Bush, George H.W.', 'republican', 733386, 1790017)
# (446, 1992, 'Maine', 'Clinton, Bill', 'democrat', 263420, 679499)
# (447, 1992, 'Maine', 'Bush, George H.W.', 'republican', 206504, 679499)
# (448, 1992, 'Maryland', 'Clinton, Bill', 'democrat', 988571, 1984580)
# (449, 1992, 'Maryland', 'Bush, George H.W.', 'republican', 707094, 1984580)
# (450, 1992, 'Massachusetts', 'Clinton, Bill', 'democrat', 1318639, 2773664)
# (451, 1992, 'Massachusetts', 'Bush, George H.W.', 'republican', 805039, 2773664)
# (452, 1992, 'Michigan', 'Clinton, Bill', 'democrat', 1871182, 4274673)
# (453, 1992, 'Michigan', 'Bush, George H.W.', 'republican', 1554940, 4274673)
# (454, 1992, 'Minnesota', 'Clinton, Bill', 'democrat', 1020997, 2347948)
# (455, 1992, 'Minnesota', 'Bush, George H.W.', 'republican', 747841, 2347948)
# (456, 1992, 'Mississippi', 'Bush, George H.W.', 'republican', 487793, 981793)
# (457, 1992, 'Mississippi', 'Clinton, Bill', 'democrat', 400258, 981793)
# (458, 1992, 'Missouri', 'Clinton, Bill', 'democrat', 1053873, 2391270)
# (459, 1992, 'Missouri', 'Bush, George H.W.', 'republican', 811159, 2391270)
# (460, 1992, 'Montana', 'Clinton, Bill', 'democrat', 154507, 410583)
# (461, 1992, 'Montana', 'Bush, George H.W.', 'republican', 144207, 410583)
# (462, 1992, 'Nebraska', 'Bush, George H.W.', 'republican', 343678, 737546)
# (463, 1992, 'Nebraska', 'Clinton, Bill', 'democrat', 216864, 737546)
# (464, 1992, 'Nevada', 'Clinton, Bill', 'democrat', 189148, 506318)
# (465, 1992, 'Nevada', 'Bush, George H.W.', 'republican', 175828, 506318)
# (466, 1992, 'New Hampshire', 'Clinton, Bill', 'democrat', 209040, 537215)
# (467, 1992, 'New Hampshire', 'Bush, George H.W.', 'republican', 202484, 537215)
# (468, 1992, 'New Jersey', 'Clinton, Bill', 'democrat', 1436206, 3343594)
# (469, 1992, 'New Jersey', 'Bush, George H.W.', 'republican', 1356865, 3343594)
# (470, 1992, 'New Mexico', 'Clinton, Bill', 'democrat', 261617, 569986)
# (471, 1992, 'New Mexico', 'Bush, George H.W.', 'republican', 212824, 569986)
# (472, 1992, 'New York', 'Clinton, Bill', 'democrat', 3346894, 7079432)
# (473, 1992, 'New York', 'Bush, George H.W.', 'republican', 2041690, 7079432)
# (474, 1992, 'North Carolina', 'Bush, George H.W.', 'republican', 1134661, 2611850)
# (475, 1992, 'North Carolina', 'Clinton, Bill', 'democrat', 1114042, 2611850)
# (476, 1992, 'North Dakota', 'Bush, George H.W.', 'republican', 136244, 308133)
# (477, 1992, 'North Dakota', 'Clinton, Bill', 'democrat', 99168, 308133)
# (478, 1992, 'Ohio', 'Clinton, Bill', 'democrat', 1984942, 4939967)
# (479, 1992, 'Ohio', 'Bush, George H.W.', 'republican', 1894310, 4939967)
# (480, 1992, 'Oklahoma', 'Bush, George H.W.', 'republican', 592929, 1390359)
# (481, 1992, 'Oklahoma', 'Clinton, Bill', 'democrat', 473066, 1390359)
# (482, 1992, 'Oregon', 'Clinton, Bill', 'democrat', 621314, 1462643)
# (483, 1992, 'Oregon', 'Bush, George H.W.', 'republican', 475757, 1462643)
# (484, 1992, 'Pennsylvania', 'Clinton, Bill', 'democrat', 2239164, 4959810)
# (485, 1992, 'Pennsylvania', 'Bush, George H.W.', 'republican', 1791841, 4959810)
# (486, 1992, 'Rhode Island', 'Clinton, Bill', 'democrat', 213299, 453365)
# (487, 1992, 'Rhode Island', 'Bush, George H.W.', 'republican', 131601, 453365)
# (488, 1992, 'South Carolina', 'Bush, George H.W.', 'republican', 577507, 1228912)
# (489, 1992, 'South Carolina', 'Clinton, Bill', 'democrat', 525514, 1228912)
# (490, 1992, 'South Dakota', 'Bush, George H.W.', 'republican', 136718, 336254)
# (491, 1992, 'South Dakota', 'Clinton, Bill', 'democrat', 124888, 336254)
# (492, 1992, 'Tennessee', 'Clinton, Bill', 'democrat', 933521, 1982638)
# (493, 1992, 'Tennessee', 'Bush, George H.W.', 'republican', 841300, 1982638)
# (494, 1992, 'Texas', 'Bush, George H.W.', 'republican', 2496071, 6154018)
# (495, 1992, 'Texas', 'Clinton, Bill', 'democrat', 2281815, 6154018)
# (496, 1992, 'Utah', 'Bush, George H.W.', 'republican', 322632, 743998)
# (497, 1992, 'Utah', 'Clinton, Bill', 'democrat', 183429, 743998)
# (498, 1992, 'Vermont', 'Clinton, Bill', 'democrat', 133592, 289701)
# (499, 1992, 'Vermont', 'Bush, George H.W.', 'republican', 88122, 289701)
# (500, 1992, 'Virginia', 'Bush, George H.W.', 'republican', 1150517, 2559129)
# (501, 1992, 'Virginia', 'Clinton, Bill', 'democrat', 1038650, 2559129)
# (502, 1992, 'Washington', 'Clinton, Bill', 'democrat', 993037, 2287565)
# (503, 1992, 'Washington', 'Bush, George H.W.', 'republican', 731234, 2287565)
# (504, 1992, 'West Virginia', 'Clinton, Bill', 'democrat', 331001, 683677)
# (505, 1992, 'West Virginia', 'Bush, George H.W.', 'republican', 241974, 683677)
# (506, 1992, 'Wisconsin', 'Clinton, Bill', 'democrat', 1041066, 2531064)
# (507, 1992, 'Wisconsin', 'Bush, George H.W.', 'republican', 930855, 2531064)
# (508, 1992, 'Wyoming', 'Bush, George H.W.', 'republican', 79347, 199884)
# (509, 1992, 'Wyoming', 'Clinton, Bill', 'democrat', 68160, 199884)
# (510, 1996, 'Alabama', 'Dole, Robert', 'republican', 769044, 1534349)
# (511, 1996, 'Alabama', 'Clinton, Bill', 'democrat', 662165, 1534349)
# (512, 1996, 'Alaska', 'Dole, Robert', 'republican', 122746, 241620)
# (513, 1996, 'Alaska', 'Clinton, Bill', 'democrat', 80380, 241620)
# (514, 1996, 'Arizona', 'Clinton, Bill', 'democrat', 653288, 1404405)
# (515, 1996, 'Arizona', 'Dole, Robert', 'republican', 622073, 1404405)
# (516, 1996, 'Arkansas', 'Clinton, Bill', 'democrat', 475171, 884262)
# (517, 1996, 'Arkansas', 'Dole, Robert', 'republican', 325416, 884262)
# (518, 1996, 'California', 'Clinton, Bill', 'democrat', 5119835, 10019469)
# (519, 1996, 'California', 'Dole, Robert', 'republican', 3828381, 10019469)
# (520, 1996, 'Colorado', 'Dole, Robert', 'republican', 691848, 1510702)
# (521, 1996, 'Colorado', 'Clinton, Bill', 'democrat', 671152, 1510702)
# (522, 1996, 'Connecticut', 'Clinton, Bill', 'democrat', 735740, 1392614)
# (523, 1996, 'Connecticut', 'Dole, Robert', 'republican', 483109, 1392614)
# (524, 1996, 'Delaware', 'Clinton, Bill', 'democrat', 140355, 270810)
# (525, 1996, 'Delaware', 'Dole, Robert', 'republican', 99062, 270810)
# (526, 1996, 'District of Columbia', 'Clinton, Bill', 'democrat', 158220, 185726)
# (527, 1996, 'District of Columbia', 'Dole, Robert', 'republican', 17339, 185726)
# (528, 1996, 'Florida', 'Clinton, Bill', 'democrat', 2546870, 5303154)
# (529, 1996, 'Florida', 'Dole, Robert', 'republican', 2244536, 5303154)
# (530, 1996, 'Georgia', 'Dole, Robert', 'republican', 1080843, 2298899)
# (531, 1996, 'Georgia', 'Clinton, Bill', 'democrat', 1053849, 2298899)
# (532, 1996, 'Hawaii', 'Clinton, Bill', 'democrat', 205012, 360120)
# (533, 1996, 'Hawaii', 'Dole, Robert', 'republican', 113943, 360120)
# (534, 1996, 'Idaho', 'Dole, Robert', 'republican', 256595, 491711)
# (535, 1996, 'Idaho', 'Clinton, Bill', 'democrat', 165443, 491711)
# (536, 1996, 'Illinois', 'Clinton, Bill', 'democrat', 2341744, 4311391)
# (537, 1996, 'Illinois', 'Dole, Robert', 'republican', 1587021, 4311391)
# (538, 1996, 'Indiana', 'Dole, Robert', 'republican', 1006693, 2135431)
# (539, 1996, 'Indiana', 'Clinton, Bill', 'democrat', 887424, 2135431)
# (540, 1996, 'Iowa', 'Clinton, Bill', 'democrat', 620258, 1234075)
# (541, 1996, 'Iowa', 'Dole, Robert', 'republican', 492644, 1234075)
# (542, 1996, 'Kansas', 'Dole, Robert', 'republican', 583245, 1074300)
# (543, 1996, 'Kansas', 'Clinton, Bill', 'democrat', 387659, 1074300)
# (544, 1996, 'Kentucky', 'Clinton, Bill', 'democrat', 636614, 1388708)
# (545, 1996, 'Kentucky', 'Dole, Robert', 'republican', 623283, 1388708)
# (546, 1996, 'Louisiana', 'Clinton, Bill', 'democrat', 927837, 1783959)
# (547, 1996, 'Louisiana', 'Dole, Robert', 'republican', 712586, 1783959)
# (548, 1996, 'Maine', 'Clinton, Bill', 'democrat', 312788, 605897)
# (549, 1996, 'Maine', 'Dole, Robert', 'republican', 186378, 605897)
# (550, 1996, 'Maryland', 'Clinton, Bill', 'democrat', 966207, 1780870)
# (551, 1996, 'Maryland', 'Dole, Robert', 'republican', 681530, 1780870)
# (552, 1996, 'Massachusetts', 'Clinton, Bill', 'democrat', 1571509, 2556459)
# (553, 1996, 'Massachusetts', 'Dole, Robert', 'republican', 718058, 2556459)
# (554, 1996, 'Michigan', 'Clinton, Bill', 'democrat', 1989653, 3848844)
# (555, 1996, 'Michigan', 'Dole, Robert', 'republican', 1481212, 3848844)
# (556, 1996, 'Minnesota', 'Clinton, Bill', 'democrat', 1120380, 2192492)
# (557, 1996, 'Minnesota', 'Dole, Robert', 'republican', 766395, 2192492)
# (558, 1996, 'Mississippi', 'Dole, Robert', 'republican', 439838, 893857)
# (559, 1996, 'Mississippi', 'Clinton, Bill', 'democrat', 394022, 893857)
# (560, 1996, 'Missouri', 'Clinton, Bill', 'democrat', 1025935, 2158065)
# (561, 1996, 'Missouri', 'Dole, Robert', 'republican', 890016, 2158065)
# (562, 1996, 'Montana', 'Dole, Robert', 'republican', 179652, 407083)
# (563, 1996, 'Montana', 'Clinton, Bill', 'democrat', 167922, 407083)
# (564, 1996, 'Nebraska', 'Dole, Robert', 'republican', 363467, 677415)
# (565, 1996, 'Nebraska', 'Clinton, Bill', 'democrat', 236761, 677415)
# (566, 1996, 'Nevada', 'Clinton, Bill', 'democrat', 203974, 464279)
# (567, 1996, 'Nevada', 'Dole, Robert', 'republican', 199244, 464279)
# (568, 1996, 'New Hampshire', 'Clinton, Bill', 'democrat', 246166, 496597)
# (569, 1996, 'New Hampshire', 'Dole, Robert', 'republican', 196486, 496597)
# (570, 1996, 'New Jersey', 'Clinton, Bill', 'democrat', 1652361, 3075860)
# (571, 1996, 'New Jersey', 'Dole, Robert', 'republican', 1103099, 3075860)
# (572, 1996, 'New Mexico', 'Clinton, Bill', 'democrat', 273495, 556074)
# (573, 1996, 'New Mexico', 'Dole, Robert', 'republican', 232751, 556074)
# (574, 1996, 'New York', 'Clinton, Bill', 'democrat', 3649630, 6439129)
# (575, 1996, 'New York', 'Dole, Robert', 'republican', 1738707, 6439129)
# (576, 1996, 'North Carolina', 'Dole, Robert', 'republican', 1225938, 2515807)
# (577, 1996, 'North Carolina', 'Clinton, Bill', 'democrat', 1107849, 2515807)
# (578, 1996, 'North Dakota', 'Dole, Robert', 'republican', 125050, 266411)
# (579, 1996, 'North Dakota', 'Clinton, Bill', 'democrat', 106905, 266411)
# (580, 1996, 'Ohio', 'Clinton, Bill', 'democrat', 2148222, 4534434)
# (581, 1996, 'Ohio', 'Dole, Robert', 'republican', 1859883, 4534434)
# (582, 1996, 'Oklahoma', 'Dole, Robert', 'republican', 582315, 1206713)
# (583, 1996, 'Oklahoma', 'Clinton, Bill', 'democrat', 488105, 1206713)
# (584, 1996, 'Oregon', 'Clinton, Bill', 'democrat', 649641, 1377760)
# (585, 1996, 'Oregon', 'Dole, Robert', 'republican', 538152, 1377760)
# (586, 1996, 'Pennsylvania', 'Clinton, Bill', 'democrat', 2215819, 4501307)
# (587, 1996, 'Pennsylvania', 'Dole, Robert', 'republican', 1801169, 4501307)
# (588, 1996, 'Rhode Island', 'Clinton, Bill', 'democrat', 233050, 390247)
# (589, 1996, 'Rhode Island', 'Dole, Robert', 'republican', 104683, 390247)
# (590, 1996, 'South Carolina', 'Dole, Robert', 'republican', 573339, 1150182)
# (591, 1996, 'South Carolina', 'Clinton, Bill', 'democrat', 506152, 1150182)
# (592, 1996, 'South Dakota', 'Dole, Robert', 'republican', 150543, 323826)
# (593, 1996, 'South Dakota', 'Clinton, Bill', 'democrat', 139333, 323826)
# (594, 1996, 'Tennessee', 'Clinton, Bill', 'democrat', 909146, 1894105)
# (595, 1996, 'Tennessee', 'Dole, Robert', 'republican', 863530, 1894105)
# (596, 1996, 'Texas', 'Dole, Robert', 'republican', 2736167, 5611644)
# (597, 1996, 'Texas', 'Clinton, Bill', 'democrat', 2459683, 5611644)
# (598, 1996, 'Utah', 'Dole, Robert', 'republican', 361911, 665629)
# (599, 1996, 'Utah', 'Clinton, Bill', 'democrat', 221633, 665629)
# (600, 1996, 'Vermont', 'Clinton, Bill', 'democrat', 137894, 258449)
# (601, 1996, 'Vermont', 'Dole, Robert', 'republican', 80352, 258449)
# (602, 1996, 'Virginia', 'Dole, Robert', 'republican', 1138350, 2416642)
# (603, 1996, 'Virginia', 'Clinton, Bill', 'democrat', 1091060, 2416642)
# (604, 1996, 'Washington', 'Clinton, Bill', 'democrat', 1123323, 2253837)
# (605, 1996, 'Washington', 'Dole, Robert', 'republican', 840712, 2253837)
# (606, 1996, 'West Virginia', 'Clinton, Bill', 'democrat', 327812, 636459)
# (607, 1996, 'West Virginia', 'Dole, Robert', 'republican', 233946, 636459)
# (608, 1996, 'Wisconsin', 'Clinton, Bill', 'democrat', 1071971, 2196169)
# (609, 1996, 'Wisconsin', 'Dole, Robert', 'republican', 845029, 2196169)
# (610, 1996, 'Wyoming', 'Dole, Robert', 'republican', 105388, 211571)
# (611, 1996, 'Wyoming', 'Clinton, Bill', 'democrat', 77934, 211571)
# (612, 2000, 'Alabama', 'Bush, George W.', 'republican', 941173, 1666272)
# (613, 2000, 'Alabama', 'Gore, Al', 'democrat', 692611, 1666272)
# (614, 2000, 'Alaska', 'Bush, George W.', 'republican', 167398, 285560)
# (615, 2000, 'Alaska', 'Gore, Al', 'democrat', 79004, 285560)
# (616, 2000, 'Arizona', 'Bush, George W.', 'republican', 781652, 1532016)
# (617, 2000, 'Arizona', 'Gore, Al', 'democrat', 685341, 1532016)
# (618, 2000, 'Arkansas', 'Bush, George W.', 'republican', 472940, 921781)
# (619, 2000, 'Arkansas', 'Gore, Al', 'democrat', 422768, 921781)
# (620, 2000, 'California', 'Gore, Al', 'democrat', 5861203, 10965822)
# (621, 2000, 'California', 'Bush, George W.', 'republican', 4567429, 10965822)
# (622, 2000, 'Colorado', 'Bush, George W.', 'republican', 883748, 1741368)
# (623, 2000, 'Colorado', 'Gore, Al', 'democrat', 738227, 1741368)
# (624, 2000, 'Connecticut', 'Gore, Al', 'democrat', 816015, 1459525)
# (625, 2000, 'Connecticut', 'Bush, George W.', 'republican', 561094, 1459525)
# (626, 2000, 'Delaware', 'Gore, Al', 'democrat', 180068, 327529)
# (627, 2000, 'Delaware', 'Bush, George W.', 'republican', 137288, 327529)
# (628, 2000, 'District of Columbia', 'Gore, Al', 'democrat', 171923, 201894)
# (629, 2000, 'District of Columbia', 'Bush, George W.', 'republican', 18073, 201894)
# (630, 2000, 'Florida', 'Bush, George W.', 'republican', 2912790, 5963110)
# (631, 2000, 'Florida', 'Gore, Al', 'democrat', 2912253, 5963110)
# (632, 2000, 'Georgia', 'Bush, George W.', 'republican', 1419720, 2583208)
# (633, 2000, 'Georgia', 'Gore, Al', 'democrat', 1116230, 2583208)
# (634, 2000, 'Hawaii', 'Gore, Al', 'democrat', 205286, 367951)
# (635, 2000, 'Hawaii', 'Bush, George W.', 'republican', 137845, 367951)
# (636, 2000, 'Idaho', 'Bush, George W.', 'republican', 336937, 501615)
# (637, 2000, 'Idaho', 'Gore, Al', 'democrat', 138637, 501615)
# (638, 2000, 'Illinois', 'Gore, Al', 'democrat', 2589026, 4742108)
# (639, 2000, 'Illinois', 'Bush, George W.', 'republican', 2019421, 4742108)
# (640, 2000, 'Indiana', 'Bush, George W.', 'republican', 1245836, 2199302)
# (641, 2000, 'Indiana', 'Gore, Al', 'democrat', 901980, 2199302)
# (642, 2000, 'Iowa', 'Gore, Al', 'democrat', 638517, 1353022)
# (643, 2000, 'Iowa', 'Bush, George W.', 'republican', 634373, 1353022)
# (644, 2000, 'Kansas', 'Bush, George W.', 'republican', 622332, 1072216)
# (645, 2000, 'Kansas', 'Gore, Al', 'democrat', 399276, 1072216)
# (646, 2000, 'Kentucky', 'Bush, George W.', 'republican', 872520, 1544106)
# (647, 2000, 'Kentucky', 'Gore, Al', 'democrat', 638923, 1544106)
# (648, 2000, 'Louisiana', 'Bush, George W.', 'republican', 927871, 1765656)
# (649, 2000, 'Louisiana', 'Gore, Al', 'democrat', 792344, 1765656)
# (650, 2000, 'Maine', 'Gore, Al', 'democrat', 319951, 651817)
# (651, 2000, 'Maine', 'Bush, George W.', 'republican', 286616, 651817)
# (652, 2000, 'Maryland', 'Gore, Al', 'democrat', 1144008, 2025212)
# (653, 2000, 'Maryland', 'Bush, George W.', 'republican', 813827, 2025212)
# (654, 2000, 'Massachusetts', 'Gore, Al', 'democrat', 1616487, 2733964)
# (655, 2000, 'Massachusetts', 'Bush, George W.', 'republican', 878502, 2733964)
# (656, 2000, 'Michigan', 'Gore, Al', 'democrat', 2170418, 4232501)
# (657, 2000, 'Michigan', 'Bush, George W.', 'republican', 1953139, 4232501)
# (658, 2000, 'Minnesota', 'Gore, Al', 'democrat', 1168266, 2438685)
# (659, 2000, 'Minnesota', 'Bush, George W.', 'republican', 1109659, 2438685)
# (660, 2000, 'Mississippi', 'Bush, George W.', 'republican', 572844, 994184)
# (661, 2000, 'Mississippi', 'Gore, Al', 'democrat', 404614, 994184)
# (662, 2000, 'Missouri', 'Bush, George W.', 'republican', 1189924, 2359892)
# (663, 2000, 'Missouri', 'Gore, Al', 'democrat', 1111138, 2359892)
# (664, 2000, 'Montana', 'Bush, George W.', 'republican', 240178, 410986)
# ...
# (907, 2008, 'Vermont', 'McCain, John', 'republican', 98974, 325046)
# (908, 2008, 'Virginia', 'Obama, Barack H.', 'democrat', 1959532, 3723260)
# (909, 2008, 'Virginia', 'McCain, John', 'republican', 1725005, 3723260)
# (910, 2008, 'Washington', 'Obama, Barack H.', 'democrat', 1750848, 3036878)
# (911, 2008, 'Washington', 'McCain, John', 'republican', 1229216, 3036878)
# (912, 2008, 'West Virginia', 'McCain, John', 'republican', 397466, 713451)
# (913, 2008, 'West Virginia', 'Obama, Barack H.', 'democrat', 303857, 713451)
# (914, 2008, 'Wisconsin', 'Obama, Barack H.', 'democrat', 1677211, 2983417)
# (915, 2008, 'Wisconsin', 'McCain, John', 'republican', 1262393, 2983417)
# (916, 2008, 'Wyoming', 'McCain, John', 'republican', 164958, 254904)
# (917, 2008, 'Wyoming', 'Obama, Barack H.', 'democrat', 82868, 254904)
# (918, 2012, 'Alabama', 'Romney, Mitt', 'republican', 1255925, 2074338)
# (919, 2012, 'Alabama', 'Obama, Barack H.', 'democrat', 795696, 2074338)
# (920, 2012, 'Alaska', 'Romney, Mitt', 'republican', 164676, 300495)
# (921, 2012, 'Alaska', 'Obama, Barack H.', 'democrat', 122640, 300495)
# (922, 2012, 'Arizona', 'Romney, Mitt', 'republican', 1233654, 2299254)
# (923, 2012, 'Arizona', 'Obama, Barack H.', 'democrat', 1025232, 2299254)
# (924, 2012, 'Arkansas', 'Romney, Mitt', 'republican', 647744, 1069468)
# (925, 2012, 'Arkansas', 'Obama, Barack H.', 'democrat', 394409, 1069468)
# (926, 2012, 'California', 'Obama, Barack H.', 'democrat', 7854285, 13038547)
# (927, 2012, 'California', 'Romney, Mitt', 'republican', 4839958, 13038547)
# (928, 2012, 'Colorado', 'Obama, Barack H.', 'democrat', 1323101, 2569516)
# (929, 2012, 'Colorado', 'Romney, Mitt', 'republican', 1185243, 2569516)
# (930, 2012, 'Connecticut', 'Obama, Barack H.', 'democrat', 905083, 1558204)
# (931, 2012, 'Connecticut', 'Romney, Mitt', 'republican', 634892, 1558204)
# (932, 2012, 'Delaware', 'Obama, Barack H.', 'democrat', 242584, 413890)
# (933, 2012, 'Delaware', 'Romney, Mitt', 'republican', 165484, 413890)
# (934, 2012, 'District of Columbia', 'Obama, Barack H.', 'democrat', 267070, 293764)
# (935, 2012, 'District of Columbia', 'Romney, Mitt', 'republican', 21381, 293764)
# (936, 2012, 'Florida', 'Obama, Barack H.', 'democrat', 4237756, 8474179)
# (937, 2012, 'Florida', 'Romney, Mitt', 'republican', 4163447, 8474179)
# (938, 2012, 'Georgia', 'Romney, Mitt', 'republican', 2078688, 3897839)
# (939, 2012, 'Georgia', 'Obama, Barack H.', 'democrat', 1773827, 3897839)
# (940, 2012, 'Hawaii', 'Obama, Barack H.', 'democrat', 306658, 437159)
# (941, 2012, 'Hawaii', 'Romney, Mitt', 'republican', 121015, 437159)
# (942, 2012, 'Idaho', 'Romney, Mitt', 'republican', 420911, 652274)
# (943, 2012, 'Idaho', 'Obama, Barack H.', 'democrat', 212787, 652274)
# (944, 2012, 'Illinois', 'Obama, Barack H.', 'democrat', 3019512, 5242014)
# (945, 2012, 'Illinois', 'Romney, Mitt', 'republican', 2135216, 5242014)
# (946, 2012, 'Indiana', 'Romney, Mitt', 'republican', 1420543, 2624534)
# (947, 2012, 'Indiana', 'Obama, Barack H.', 'democrat', 1152887, 2624534)
# (948, 2012, 'Iowa', 'Obama, Barack H.', 'democrat', 822544, 1582180)
# (949, 2012, 'Iowa', 'Romney, Mitt', 'republican', 730617, 1582180)
# (950, 2012, 'Kansas', 'Romney, Mitt', 'republican', 692634, 1159971)
# (951, 2012, 'Kansas', 'Obama, Barack H.', 'democrat', 440726, 1159971)
# (952, 2012, 'Kentucky', 'Romney, Mitt', 'republican', 1087190, 1797212)
# (953, 2012, 'Kentucky', 'Obama, Barack H.', 'democrat', 679370, 1797212)
# (954, 2012, 'Louisiana', 'Romney, Mitt', 'republican', 1152262, 1994065)
# (955, 2012, 'Louisiana', 'Obama, Barack H.', 'democrat', 809141, 1994065)
# (956, 2012, 'Maine', 'Obama, Barack H.', 'democrat', 401306, 724758)
# (957, 2012, 'Maine', 'Romney, Mitt', 'republican', 292276, 724758)
# (958, 2012, 'Maryland', 'Obama, Barack H.', 'democrat', 1677844, 2707327)
# (959, 2012, 'Maryland', 'Romney, Mitt', 'republican', 971869, 2707327)
# (960, 2012, 'Massachusetts', 'Obama, Barack H.', 'democrat', 1921290, 3184196)
# (961, 2012, 'Massachusetts', 'Romney, Mitt', 'republican', 1188314, 3184196)
# (962, 2012, 'Michigan', 'Obama, Barack H.', 'democrat', 2564569, 4730961)
# (963, 2012, 'Michigan', 'Romney, Mitt', 'republican', 2115256, 4730961)
# (964, 2012, 'Minnesota', 'Obama, Barack H.', 'democrat', 1546167, 2936561)
# (965, 2012, 'Minnesota', 'Romney, Mitt', 'republican', 1320225, 2936561)
# (966, 2012, 'Mississippi', 'Romney, Mitt', 'republican', 710746, 1285584)
# (967, 2012, 'Mississippi', 'Obama, Barack H.', 'democrat', 562949, 1285584)
# (968, 2012, 'Missouri', 'Romney, Mitt', 'republican', 1482440, 2757323)
# (969, 2012, 'Missouri', 'Obama, Barack H.', 'democrat', 1223796, 2757323)
# (970, 2012, 'Montana', 'Romney, Mitt', 'republican', 267928, 484048)
# (971, 2012, 'Montana', 'Obama, Barack H.', 'democrat', 201839, 484048)
# (972, 2012, 'Nebraska', 'Romney, Mitt', 'republican', 475064, 794379)
# (973, 2012, 'Nebraska', 'Obama, Barack H.', 'democrat', 302081, 794379)
# (974, 2012, 'Nevada', 'Obama, Barack H.', 'democrat', 531373, 1014918)
# (975, 2012, 'Nevada', 'Romney, Mitt', 'republican', 463567, 1014918)
# (976, 2012, 'New Hampshire', 'Obama, Barack H.', 'democrat', 369561, 710972)
# (977, 2012, 'New Hampshire', 'Romney, Mitt', 'republican', 329918, 710972)
# (978, 2012, 'New Jersey', 'Obama, Barack H.', 'democrat', 2122786, 3638499)
# (979, 2012, 'New Jersey', 'Romney, Mitt', 'republican', 1478088, 3638499)
# (980, 2012, 'New Mexico', 'Obama, Barack H.', 'democrat', 415335, 783758)
# (981, 2012, 'New Mexico', 'Romney, Mitt', 'republican', 335788, 783758)
# (982, 2012, 'New York', 'Obama, Barack H.', 'democrat', 4324228, 7116784)
# (983, 2012, 'New York', 'Romney, Mitt', 'republican', 2223397, 7116784)
# (984, 2012, 'North Carolina', 'Romney, Mitt', 'republican', 2270395, 4505372)
# (985, 2012, 'North Carolina', 'Obama, Barack H.', 'democrat', 2178391, 4505372)
# (986, 2012, 'North Dakota', 'Romney, Mitt', 'republican', 188320, 322932)
# (987, 2012, 'North Dakota', 'Obama, Barack H.', 'democrat', 124966, 322932)
# (988, 2012, 'Ohio', 'Obama, Barack H.', 'democrat', 2827621, 5580822)
# (989, 2012, 'Ohio', 'Romney, Mitt', 'republican', 2661407, 5580822)
# (990, 2012, 'Oklahoma', 'Romney, Mitt', 'republican', 891325, 1334872)
# (991, 2012, 'Oklahoma', 'Obama, Barack H.', 'democrat', 443547, 1334872)
# (992, 2012, 'Oregon', 'Obama, Barack H.', 'democrat', 970488, 1789270)
# (993, 2012, 'Oregon', 'Romney, Mitt', 'republican', 754175, 1789270)
# (994, 2012, 'Pennsylvania', 'Obama, Barack H.', 'democrat', 2990274, 5742040)
# (995, 2012, 'Pennsylvania', 'Romney, Mitt', 'republican', 2680434, 5742040)
# (996, 2012, 'Rhode Island', 'Obama, Barack H.', 'democrat', 279677, 446049)
# (997, 2012, 'Rhode Island', 'Romney, Mitt', 'republican', 157204, 446049)
# (998, 2012, 'South Carolina', 'Romney, Mitt', 'republican', 1071645, 1964118)
# (999, 2012, 'South Carolina', 'Obama, Barack H.', 'democrat', 865941, 1964118)
# (1000, 2012, 'South Dakota', 'Romney, Mitt', 'republican', 210610, 363815)
# (1001, 2012, 'South Dakota', 'Obama, Barack H.', 'democrat', 145039, 363815)
# (1002, 2012, 'Tennessee', 'Romney, Mitt', 'republican', 1462330, 2458577)
# (1003, 2012, 'Tennessee', 'Obama, Barack H.', 'democrat', 960709, 2458577)
# (1004, 2012, 'Texas', 'Romney, Mitt', 'republican', 4569843, 7993851)
# (1005, 2012, 'Texas', 'Obama, Barack H.', 'democrat', 3308124, 7993851)
# (1006, 2012, 'Utah', 'Romney, Mitt', 'republican', 740600, 1017440)
# (1007, 2012, 'Utah', 'Obama, Barack H.', 'democrat', 251813, 1017440)
# (1008, 2012, 'Vermont', 'Obama, Barack H.', 'democrat', 199239, 299290)
# (1009, 2012, 'Vermont', 'Romney, Mitt', 'republican', 92698, 299290)
# (1010, 2012, 'Virginia', 'Obama, Barack H.', 'democrat', 1971820, 3854489)
# (1011, 2012, 'Virginia', 'Romney, Mitt', 'republican', 1822522, 3854489)
# (1012, 2012, 'Washington', 'Obama, Barack H.', 'democrat', 1755396, 3125516)
# (1013, 2012, 'Washington', 'Mitt, Romney', 'republican', 1290670, 3125516)
# (1014, 2012, 'West Virginia', 'Romney, Mitt', 'republican', 417655, 670438)
# (1015, 2012, 'West Virginia', 'Obama, Barack H.', 'democrat', 238269, 670438)
# (1016, 2012, 'Wisconsin', 'Obama, Barack H.', 'democrat', 1620985, 3071434)
# (1017, 2012, 'Wisconsin', 'Romney, Mitt', 'republican', 1410966, 3071434)
# (1018, 2012, 'Wyoming', 'Romney, Mitt', 'republican', 170962, 250701)
# (1019, 2012, 'Wyoming', 'Obama, Barack H.', 'democrat', 69286, 250701)
# (1020, 2016, 'Alabama', 'Trump, Donald J.', 'republican', 1318255, 2123372)
# (1021, 2016, 'Alabama', 'Clinton, Hillary', 'democrat', 729547, 2123372)
# (1022, 2016, 'Alaska', 'Trump, Donald J.', 'republican', 163387, 318608)
# (1023, 2016, 'Alaska', 'Clinton, Hillary', 'democrat', 116454, 318608)
# (1024, 2016, 'Arizona', 'Trump, Donald J.', 'republican', 1252401, 2573165)
# (1025, 2016, 'Arizona', 'Clinton, Hillary', 'democrat', 1161167, 2573165)
# (1026, 2016, 'Arkansas', 'Trump, Donald J.', 'republican', 684872, 1130635)
# (1027, 2016, 'Arkansas', 'Clinton, Hillary', 'democrat', 380494, 1130635)
# (1028, 2016, 'California', 'Clinton, Hillary', 'democrat', 8753788, 14181595)
# (1029, 2016, 'California', 'Trump, Donald J.', 'republican', 4483810, 14181595)
# (1030, 2016, 'Colorado', 'Clinton, Hillary', 'democrat', 1338870, 2780220)
# (1031, 2016, 'Colorado', 'Trump, Donald J.', 'republican', 1202484, 2780220)
# (1032, 2016, 'Connecticut', 'Clinton, Hillary', 'democrat', 897572, 1644920)
# (1033, 2016, 'Connecticut', 'Trump, Donald J.', 'republican', 673215, 1644920)
# (1034, 2016, 'Delaware', 'Clinton, Hillary', 'democrat', 235603, 441590)
# (1035, 2016, 'Delaware', 'Trump, Donald J.', 'republican', 185127, 441590)
# (1036, 2016, 'District of Columbia', 'Clinton, Hillary', 'democrat', 282830, 312575)
# (1037, 2016, 'District of Columbia', 'Trump, Donald J.', 'republican', 12723, 312575)
# (1038, 2016, 'Florida', 'Trump, Donald J.', 'republican', 4617886, 9420039)
# (1039, 2016, 'Florida', 'Clinton, Hillary', 'democrat', 4504975, 9420039)
# (1040, 2016, 'Georgia', 'Trump, Donald J.', 'republican', 2089104, 4114732)
# (1041, 2016, 'Georgia', 'Clinton, Hillary', 'democrat', 1877963, 4114732)
# (1042, 2016, 'Hawaii', 'Clinton, Hillary', 'democrat', 266891, 437664)
# (1043, 2016, 'Hawaii', 'Trump, Donald J.', 'republican', 128847, 437664)
# (1044, 2016, 'Idaho', 'Trump, Donald J.', 'republican', 409055, 690255)
# (1045, 2016, 'Idaho', 'Clinton, Hillary', 'democrat', 189765, 690255)
# (1046, 2016, 'Illinois', 'Clinton, Hillary', 'democrat', 3090729, 5536424)
# (1047, 2016, 'Illinois', 'Trump, Donald J.', 'republican', 2146015, 5536424)
# (1048, 2016, 'Indiana', 'Trump, Donald J.', 'republican', 1557286, 2734958)
# (1049, 2016, 'Indiana', 'Clinton, Hillary', 'democrat', 1033126, 2734958)
# (1050, 2016, 'Iowa', 'Trump, Donald J.', 'republican', 800983, 1565580)
# (1051, 2016, 'Iowa', 'Clinton, Hillary', 'democrat', 653669, 1565580)
# (1052, 2016, 'Kansas', 'Trump, Donald J.', 'republican', 671018, 1184402)
# (1053, 2016, 'Kansas', 'Clinton, Hillary', 'democrat', 427005, 1184402)
# (1054, 2016, 'Kentucky', 'Trump, Donald J.', 'republican', 1202971, 1924149)
# (1055, 2016, 'Kentucky', 'Clinton, Hillary', 'democrat', 628854, 1924149)
# (1056, 2016, 'Louisiana', 'Trump, Donald J.', 'republican', 1178638, 2029032)
# (1057, 2016, 'Louisiana', 'Clinton, Hillary', 'democrat', 780154, 2029032)
# (1058, 2016, 'Maine', 'Clinton, Hillary', 'democrat', 357735, 771892)
# (1059, 2016, 'Maine', 'Trump, Donald J.', 'republican', 335593, 771892)
# (1060, 2016, 'Maryland', 'Clinton, Hillary', 'democrat', 1677928, 2781446)
# (1061, 2016, 'Maryland', 'Trump, Donald J.', 'republican', 943169, 2781446)
# (1062, 2016, 'Massachusetts', 'Clinton, Hillary', 'democrat', 1995196, 3378821)
# (1063, 2016, 'Massachusetts', 'Trump, Donald J.', 'republican', 1090893, 3378821)
# (1064, 2016, 'Michigan', 'Trump, Donald J.', 'republican', 2279543, 4799284)
# (1065, 2016, 'Michigan', 'Clinton, Hillary', 'democrat', 2268839, 4799284)
# (1066, 2016, 'Minnesota', 'Clinton, Hillary', 'democrat', 1367705, 2944782)
# (1067, 2016, 'Minnesota', 'Trump, Donald J.', 'republican', 1322949, 2944782)
# (1068, 2016, 'Mississippi', 'Trump, Donald J.', 'republican', 700714, 1209357)
# (1069, 2016, 'Mississippi', 'Clinton, Hillary', 'democrat', 485131, 1209357)
# (1070, 2016, 'Missouri', 'Trump, Donald J.', 'republican', 1594511, 2808605)
# (1071, 2016, 'Missouri', 'Clinton, Hillary', 'democrat', 1071068, 2808605)
# (1072, 2016, 'Montana', 'Trump, Donald J.', 'republican', 279240, 494526)
# (1073, 2016, 'Montana', 'Clinton, Hillary', 'democrat', 177709, 494526)
# (1074, 2016, 'Nebraska', 'Trump, Donald J.', 'republican', 495961, 844227)
# (1075, 2016, 'Nebraska', 'Clinton, Hillary', 'democrat', 284494, 844227)
# (1076, 2016, 'Nevada', 'Clinton, Hillary', 'democrat', 539260, 1125385)
# (1077, 2016, 'Nevada', 'Trump, Donald J.', 'republican', 512058, 1125385)
# (1078, 2016, 'New Hampshire', 'Clinton, Hillary', 'democrat', 348526, 744296)
# (1079, 2016, 'New Hampshire', 'Trump, Donald J.', 'republican', 345790, 744296)
# (1080, 2016, 'New Jersey', 'Clinton, Hillary', 'democrat', 2148278, 3874046)
# (1081, 2016, 'New Jersey', 'Trump, Donald J.', 'republican', 1601933, 3874046)
# (1082, 2016, 'New Mexico', 'Clinton, Hillary', 'democrat', 385234, 798319)
# (1083, 2016, 'New Mexico', 'Trump, Donald J.', 'republican', 319667, 798319)
# (1084, 2016, 'New York', 'Clinton, Hillary', 'democrat', 4379789, 7802084)
# (1085, 2016, 'New York', 'Trump, Donald J.', 'republican', 2527142, 7802084)
# (1086, 2016, 'North Carolina', 'Trump, Donald J.', 'republican', 2362631, 4741564)
# (1087, 2016, 'North Carolina', 'Clinton, Hillary', 'democrat', 2189316, 4741564)
# (1088, 2016, 'North Dakota', 'Trump, Donald J.', 'republican', 216794, 344360)
# (1089, 2016, 'North Dakota', 'Clinton, Hillary', 'democrat', 93758, 344360)
# (1090, 2016, 'Ohio', 'Trump, Donald J.', 'republican', 2841005, 5496487)
# (1091, 2016, 'Ohio', 'Clinton, Hillary', 'democrat', 2394164, 5496487)
# (1092, 2016, 'Oklahoma', 'Trump, Donald J.', 'republican', 949136, 1452992)
# (1093, 2016, 'Oklahoma', 'Clinton, Hillary', 'democrat', 420375, 1452992)
# (1094, 2016, 'Oregon', 'Clinton, Hillary', 'democrat', 1002106, 2001336)
# (1095, 2016, 'Oregon', 'Trump, Donald J.', 'republican', 782403, 2001336)
# (1096, 2016, 'Pennsylvania', 'Trump, Donald J.', 'republican', 2970733, 6115402)
# (1097, 2016, 'Pennsylvania', 'Clinton, Hillary', 'democrat', 2926441, 6115402)
# (1098, 2016, 'Rhode Island', 'Clinton, Hillary', 'democrat', 252525, 464144)
# (1099, 2016, 'Rhode Island', 'Trump, Donald J.', 'republican', 180543, 464144)
# (1100, 2016, 'South Carolina', 'Trump, Donald J.', 'republican', 1155389, 2103027)
# (1101, 2016, 'South Carolina', 'Clinton, Hillary', 'democrat', 855373, 2103027)
# (1102, 2016, 'South Dakota', 'Trump, Donald J.', 'republican', 227721, 370093)
# (1103, 2016, 'South Dakota', 'Clinton, Hillary', 'democrat', 117458, 370093)
# (1104, 2016, 'Tennessee', 'Trump, Donald J.', 'republican', 1522925, 2508027)
# (1105, 2016, 'Tennessee', 'Clinton, Hillary', 'democrat', 870695, 2508027)
# (1106, 2016, 'Texas', 'Trump, Donald J.', 'republican', 4685047, 8969226)
# (1107, 2016, 'Texas', 'Clinton, Hillary', 'democrat', 3877868, 8969226)
# (1108, 2016, 'Utah', 'Trump, Donald J.', 'republican', 515211, 1131317)
# (1109, 2016, 'Utah', 'Clinton, Hillary', 'democrat', 310674, 1131317)
# (1110, 2016, 'Vermont', 'Clinton, Hillary', 'democrat', 178573, 320467)
# (1111, 2016, 'Vermont', 'Trump, Donald J.', 'republican', 95369, 320467)
# (1112, 2016, 'Virginia', 'Clinton, Hillary', 'democrat', 1981473, 3982752)
# (1113, 2016, 'Virginia', 'Trump, Donald J.', 'republican', 1769443, 3982752)
# (1114, 2016, 'Washington', 'Clinton, Hillary', 'democrat', 1742718, 3317019)
# (1115, 2016, 'Washington', 'Trump, Donald J.', 'republican', 1221747, 3317019)
# (1116, 2016, 'West Virginia', 'Trump, Donald J.', 'republican', 489371, 713051)
# (1117, 2016, 'West Virginia', 'Clinton, Hillary', 'democrat', 188794, 713051)
# (1118, 2016, 'Wisconsin', 'Trump, Donald J.', 'republican', 1405284, 2976150)
# (1119, 2016, 'Wisconsin', 'Clinton, Hillary', 'democrat', 1382536, 2976150)
# (1120, 2016, 'Wyoming', 'Trump, Donald J.', 'republican', 174419, 258788)
# (1121, 2016, 'Wyoming', 'Clinton, Hillary', 'democrat', 55973, 258788)

# %%
c.close()
conn.close()
