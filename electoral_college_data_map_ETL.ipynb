# %% [markdown]
# # Electoral College Data ETL

# %% [markdown]
# The purpose of this project is to analyze the how the electoral college votes were distributed after the 2010 census, look at how the redistribution of population (by estimate) has shifted over time until today, and what that means for the voter per electoral college vote in each state. I will also analyze how we expect the electoral college to be redistributed after the 2020 census, given census bureau predictions.
#
# An analysis will also be performed on the percentage likelihood of each state giving its electoral college votes to a particular party and their respective nominees, based purely on historical data. The aim is to demonstrate which states have the greatest power per vote, given both their current electoral votes allotted and the likelihood of that state assigning thier votes to either party candidate.

# %% [markdown]
# ## Import

# %%
#import necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
import json

from bs4 import BeautifulSoup
import re

import sqlite3
# %matplotlib inline

# %% [markdown]
# ## Support Functions

# %%
#define how to retrieve api keys

def get_keys(path):
    """
    Pulls necessary api keys from designated path
    """
    with open(path) as f:
        return json.load(f)

# %%
def reciprocal_geometric_mean(next_house_seat):
    """
    Calculates the reciprocal geometric mean for the next house seat a state could potentially receive
    """
    return 1 / np.sqrt(next_house_seat*(next_house_seat-1))

# %%
def priority_value(state_pop, next_house_seat):
    """
    Calculates the priority value a state has for receiving another house seat.
    The highest priority value state gets the next house seat available.
    """
    return int(round(state_pop * reciprocal_geometric_mean(next_house_seat), 0))

# %%
def state_status_scrape(state_start):
    """
    From a beautiful soup webscrape, takes the tag just prior to the first state with NPVIC information
    and iterates through all siblings to make and return a dictionary of all states and their NPVIC status
    """
    state_npvic_status = {}
    for p in state_start.find_next_siblings():
        if p.contents == [] or p.contents == ['\xa0']:
            break

        soup_state_status = p.get_text().replace('\xa0', ' ')
        if '-' not in soup_state_status:
            state = soup_state_status
            status = ''
        else:
            dash_index = soup_state_status.index('-')
            state = soup_state_status[:dash_index-1]
            status = soup_state_status[dash_index+2:]

        state_npvic_status.update({state: status})
        
    return state_npvic_status

# %%
def state_status_to_numerical(state_npvic_status):
    """
    Takes all phrases from dictionary and assigns a value for how close the state is to joining the NPVIC
    Joined (passed legislature and signed by governor): 1.0
    Passed by one or two branches of state legislature: 0.5
    Approved by house committee:                        0.25
    States with no movement:                            0
    
    """
    for state in state_npvic_status.keys():
        if 'Enacted into law' in state_npvic_status[state]:
            state_npvic_status[state] = 1.0
        elif 'Passed' in state_npvic_status[state]:
            state_npvic_status[state] = 0.5
        elif 'approved' in state_npvic_status[state]:
            state_npvic_status[state] = 0.25
        else:
            state_npvic_status[state] = 0

    return state_npvic_status

# %%
def sql_table_creation(connection, cursor, table_name, *argv):
    """
    Passing in the connection to the SQL database, the cursor, the proposed table name, and any number of
    sequential arguments for columns of the table and associated data types, either create a new table with
    said information, or if the table already exists, drop the existing table, and create it newly.
    
    """
    var_string = argv[0]
    var_list = argv[0].split(' ')[0]
    for arg in argv[1:]:
        var_string += ', ' + arg
        var_list += ', ' + arg.split(' ')[0]
        
    try:
        c.execute('CREATE TABLE {} ({})'.format(table_name, var_string))
        conn.commit()
        print('{} Table created ({})'.format(table_name, var_list))
    except:
        c.execute('DROP TABLE {}'.format(table_name))
        print('{} table dropped'.format(table_name))
        c.execute('CREATE TABLE {} ({})'.format(table_name, var_string))
        conn.commit()
        print('{} table created ({})'.format(table_name, var_list))

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### API Request

# %% [markdown]
# Retrieve my personal API key for querying the Census Bureau.

# %%
#get key for census bureau api
key_path = "/Users/flatironschool/.secret/census_api.json"
keys = get_keys(key_path)

api_key = keys['api_key']

# %% [markdown]
# After a ton of research into the Census Bureau API and the information available, I found the right link, the right variables, and the right order for the parameters to send for the information I needed.

# %%
#make and print request for census count and estimates from 2010-2019 for all states
year = '2019'

url = 'https://api.census.gov/data/{}/pep/population'.format(year)

variables = ['DATE_CODE', 'DATE_DESC', 'POP', 'NAME']

granularity = 'state:*'

params = {'get': ','.join(variables), 'for': granularity, 'key': api_key}

r = requests.get(url, params=params)
print(r.url)
print(r)
print(r.text[:1000])
# Out:
# https://api.census.gov/data/2019/pep/population?get=DATE_CODE%2CDATE_DESC%2CPOP%2CNAME&for=state%3A%2A&key=b7961d22ec04ff1777be8a0450921d3f28af8315
# <Response [200]>
# [["DATE_CODE","DATE_DESC","POP","NAME","state"],
# ["1","4/1/2010 Census population","5303925","Minnesota","27"],
# ["2","4/1/2010 population estimates base","5303927","Minnesota","27"],
# ["3","7/1/2010 population estimate","5310828","Minnesota","27"],
# ["4","7/1/2011 population estimate","5346143","Minnesota","27"],
# ["5","7/1/2012 population estimate","5376643","Minnesota","27"],
# ["6","7/1/2013 population estimate","5413479","Minnesota","27"],
# ["7","7/1/2014 population estimate","5451079","Minnesota","27"],
# ["8","7/1/2015 population estimate","5482032","Minnesota","27"],
# ["9","7/1/2016 population estimate","5522744","Minnesota","27"],
# ["10","7/1/2017 population estimate","5566230","Minnesota","27"],
# ["11","7/1/2018 population estimate","5606249","Minnesota","27"],
# ["12","7/1/2019 population estimate","5639632","Minnesota","27"],
# ["1","4/1/2010 Census population","2967297","Mississippi","28"],
# ["2","4/1/2010 population estimates base","2968130","Mississippi","28"],
# ["3","7/1/2010 population

# %%
#take the api response, turn it into a json, then parse that json into a pandas dataframe
data = r.json()
pop_df = pd.DataFrame(data[1:], columns=data[0])

#cut down the date column to just the year
pop_df['YEAR'] = pop_df.DATE_DESC.apply(lambda x: x[4:8])

#eliminate the census population estimate for the same year it was recorded and the July date of that same year
pop_df.drop(pop_df[(pop_df.DATE_CODE == '2') | (pop_df.DATE_CODE == '3')].index, inplace=True)

#drop unnecessary columns and reset the index
pop_df.drop(['state','DATE_CODE', 'DATE_DESC'], axis=1, inplace=True)
pop_df.reset_index(drop=True, inplace=True)

#set the population to an integer val, reorder and rename the columns
pop_df['POP'] = pop_df.POP.astype('int64')
pop_df = pop_df[['YEAR', 'NAME', 'POP']]
pop_df.columns = ['Year', 'State', 'Pop']

display(pop_df.head(15))
display(pop_df.info())
# Out:
#     Year        State      Pop
# 0   2010    Minnesota  5303925
# 1   2011    Minnesota  5346143
# 2   2012    Minnesota  5376643
# 3   2013    Minnesota  5413479
# 4   2014    Minnesota  5451079
# 5   2015    Minnesota  5482032
# 6   2016    Minnesota  5522744
# 7   2017    Minnesota  5566230
# 8   2018    Minnesota  5606249
# 9   2019    Minnesota  5639632
# 10  2010  Mississippi  2967297
# 11  2011  Mississippi  2978731
# 12  2012  Mississippi  2983816
# 13  2013  Mississippi  2988711
# 14  2014  Mississippi  2990468
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 3 columns):
# Year     520 non-null object
# State    520 non-null object
# Pop      520 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 12.3+ KB
# None

# %% [markdown]
# So we finally end up with the information needed, actual census data from 2010, and the estimates the Census Bureau has made about the population since the last official census. What these numbers don't include though (and is crucial when calculating who gets how many electoral votes) are the number of citizens of these states overseas. Let's get that data next.

# %% [markdown]
# ### Overseas Population Import

# %% [markdown]
# Sadly, I couldn't find this info through the API, and had to direct download the csv from the Census Bureau.

# %%
overseas_df = pd.read_excel('Overseas Population 2010.xls', skiprows=7)
overseas_df.dropna(inplace=True)
overseas_df.columns = ['State', 'Overseas_pop']
overseas_df['Year'] = '2010'
overseas_df['Overseas_pop'] = overseas_df['Overseas_pop'].astype('int64')
overseas_df.reset_index(drop=True, inplace=True)

display(overseas_df.head())
display(overseas_df.info())
# Out:
#         State  Overseas_pop  Year
# 0     Alabama         23246  2010
# 1      Alaska         11292  2010
# 2     Arizona         20683  2010
# 3    Arkansas         10311  2010
# 4  California         88033  2010
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State           52 non-null object
# Overseas_pop    52 non-null int64
# Year            52 non-null object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB
# None

# %% [markdown]
# This data is only for the year the 2010 census was completed, but where are the estimates? After some digging, I found a court filing where the process of calculating estimates for overseas population per state was discussed, but the Census Bureau said effectively that to survey overseas populations for estimation purposes was too costly and too time intensive (read: we don't have a big enough budget for that). While they would continue to measure the overseas population during the actual Census, there is no produced data for overseas estimates.

# %% [markdown]
# So, let's make it instead! As my real focus is on the electoral college, which is based on the total population (measured population in the US + Overseas population) I need something to predict what the 2020 electoral college will look like. Since 2010, a number of our troops have come home from the Middle East, but the movement of populations in and out of states shouldn't be affected by troops coming home or other reasons state residents are abroad. Soldiers and other ex-pats are just as likely to move to another state when coming home as the next individual. I therefore was comfortable interpolating the overseas population for 2011 - 2019 such that its growth or decline matched the movement of the non-overseas population from year to year.
#
# I calculate the percent change in the non-overseas population from year to year for each state, and adjust the overseas population by that same percentage.

# %%
#merge the overseas data with the main population estimates table and extrapolate overseas estimates based on 
#percentage change in the population year over year

#merge the population estimates with overseas data on State and Year
merged_df = pop_df.merge(overseas_df, how='left', on=['State','Year'])

#create our Percent change in population column
merged_df['Percent_change'] = (merged_df.Pop - merged_df.Pop.shift(1)) / merged_df.Pop.shift(1)

#iterate through the missing data in overseas population, calculating the next missing value from the previous known
#(from the 2010 census) or from the last calculated value based on percentage change in that state
for i in range(len(merged_df)):
    if pd.isna(merged_df.iloc[i]['Overseas_pop']):
        merged_df.at[i,'Overseas_pop'] = round(merged_df.iloc[i]['Percent_change'] * \
                                               merged_df.iloc[i-1]['Overseas_pop'] + \
                                               merged_df.iloc[i-1]['Overseas_pop'], 0)
        
merged_df.drop('Percent_change', axis=1, inplace=True)        
merged_df['Overseas_pop'] = merged_df.Overseas_pop.astype('int64')
merged_df['Year'] = merged_df.Year.astype('int64')

display(merged_df.head(25))
display(merged_df.info())
# Out:
#     Year        State      Pop  Overseas_pop
# 0   2010    Minnesota  5303925         10954
# 1   2011    Minnesota  5346143         11041
# 2   2012    Minnesota  5376643         11104
# 3   2013    Minnesota  5413479         11180
# 4   2014    Minnesota  5451079         11258
# 5   2015    Minnesota  5482032         11322
# 6   2016    Minnesota  5522744         11406
# 7   2017    Minnesota  5566230         11496
# 8   2018    Minnesota  5606249         11579
# 9   2019    Minnesota  5639632         11648
# 10  2010  Mississippi  2967297         10943
# 11  2011  Mississippi  2978731         10985
# 12  2012  Mississippi  2983816         11004
# 13  2013  Mississippi  2988711         11022
# 14  2014  Mississippi  2990468         11028
# 15  2015  Mississippi  2988471         11021
# 16  2016  Mississippi  2987938         11019
# 17  2017  Mississippi  2988510         11021
# 18  2018  Mississippi  2981020         10993
# 19  2019  Mississippi  2976149         10975
# 20  2010     Missouri  5988927         22551
# 21  2011     Missouri  6010275         22631
# 22  2012     Missouri  6024367         22684
# 23  2013     Missouri  6040715         22746
# 24  2014     Missouri  6056202         22804
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 520 entries, 0 to 519
# Data columns (total 4 columns):
# Year            520 non-null int64
# State           520 non-null object
# Pop             520 non-null int64
# Overseas_pop    520 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 40.3+ KB
# None

# %% [markdown]
# ### Scraping National Popular Vote Interstate Compact State Status

# %% [markdown]
# The thing that could upend this whole electoral college institution is the NPVIC, which goes into effect once the states who have ratified it have enough electoral votes to add up to 270. Every state who has signed says they will give all their electoral votes to whomever wins the popular vote NATIONWIDE, not just who wins the popular vote in their particular state (it has some pretty solid footing for being legitimate by the constitution). I want to look at how close we actually are to implementing this, if it's even a reality. I found a website that updates as states move forward in their ratification of the NPVIC, and shows how far (or not) a state is in the process.
#
# We do a little webscraping using BeautifulSoup to find the information we need.

# %%
url = "https://www.nationalpopularvote.com/state-status"
req = requests.get(url)
soup = BeautifulSoup(req.content, 'html.parser')

# %%
#skips over the initial list (and links) of states at the top of the page
init_state_skip = soup.find("p", text=re.compile("On the map below"))

# %%
#brings us to the tag just before the states and their current NPVIC status
tag_before_states = init_state_skip.find_next_sibling().find_next_sibling()

print(tag_before_states)
print(tag_before_states.find_next_sibling())
# Out:
# <p> </p>
# <p><a class="menu__link" href="/state/ak">Alaska</a></p>

# %%
#scrape the site for NPVIC status of each state
npvic_word_status = state_status_scrape(tag_before_states)
#make the status numerical
npvic_num_status = state_status_to_numerical(npvic_word_status)

#turns dict into pandas dataframe
npvic_df = pd.DataFrame.from_dict(npvic_num_status, orient='index')
npvic_df.reset_index(inplace=True)
npvic_df.columns = ['State', 'Status']

display(npvic_df.head())
display(npvic_df.info())
# Out:
#         State  Status
# 0      Alaska     0.0
# 1     Alabama     0.0
# 2    Arkansas     0.5
# 3     Arizona     0.5
# 4  California     1.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
# State     51 non-null object
# Status    51 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 944.0+ bytes
# None

# %% [markdown]
# ### Election History Data

# %% [markdown]
# Now what really matters to most people is how our elections will be affected, and for candidates who are running a presidential campaign, what states are safe, and which they should be worried about. From the MIT Election Lab (https://electionlab.mit.edu/data) I found a dataset for all presidential elections, by state, from 1976 to 2016.
#
# We do a little EDA on the data (details below) and reorganize the columns into something more readable.

# %% [markdown]
# Some things of note:
# - In exploration of the data, there was a "democrat/republican" that someone once ran as (James Gritz, only in CO, and in 1992) but that was excluded from the purely democrat/republican divide I want to study here
# - Any write in candidates were also not considered, as they are effectively outliers for this study
# - This dataset was only for US Presidential elections, so the office column is superfluous
# - In 2000, 2004, 2012, nominees Al Gore, John Kerry and Barack Obama had to run under the 'democratic-farmer-labor' party. That party name has been changed to 'democrat' for ease of analysis

# %%
vote_history = pd.read_csv('1976-2016-president.csv')

#changing the democratic-farmer-labor party to just democrat for 2000, 2004, and 2012
vote_history.replace(to_replace='democratic-farmer-labor', value='democrat', inplace=True)

#drop anything that's a write in, or not in the main two parties, and reset the index
vote_history = vote_history[(vote_history['party'].isin(['democrat', 'republican'])) & 
                            (vote_history['writein'] == False)]

#get rid of unnecessary columns
drop_vote_history_cols = ['state_po', 'state_fips', 'state_cen', 'writein', 'state_ic', 'office', 'version', 'notes']
vote_history.drop(drop_vote_history_cols, axis=1, inplace=True)

#combine two rows for each state into one row with all info for that year/state
vote_history = vote_history.sort_values(['year', 'state', 'party'])
dems = vote_history[vote_history.party == 'democrat'].drop('party', axis=1)
reps = vote_history[vote_history.party == 'republican'].drop('party', axis=1)
vote_history = dems.merge(reps, on=['year', 'state', 'totalvotes'])
vote_history.rename({'candidate_x': 'dem_cand', 'candidatevotes_x': 'dem_vote',
                     'candidate_y': 'rep_cand', 'candidatevotes_y': 'rep_vote'}, axis = 1, inplace=True)

#move the column totalvotes to the end of the dataframe
new_col_order = list(vote_history.columns)
new_col_order.remove('totalvotes')
new_col_order.append('totalvotes')

vote_history = vote_history[new_col_order]

display(vote_history.head(10))
display(vote_history.info())
# Out:
#    year                 state       dem_cand  dem_vote      rep_cand  \
# 0  1976               Alabama  Carter, Jimmy    659170  Ford, Gerald
# 1  1976                Alaska  Carter, Jimmy     44058  Ford, Gerald
# 2  1976               Arizona  Carter, Jimmy    295602  Ford, Gerald
# 3  1976              Arkansas  Carter, Jimmy    498604  Ford, Gerald
# 4  1976            California  Carter, Jimmy   3742284  Ford, Gerald
# 5  1976              Colorado  Carter, Jimmy    460801  Ford, Gerald
# 6  1976           Connecticut  Carter, Jimmy    647895  Ford, Gerald
# 7  1976              Delaware  Carter, Jimmy    122461  Ford, Gerald
# 8  1976  District of Columbia  Carter, Jimmy    137818  Ford, Gerald
# 9  1976               Florida  Carter, Jimmy   1636000  Ford, Gerald
#
#    rep_vote  totalvotes
# 0    504070     1182850
# 1     71555      123574
# 2    418642      742719
# 3    267903      767535
# 4   3882244     7803770
# 5    584278     1081440
# 6    719261     1386355
# 7    109780      235642
# 8     27873      168830
# 9   1469531     3150631
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 561 entries, 0 to 560
# Data columns (total 7 columns):
# year          561 non-null int64
# state         561 non-null object
# dem_cand      561 non-null object
# dem_vote      561 non-null int64
# rep_cand      561 non-null object
# rep_vote      561 non-null int64
# totalvotes    561 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 35.1+ KB
# None

# %% [markdown]
# ### Merging all data into SQL Database

# %% [markdown]
# We'll take all this data that we've collected through APIs, webscraping, and downloaded CSV files, and throw them all into a SQL database for easier analysis in another notebook!

# %%
#put all data into SQL database for retrieval in analysis
conn = sqlite3.connect('census_pop_data.db')
c = conn.cursor()

# %% [markdown]
# #### Population Data

# %%
# sql_table_creation(conn, c, 'Population', 'Year integer', 'State text', 'Pop integer', 'Overseas_pop integer')

# %%
merged_df.to_sql(name='Population', con=conn, if_exists='replace')

# %% [markdown]
# #### NPVIC Status

# %%
# sql_table_creation(conn, c, 'NPVIC_status', 'State text', 'Status real')

# %%
npvic_df.to_sql(name='NPVIC_status', con=conn, if_exists='replace')

# %% [markdown]
# #### Election Results

# %%
# sql_table_creation(conn, c, 'Election_results', 'Year integer', 'State text', 'Dem_cand text', 'Dem_vote integer', 
#                    'Rep_cand text', 'Rep_vote integer', 'Totalvotes integer')

# %%
vote_history.to_sql(name='Election_results', con=conn, if_exists='replace')

# %% [markdown]
# ### Check the input

# %%
c.execute('SELECT year, state, pop, overseas_pop FROM population')
for row in c.fetchall():
    print(row)
# Out:
# (2010, 'Minnesota', 5303925, 10954)
# (2011, 'Minnesota', 5346143, 11041)
# (2012, 'Minnesota', 5376643, 11104)
# (2013, 'Minnesota', 5413479, 11180)
# (2014, 'Minnesota', 5451079, 11258)
# (2015, 'Minnesota', 5482032, 11322)
# (2016, 'Minnesota', 5522744, 11406)
# (2017, 'Minnesota', 5566230, 11496)
# (2018, 'Minnesota', 5606249, 11579)
# (2019, 'Minnesota', 5639632, 11648)
# (2010, 'Mississippi', 2967297, 10943)
# (2011, 'Mississippi', 2978731, 10985)
# (2012, 'Mississippi', 2983816, 11004)
# (2013, 'Mississippi', 2988711, 11022)
# (2014, 'Mississippi', 2990468, 11028)
# (2015, 'Mississippi', 2988471, 11021)
# (2016, 'Mississippi', 2987938, 11019)
# (2017, 'Mississippi', 2988510, 11021)
# (2018, 'Mississippi', 2981020, 10993)
# (2019, 'Mississippi', 2976149, 10975)
# (2010, 'Missouri', 5988927, 22551)
# (2011, 'Missouri', 6010275, 22631)
# (2012, 'Missouri', 6024367, 22684)
# (2013, 'Missouri', 6040715, 22746)
# (2014, 'Missouri', 6056202, 22804)
# (2015, 'Missouri', 6071732, 22862)
# (2016, 'Missouri', 6087135, 22920)
# (2017, 'Missouri', 6106670, 22994)
# (2018, 'Missouri', 6121623, 23050)
# (2019, 'Missouri', 6137428, 23110)
# (2010, 'Montana', 989415, 5001)
# (2011, 'Montana', 997316, 5041)
# (2012, 'Montana', 1003783, 5074)
# (2013, 'Montana', 1013569, 5123)
# (2014, 'Montana', 1021869, 5165)
# (2015, 'Montana', 1030475, 5208)
# (2016, 'Montana', 1040859, 5260)
# (2017, 'Montana', 1052482, 5319)
# (2018, 'Montana', 1060665, 5360)
# (2019, 'Montana', 1068778, 5401)
# (2010, 'Nebraska', 1826341, 5484)
# (2011, 'Nebraska', 1840672, 5527)
# (2012, 'Nebraska', 1853303, 5565)
# (2013, 'Nebraska', 1865279, 5601)
# (2014, 'Nebraska', 1879321, 5643)
# (2015, 'Nebraska', 1891277, 5679)
# (2016, 'Nebraska', 1905616, 5722)
# (2017, 'Nebraska', 1915947, 5753)
# (2018, 'Nebraska', 1925614, 5782)
# (2019, 'Nebraska', 1934408, 5808)
# (2010, 'Nevada', 2700551, 8881)
# (2011, 'Nevada', 2712730, 8921)
# (2012, 'Nevada', 2743996, 9024)
# (2013, 'Nevada', 2775970, 9129)
# (2014, 'Nevada', 2817628, 9266)
# (2015, 'Nevada', 2866939, 9428)
# (2016, 'Nevada', 2917563, 9594)
# (2017, 'Nevada', 2969905, 9766)
# (2018, 'Nevada', 3027341, 9955)
# (2019, 'Nevada', 3080156, 10129)
# (2010, 'New Hampshire', 1316470, 4975)
# (2011, 'New Hampshire', 1320202, 4989)
# (2012, 'New Hampshire', 1324232, 5004)
# (2013, 'New Hampshire', 1326622, 5013)
# (2014, 'New Hampshire', 1333341, 5038)
# (2015, 'New Hampshire', 1336350, 5049)
# (2016, 'New Hampshire', 1342307, 5072)
# (2017, 'New Hampshire', 1348787, 5096)
# (2018, 'New Hampshire', 1353465, 5114)
# (2019, 'New Hampshire', 1359711, 5138)
# (2010, 'New Jersey', 8791894, 15607)
# (2011, 'New Jersey', 8828117, 15671)
# (2012, 'New Jersey', 8844942, 15701)
# (2013, 'New Jersey', 8856972, 15722)
# (2014, 'New Jersey', 8864525, 15735)
# (2015, 'New Jersey', 8867949, 15741)
# (2016, 'New Jersey', 8870827, 15746)
# (2017, 'New Jersey', 8885525, 15772)
# (2018, 'New Jersey', 8886025, 15773)
# (2019, 'New Jersey', 8882190, 15766)
# (2010, 'New Mexico', 2059179, 8094)
# (2011, 'New Mexico', 2080450, 8178)
# (2012, 'New Mexico', 2087309, 8205)
# (2013, 'New Mexico', 2092273, 8225)
# (2014, 'New Mexico', 2089568, 8214)
# (2015, 'New Mexico', 2089291, 8213)
# (2016, 'New Mexico', 2091630, 8222)
# (2017, 'New Mexico', 2091784, 8223)
# (2018, 'New Mexico', 2092741, 8227)
# (2019, 'New Mexico', 2096829, 8243)
# (2010, 'New York', 19378102, 42953)
# (2011, 'New York', 19499241, 43222)
# (2012, 'New York', 19572932, 43385)
# (2013, 'New York', 19624447, 43499)
# (2014, 'New York', 19651049, 43558)
# (2015, 'New York', 19654666, 43566)
# (2016, 'New York', 19633428, 43519)
# (2017, 'New York', 19589572, 43422)
# (2018, 'New York', 19530351, 43291)
# (2019, 'New York', 19453561, 43121)
# (2010, 'North Carolina', 9535483, 30298)
# (2011, 'North Carolina', 9657592, 30686)
# (2012, 'North Carolina', 9749476, 30978)
# (2013, 'North Carolina', 9843336, 31276)
# (2014, 'North Carolina', 9932887, 31561)
# (2015, 'North Carolina', 10031646, 31875)
# (2016, 'North Carolina', 10154788, 32266)
# (2017, 'North Carolina', 10268233, 32626)
# (2018, 'North Carolina', 10381615, 32986)
# (2019, 'North Carolina', 10488084, 33324)
# (2010, 'North Dakota', 672591, 3314)
# (2011, 'North Dakota', 685225, 3376)
# (2012, 'North Dakota', 701176, 3455)
# (2013, 'North Dakota', 722036, 3558)
# (2014, 'North Dakota', 737401, 3634)
# (2015, 'North Dakota', 754066, 3716)
# (2016, 'North Dakota', 754434, 3718)
# (2017, 'North Dakota', 754942, 3721)
# (2018, 'North Dakota', 758080, 3736)
# (2019, 'North Dakota', 762062, 3756)
# (2010, 'Ohio', 11536504, 31991)
# (2011, 'Ohio', 11544663, 32014)
# (2012, 'Ohio', 11548923, 32026)
# (2013, 'Ohio', 11576684, 32103)
# (2014, 'Ohio', 11602700, 32175)
# (2015, 'Ohio', 11617527, 32216)
# (2016, 'Ohio', 11634370, 32263)
# (2017, 'Ohio', 11659650, 32333)
# (2018, 'Ohio', 11676341, 32379)
# (2019, 'Ohio', 11689100, 32414)
# (2010, 'Oklahoma', 3751351, 13531)
# (2011, 'Oklahoma', 3788379, 13665)
# (2012, 'Oklahoma', 3818814, 13775)
# (2013, 'Oklahoma', 3853214, 13899)
# (2014, 'Oklahoma', 3878187, 13989)
# (2015, 'Oklahoma', 3909500, 14102)
# (2016, 'Oklahoma', 3926331, 14163)
# (2017, 'Oklahoma', 3931316, 14181)
# (2018, 'Oklahoma', 3940235, 14213)
# (2019, 'Oklahoma', 3956971, 14273)
# (2010, 'Oregon', 3831074, 17532)
# (2011, 'Oregon', 3872036, 17719)
# (2012, 'Oregon', 3899001, 17842)
# (2013, 'Oregon', 3922468, 17949)
# (2014, 'Oregon', 3963244, 18136)
# (2015, 'Oregon', 4015792, 18376)
# (2016, 'Oregon', 4089976, 18715)
# (2017, 'Oregon', 4143625, 18960)
# (2018, 'Oregon', 4181886, 19135)
# (2019, 'Oregon', 4217737, 19299)
# (2010, 'Pennsylvania', 12702379, 32526)
# (2011, 'Pennsylvania', 12745815, 32637)
# (2012, 'Pennsylvania', 12767118, 32692)
# (2013, 'Pennsylvania', 12776309, 32716)
# (2014, 'Pennsylvania', 12788313, 32747)
# (2015, 'Pennsylvania', 12784826, 32738)
# (2016, 'Pennsylvania', 12782275, 32731)
# (2017, 'Pennsylvania', 12787641, 32745)
# (2018, 'Pennsylvania', 12800922, 32779)
# (2019, 'Pennsylvania', 12801989, 32782)
# (2010, 'Rhode Island', 1052567, 2680)
# (2011, 'Rhode Island', 1053649, 2683)
# (2012, 'Rhode Island', 1054621, 2685)
# (2013, 'Rhode Island', 1055081, 2686)
# (2014, 'Rhode Island', 1055936, 2688)
# (2015, 'Rhode Island', 1056065, 2688)
# (2016, 'Rhode Island', 1056770, 2690)
# (2017, 'Rhode Island', 1055673, 2687)
# (2018, 'Rhode Island', 1058287, 2694)
# (2019, 'Rhode Island', 1059361, 2697)
# (2010, 'South Carolina', 4625364, 20611)
# (2011, 'South Carolina', 4671994, 20819)
# (2012, 'South Carolina', 4717354, 21021)
# (2013, 'South Carolina', 4764080, 21229)
# (2014, 'South Carolina', 4823617, 21494)
# (2015, 'South Carolina', 4891938, 21798)
# (2016, 'South Carolina', 4957968, 22092)
# (2017, 'South Carolina', 5021268, 22374)
# (2018, 'South Carolina', 5084156, 22654)
# (2019, 'South Carolina', 5148714, 22942)
# (2010, 'South Dakota', 814180, 5581)
# (2011, 'South Dakota', 823579, 5645)
# (2012, 'South Dakota', 833566, 5713)
# (2013, 'South Dakota', 842316, 5773)
# (2014, 'South Dakota', 849129, 5820)
# (2015, 'South Dakota', 853988, 5853)
# (2016, 'South Dakota', 862996, 5915)
# (2017, 'South Dakota', 872868, 5983)
# (2018, 'South Dakota', 878698, 6023)
# (2019, 'South Dakota', 884659, 6064)
# (2010, 'Tennessee', 6346105, 29326)
# (2011, 'Tennessee', 6399291, 29572)
# (2012, 'Tennessee', 6453898, 29824)
# (2013, 'Tennessee', 6494340, 30011)
# (2014, 'Tennessee', 6541223, 30228)
# (2015, 'Tennessee', 6591170, 30459)
# (2016, 'Tennessee', 6646010, 30712)
# (2017, 'Tennessee', 6708799, 31002)
# (2018, 'Tennessee', 6771631, 31292)
# (2019, 'Tennessee', 6829174, 31558)
# (2010, 'Texas', 25145561, 122857)
# (2011, 'Texas', 25645629, 125300)
# (2012, 'Texas', 26084481, 127444)
# (2013, 'Texas', 26480266, 129378)
# (2014, 'Texas', 26964333, 131743)
# (2015, 'Texas', 27470056, 134214)
# (2016, 'Texas', 27914410, 136385)
# (2017, 'Texas', 28295273, 138246)
# (2018, 'Texas', 28628666, 139875)
# (2019, 'Texas', 28995881, 141669)
# (2010, 'Utah', 2763885, 6880)
# (2011, 'Utah', 2814384, 7006)
# (2012, 'Utah', 2853375, 7103)
# (2013, 'Utah', 2897640, 7213)
# (2014, 'Utah', 2936879, 7311)
# (2015, 'Utah', 2981835, 7423)
# (2016, 'Utah', 3041868, 7572)
# (2017, 'Utah', 3101042, 7719)
# (2018, 'Utah', 3153550, 7850)
# (2019, 'Utah', 3205958, 7980)
# (2010, 'Vermont', 625741, 4596)
# (2011, 'Vermont', 627049, 4606)
# (2012, 'Vermont', 626090, 4599)
# (2013, 'Vermont', 626210, 4600)
# (2014, 'Vermont', 625214, 4593)
# (2015, 'Vermont', 625216, 4593)
# (2016, 'Vermont', 623657, 4582)
# (2017, 'Vermont', 624344, 4587)
# (2018, 'Vermont', 624358, 4587)
# (2019, 'Vermont', 623989, 4584)
# (2010, 'Virginia', 8001024, 36712)
# (2011, 'Virginia', 8101155, 37171)
# (2012, 'Virginia', 8185080, 37556)
# (2013, 'Virginia', 8252427, 37865)
# (2014, 'Virginia', 8310993, 38134)
# (2015, 'Virginia', 8361808, 38367)
# (2016, 'Virginia', 8410106, 38589)
# (2017, 'Virginia', 8463587, 38834)
# (2018, 'Virginia', 8501286, 39007)
# (2019, 'Virginia', 8535519, 39164)
# (2010, 'West Virginia', 1852994, 6821)
# (2011, 'West Virginia', 1856301, 6833)
# (2012, 'West Virginia', 1856872, 6835)
# (2013, 'West Virginia', 1853914, 6824)
# (2014, 'West Virginia', 1849489, 6808)
# (2015, 'West Virginia', 1842050, 6781)
# (2016, 'West Virginia', 1831023, 6740)
# (2017, 'West Virginia', 1817004, 6688)
# (2018, 'West Virginia', 1804291, 6641)
# (2019, 'West Virginia', 1792147, 6596)
# (2010, 'Washington', 6724540, 28829)
# (2011, 'Washington', 6826627, 29267)
# (2012, 'Washington', 6897058, 29569)
# (2013, 'Washington', 6963985, 29856)
# (2014, 'Washington', 7054655, 30245)
# (2015, 'Washington', 7163657, 30712)
# (2016, 'Washington', 7294771, 31274)
# (2017, 'Washington', 7423362, 31825)
# (2018, 'Washington', 7523869, 32256)
# (2019, 'Washington', 7614893, 32646)
# (2010, 'Wisconsin', 5686986, 11244)
# (2011, 'Wisconsin', 5705288, 11280)
# (2012, 'Wisconsin', 5719960, 11309)
# (2013, 'Wisconsin', 5736754, 11342)
# (2014, 'Wisconsin', 5751525, 11371)
# (2015, 'Wisconsin', 5760940, 11390)
# (2016, 'Wisconsin', 5772628, 11413)
# (2017, 'Wisconsin', 5790186, 11448)
# (2018, 'Wisconsin', 5807406, 11482)
# (2019, 'Wisconsin', 5822434, 11512)
# (2010, 'Wyoming', 563626, 4674)
# (2011, 'Wyoming', 567299, 4704)
# (2012, 'Wyoming', 576305, 4779)
# (2013, 'Wyoming', 582122, 4827)
# (2014, 'Wyoming', 582531, 4830)
# (2015, 'Wyoming', 585613, 4856)
# (2016, 'Wyoming', 584215, 4844)
# (2017, 'Wyoming', 578931, 4800)
# (2018, 'Wyoming', 577601, 4789)
# (2019, 'Wyoming', 578759, 4799)
# (2010, 'Puerto Rico', 3725789, 30894)
# (2011, 'Puerto Rico', 3678732, 30504)
# (2012, 'Puerto Rico', 3634488, 30137)
# (2013, 'Puerto Rico', 3593077, 29794)
# (2014, 'Puerto Rico', 3534874, 29311)
# (2015, 'Puerto Rico', 3473232, 28800)
# (2016, 'Puerto Rico', 3406672, 28248)
# (2017, 'Puerto Rico', 3325286, 27573)
# (2018, 'Puerto Rico', 3193354, 26479)
# (2019, 'Puerto Rico', 3193694, 26482)
# (2010, 'Alabama', 4779736, 23246)
# (2011, 'Alabama', 4799069, 23340)
# (2012, 'Alabama', 4815588, 23420)
# (2013, 'Alabama', 4830081, 23490)
# (2014, 'Alabama', 4841799, 23547)
# (2015, 'Alabama', 4852347, 23598)
# (2016, 'Alabama', 4863525, 23652)
# (2017, 'Alabama', 4874486, 23705)
# (2018, 'Alabama', 4887681, 23769)
# (2019, 'Alabama', 4903185, 23844)
# (2010, 'Alaska', 710231, 11292)
# (2011, 'Alaska', 722128, 11481)
# (2012, 'Alaska', 730443, 11613)
# (2013, 'Alaska', 737068, 11718)
# (2014, 'Alaska', 736283, 11706)
# (2015, 'Alaska', 737498, 11725)
# (2016, 'Alaska', 741456, 11788)
# (2017, 'Alaska', 739700, 11760)
# (2018, 'Alaska', 735139, 11687)
# (2019, 'Alaska', 731545, 11630)
# (2010, 'Arizona', 6392017, 20683)
# (2011, 'Arizona', 6472643, 20944)
# (2012, 'Arizona', 6554978, 21210)
# (2013, 'Arizona', 6632764, 21462)
# (2014, 'Arizona', 6730413, 21778)
# (2015, 'Arizona', 6829676, 22099)
# (2016, 'Arizona', 6941072, 22459)
# (2017, 'Arizona', 7044008, 22792)
# (2018, 'Arizona', 7158024, 23161)
# (2019, 'Arizona', 7278717, 23552)
# (2010, 'Arkansas', 2915918, 10311)
# (2011, 'Arkansas', 2940667, 10399)
# (2012, 'Arkansas', 2952164, 10440)
# (2013, 'Arkansas', 2959400, 10466)
# (2014, 'Arkansas', 2967392, 10494)
# (2015, 'Arkansas', 2978048, 10532)
# (2016, 'Arkansas', 2989918, 10574)
# (2017, 'Arkansas', 3001345, 10614)
# (2018, 'Arkansas', 3009733, 10644)
# (2019, 'Arkansas', 3017804, 10673)
# (2010, 'California', 37253956, 88033)
# (2011, 'California', 37638369, 88941)
# (2012, 'California', 37948800, 89675)
# (2013, 'California', 38260787, 90412)
# (2014, 'California', 38596972, 91206)
# (2015, 'California', 38918045, 91965)
# (2016, 'California', 39167117, 92554)
# (2017, 'California', 39358497, 93006)
# (2018, 'California', 39461588, 93250)
# (2019, 'California', 39512223, 93370)
# (2010, 'Colorado', 5029196, 15734)
# (2011, 'Colorado', 5121108, 16022)
# (2012, 'Colorado', 5192647, 16246)
# (2013, 'Colorado', 5269035, 16485)
# (2014, 'Colorado', 5350101, 16739)
# (2015, 'Colorado', 5450623, 17054)
# (2016, 'Colorado', 5539215, 17331)
# (2017, 'Colorado', 5611885, 17558)
# (2018, 'Colorado', 5691287, 17806)
# (2019, 'Colorado', 5758736, 18017)
# (2010, 'Connecticut', 3574097, 7531)
# (2011, 'Connecticut', 3588283, 7561)
# (2012, 'Connecticut', 3594547, 7574)
# (2013, 'Connecticut', 3594841, 7575)
# (2014, 'Connecticut', 3594524, 7574)
# (2015, 'Connecticut', 3587122, 7558)
# (2016, 'Connecticut', 3578141, 7539)
# (2017, 'Connecticut', 3573297, 7529)
# (2018, 'Connecticut', 3571520, 7525)
# (2019, 'Connecticut', 3565287, 7512)
# (2010, 'Delaware', 897934, 2943)
# (2011, 'Delaware', 907381, 2974)
# (2012, 'Delaware', 915179, 3000)
# (2013, 'Delaware', 923576, 3028)
# (2014, 'Delaware', 932487, 3057)
# (2015, 'Delaware', 941252, 3086)
# (2016, 'Delaware', 948921, 3111)
# (2017, 'Delaware', 956823, 3137)
# (2018, 'Delaware', 965479, 3165)
# (2019, 'Delaware', 973764, 3192)
# (2010, 'District of Columbia', 601723, 2875)
# (2011, 'District of Columbia', 619800, 2961)
# (2012, 'District of Columbia', 634924, 3033)
# (2013, 'District of Columbia', 650581, 3108)
# (2014, 'District of Columbia', 662328, 3164)
# (2015, 'District of Columbia', 675400, 3226)
# (2016, 'District of Columbia', 685815, 3276)
# (2017, 'District of Columbia', 694906, 3319)
# (2018, 'District of Columbia', 701547, 3351)
# (2019, 'District of Columbia', 705749, 3371)
# (2010, 'Florida', 18801310, 99463)
# (2011, 'Florida', 19053237, 100796)
# (2012, 'Florida', 19297822, 102090)
# (2013, 'Florida', 19545621, 103401)
# (2014, 'Florida', 19845911, 104990)
# (2015, 'Florida', 20209042, 106911)
# (2016, 'Florida', 20613477, 109051)
# (2017, 'Florida', 20963613, 110903)
# (2018, 'Florida', 21244317, 112388)
# (2019, 'Florida', 21477737, 113623)
# (2010, 'Georgia', 9687653, 39913)
# (2011, 'Georgia', 9802431, 40386)
# (2012, 'Georgia', 9901430, 40794)
# (2013, 'Georgia', 9972479, 41087)
# (2014, 'Georgia', 10067278, 41478)
# (2015, 'Georgia', 10178447, 41936)
# (2016, 'Georgia', 10301890, 42445)
# (2017, 'Georgia', 10410330, 42892)
# (2018, 'Georgia', 10511131, 43307)
# (2019, 'Georgia', 10617423, 43745)
# (2010, 'Idaho', 1567582, 5917)
# (2011, 'Idaho', 1583910, 5979)
# (2012, 'Idaho', 1595324, 6022)
# (2013, 'Idaho', 1611206, 6082)
# (2014, 'Idaho', 1631112, 6157)
# (2015, 'Idaho', 1651059, 6232)
# (2016, 'Idaho', 1682380, 6350)
# (2017, 'Idaho', 1717715, 6483)
# (2018, 'Idaho', 1750536, 6607)
# (2019, 'Idaho', 1787065, 6745)
# (2010, 'Hawaii', 1360301, 6561)
# (2011, 'Hawaii', 1379329, 6653)
# (2012, 'Hawaii', 1394804, 6728)
# (2013, 'Hawaii', 1408243, 6793)
# (2014, 'Hawaii', 1414538, 6823)
# (2015, 'Hawaii', 1422052, 6859)
# (2016, 'Hawaii', 1427559, 6886)
# (2017, 'Hawaii', 1424393, 6871)
# (2018, 'Hawaii', 1420593, 6853)
# (2019, 'Hawaii', 1415872, 6830)
# (2010, 'Illinois', 12830632, 33748)
# (2011, 'Illinois', 12867454, 33845)
# (2012, 'Illinois', 12882510, 33885)
# (2013, 'Illinois', 12895129, 33918)
# (2014, 'Illinois', 12884493, 33890)
# (2015, 'Illinois', 12858913, 33823)
# (2016, 'Illinois', 12820527, 33722)
# (2017, 'Illinois', 12778828, 33612)
# (2018, 'Illinois', 12723071, 33465)
# (2019, 'Illinois', 12671821, 33330)
# (2010, 'Indiana', 6483802, 17780)
# (2011, 'Indiana', 6516528, 17870)
# (2012, 'Indiana', 6537703, 17928)
# (2013, 'Indiana', 6568713, 18013)
# (2014, 'Indiana', 6593644, 18081)
# (2015, 'Indiana', 6608422, 18122)
# (2016, 'Indiana', 6634304, 18193)
# (2017, 'Indiana', 6658078, 18258)
# (2018, 'Indiana', 6695497, 18361)
# (2019, 'Indiana', 6732219, 18462)
# (2010, 'Iowa', 3046355, 7432)
# (2011, 'Iowa', 3066336, 7481)
# (2012, 'Iowa', 3076190, 7505)
# (2013, 'Iowa', 3092997, 7546)
# (2014, 'Iowa', 3109350, 7586)
# (2015, 'Iowa', 3120960, 7614)
# (2016, 'Iowa', 3131371, 7639)
# (2017, 'Iowa', 3141550, 7664)
# (2018, 'Iowa', 3148618, 7681)
# (2019, 'Iowa', 3155070, 7697)
# (2010, 'Kansas', 2853118, 10695)
# (2011, 'Kansas', 2869225, 10755)
# (2012, 'Kansas', 2885257, 10815)
# (2013, 'Kansas', 2893212, 10845)
# (2014, 'Kansas', 2900475, 10872)
# (2015, 'Kansas', 2909011, 10904)
# (2016, 'Kansas', 2910844, 10911)
# (2017, 'Kansas', 2908718, 10903)
# (2018, 'Kansas', 2911359, 10913)
# (2019, 'Kansas', 2913314, 10920)
# (2010, 'Kentucky', 4339367, 11239)
# (2011, 'Kentucky', 4369821, 11318)
# (2012, 'Kentucky', 4386346, 11361)
# (2013, 'Kentucky', 4404659, 11408)
# (2014, 'Kentucky', 4414349, 11433)
# (2015, 'Kentucky', 4425976, 11463)
# (2016, 'Kentucky', 4438182, 11495)
# (2017, 'Kentucky', 4452268, 11531)
# (2018, 'Kentucky', 4461153, 11554)
# (2019, 'Kentucky', 4467673, 11571)
# (2010, 'Louisiana', 4533372, 20590)
# (2011, 'Louisiana', 4575625, 20782)
# (2012, 'Louisiana', 4600972, 20897)
# (2013, 'Louisiana', 4624527, 21004)
# (2014, 'Louisiana', 4644013, 21093)
# (2015, 'Louisiana', 4664628, 21187)
# (2016, 'Louisiana', 4678135, 21248)
# (2017, 'Louisiana', 4670560, 21214)
# (2018, 'Louisiana', 4659690, 21165)
# (2019, 'Louisiana', 4648794, 21116)
# (2010, 'Maine', 1328361, 4713)
# (2011, 'Maine', 1328284, 4713)
# (2012, 'Maine', 1327729, 4711)
# (2013, 'Maine', 1328009, 4712)
# (2014, 'Maine', 1330513, 4721)
# (2015, 'Maine', 1328262, 4713)
# (2016, 'Maine', 1331317, 4724)
# (2017, 'Maine', 1334612, 4736)
# (2018, 'Maine', 1339057, 4752)
# (2019, 'Maine', 1344212, 4770)
# (2010, 'Maryland', 5773552, 16377)
# (2011, 'Maryland', 5839419, 16564)
# (2012, 'Maryland', 5886992, 16699)
# (2013, 'Maryland', 5923188, 16802)
# (2014, 'Maryland', 5957283, 16899)
# (2015, 'Maryland', 5985562, 16979)
# (2016, 'Maryland', 6003323, 17029)
# (2017, 'Maryland', 6023868, 17087)
# (2018, 'Maryland', 6035802, 17121)
# (2019, 'Maryland', 6045680, 17149)
# (2010, 'Massachusetts', 6547629, 12015)
# (2011, 'Massachusetts', 6613583, 12136)
# (2012, 'Massachusetts', 6663005, 12227)
# (2013, 'Massachusetts', 6713315, 12319)
# (2014, 'Massachusetts', 6762596, 12409)
# (2015, 'Massachusetts', 6794228, 12467)
# (2016, 'Massachusetts', 6823608, 12521)
# (2017, 'Massachusetts', 6859789, 12587)
# (2018, 'Massachusetts', 6882635, 12629)
# (2019, 'Massachusetts', 6892503, 12647)
# (2010, 'Michigan', 9883640, 27986)
# (2011, 'Michigan', 9882412, 27983)
# (2012, 'Michigan', 9897145, 28025)
# (2013, 'Michigan', 9913065, 28070)
# (2014, 'Michigan', 9929848, 28118)
# (2015, 'Michigan', 9931715, 28123)
# (2016, 'Michigan', 9950571, 28176)
# (2017, 'Michigan', 9973114, 28240)
# (2018, 'Michigan', 9984072, 28271)
# (2019, 'Michigan', 9986857, 28279)

# %%
c.execute('SELECT state, status FROM npvic_status')
for row in c.fetchall():
    print(row)
# Out:
# ('Alaska', 0.0)
# ('Alabama', 0.0)
# ('Arkansas', 0.5)
# ('Arizona', 0.5)
# ('California', 1.0)
# ('Colorado', 1.0)
# ('Connecticut', 1.0)
# ('District of Columbia', 1.0)
# ('Delaware', 1.0)
# ('Florida', 0.0)
# ('Georgia', 0.25)
# ('Hawaii', 1.0)
# ('Iowa', 0.0)
# ('Idaho', 0.0)
# ('Illinois', 1.0)
# ('Indiana', 0.0)
# ('Kansas', 0.0)
# ('Kentucky', 0.0)
# ('Louisiana', 0.0)
# ('Massachusetts', 1.0)
# ('Maryland', 1.0)
# ('Maine', 0.5)
# ('Michigan', 0.5)
# ('Minnesota', 0.5)
# ('Missouri', 0.25)
# ('Mississippi', 0.0)
# ('Montana', 0.0)
# ('North Carolina', 0.5)
# ('North Dakota', 0.0)
# ('Nebraska', 0.0)
# ('New Hampshire', 0.0)
# ('New Jersey', 1.0)
# ('New Mexico', 1.0)
# ('Nevada', 0.5)
# ('New York', 1.0)
# ('Ohio', 0.0)
# ('Oklahoma', 0.5)
# ('Oregon', 1.0)
# ('Pennsylvania', 0.0)
# ('Rhode Island', 1.0)
# ('South Carolina', 0.0)
# ('South Dakota', 0.0)
# ('Tennessee', 0.0)
# ('Texas', 0.0)
# ('Utah', 0.0)
# ('Virginia', 0.0)
# ('Vermont', 1.0)
# ('Washington', 1.0)
# ('Wisconsin', 0.0)
# ('West Virginia', 0.0)
# ('Wyoming', 0.0)

# %%
c.execute('SELECT year, state, dem_cand, dem_vote, rep_cand, rep_vote, totalvotes FROM election_results')
for row in c.fetchall():
    print(row)
# Out:
# (1976, 'Alabama', 'Carter, Jimmy', 659170, 'Ford, Gerald', 504070, 1182850)
# (1976, 'Alaska', 'Carter, Jimmy', 44058, 'Ford, Gerald', 71555, 123574)
# (1976, 'Arizona', 'Carter, Jimmy', 295602, 'Ford, Gerald', 418642, 742719)
# (1976, 'Arkansas', 'Carter, Jimmy', 498604, 'Ford, Gerald', 267903, 767535)
# (1976, 'California', 'Carter, Jimmy', 3742284, 'Ford, Gerald', 3882244, 7803770)
# (1976, 'Colorado', 'Carter, Jimmy', 460801, 'Ford, Gerald', 584278, 1081440)
# (1976, 'Connecticut', 'Carter, Jimmy', 647895, 'Ford, Gerald', 719261, 1386355)
# (1976, 'Delaware', 'Carter, Jimmy', 122461, 'Ford, Gerald', 109780, 235642)
# (1976, 'District of Columbia', 'Carter, Jimmy', 137818, 'Ford, Gerald', 27873, 168830)
# (1976, 'Florida', 'Carter, Jimmy', 1636000, 'Ford, Gerald', 1469531, 3150631)
# (1976, 'Georgia', 'Carter, Jimmy', 979409, 'Ford, Gerald', 483743, 1463152)
# (1976, 'Hawaii', 'Carter, Jimmy', 147375, 'Ford, Gerald', 140003, 291301)
# (1976, 'Idaho', 'Carter, Jimmy', 126549, 'Ford, Gerald', 204151, 340932)
# (1976, 'Illinois', 'Carter, Jimmy', 2271295, 'Ford, Gerald', 2364269, 4721282)
# (1976, 'Indiana', 'Carter, Jimmy', 1014714, 'Ford, Gerald', 1183958, 2220362)
# (1976, 'Iowa', 'Carter, Jimmy', 619931, 'Ford, Gerald', 632864, 1279303)
# (1976, 'Kansas', 'Carter, Jimmy', 430421, 'Ford, Gerald', 502752, 957845)
# (1976, 'Kentucky', 'Carter, Jimmy', 615717, 'Ford, Gerald', 531852, 1167142)
# (1976, 'Louisiana', 'Carter, Jimmy', 661365, 'Ford, Gerald', 587446, 1277383)
# (1976, 'Maine', 'Carter, Jimmy', 232279, 'Ford, Gerald', 236320, 482968)
# (1976, 'Maryland', 'Carter, Jimmy', 759612, 'Ford, Gerald', 672661, 1432273)
# (1976, 'Massachusetts', 'Carter, Jimmy', 1429475, 'Ford, Gerald', 1030276, 2547558)
# (1976, 'Michigan', 'Carter, Jimmy', 1696714, 'Ford, Gerald', 1893742, 3651590)
# (1976, 'Minnesota', 'Carter, Jimmy', 1070440, 'Ford, Gerald', 819395, 1949931)
# (1976, 'Mississippi', 'Carter, Jimmy', 381329, 'Ford, Gerald', 366846, 768390)
# (1976, 'Missouri', 'Carter, Jimmy', 998387, 'Ford, Gerald', 927443, 1953600)
# (1976, 'Montana', 'Carter, Jimmy', 149259, 'Ford, Gerald', 173703, 328734)
# (1976, 'Nebraska', 'Carter, Jimmy', 233293, 'Ford, Gerald', 359219, 606749)
# (1976, 'Nevada', 'Carter, Jimmy', 92479, 'Ford, Gerald', 101273, 201876)
# (1976, 'New Hampshire', 'Carter, Jimmy', 147645, 'Ford, Gerald', 185935, 339627)
# (1976, 'New Jersey', 'Carter, Jimmy', 1444653, 'Ford, Gerald', 1509688, 3014472)
# (1976, 'New Mexico', 'Carter, Jimmy', 201148, 'Ford, Gerald', 211419, 416590)
# (1976, 'New York', 'Carter, Jimmy', 3244165, 'Ford, Gerald', 2825913, 6668262)
# (1976, 'North Carolina', 'Carter, Jimmy', 927365, 'Ford, Gerald', 741960, 1677906)
# (1976, 'North Dakota', 'Carter, Jimmy', 136078, 'Ford, Gerald', 153684, 297308)
# (1976, 'Ohio', 'Carter, Jimmy', 2009959, 'Ford, Gerald', 2000626, 4110456)
# (1976, 'Oklahoma', 'Carter, Jimmy', 532442, 'Ford, Gerald', 545708, 1092251)
# (1976, 'Oregon', 'Carter, Jimmy', 490407, 'Ford, Gerald', 492120, 1029876)
# (1976, 'Pennsylvania', 'Carter, Jimmy', 2328677, 'Ford, Gerald', 2205604, 4620787)
# (1976, 'Rhode Island', 'Carter, Jimmy', 227636, 'Ford, Gerald', 181249, 410584)
# (1976, 'South Carolina', 'Carter, Jimmy', 450807, 'Ford, Gerald', 346149, 802583)
# (1976, 'South Dakota', 'Carter, Jimmy', 147068, 'Ford, Gerald', 151505, 300678)
# (1976, 'Tennessee', 'Carter, Jimmy', 825879, 'Ford, Gerald', 633969, 1476346)
# (1976, 'Texas', 'Carter, Jimmy', 2082319, 'Ford, Gerald', 1953300, 4071884)
# (1976, 'Utah', 'Carter, Jimmy', 182110, 'Ford, Gerald', 337908, 541218)
# (1976, 'Vermont', 'Carter, Jimmy', 77798, 'Ford, Gerald', 100387, 183902)
# (1976, 'Virginia', 'Carter, Jimmy', 813896, 'Ford, Gerald', 836554, 1697094)
# (1976, 'Washington', 'Carter, Jimmy', 717323, 'Ford, Gerald', 777732, 1555534)
# (1976, 'West Virginia', 'Carter, Jimmy', 435864, 'Ford, Gerald', 314726, 750590)
# (1976, 'Wisconsin', 'Carter, Jimmy', 1040232, 'Ford, Gerald', 1004987, 2101336)
# (1976, 'Wyoming', 'Carter, Jimmy', 62239, 'Ford, Gerald', 92717, 156343)
# (1980, 'Alabama', 'Carter, Jimmy', 636730, 'Reagan, Ronald', 654192, 1341929)
# (1980, 'Alaska', 'Carter, Jimmy', 41842, 'Reagan, Ronald', 86112, 158445)
# (1980, 'Arizona', 'Carter, Jimmy', 246843, 'Reagan, Ronald', 529688, 873945)
# (1980, 'Arkansas', 'Carter, Jimmy', 398041, 'Reagan, Ronald', 403164, 837582)
# (1980, 'California', 'Carter, Jimmy', 3082943, 'Reagan, Ronald', 4522994, 8582938)
# (1980, 'Colorado', 'Carter, Jimmy', 368009, 'Reagan, Ronald', 652264, 1184450)
# (1980, 'Connecticut', 'Carter, Jimmy', 541732, 'Reagan, Ronald', 677210, 1406285)
# (1980, 'Delaware', 'Carter, Jimmy', 105754, 'Reagan, Ronald', 111252, 235668)
# (1980, 'District of Columbia', 'Carter, Jimmy', 130231, 'Reagan, Ronald', 23313, 173889)
# (1980, 'Florida', 'Carter, Jimmy', 1419475, 'Reagan, Ronald', 2046951, 3686927)
# (1980, 'Georgia', 'Carter, Jimmy', 890955, 'Reagan, Ronald', 654168, 1596805)
# (1980, 'Hawaii', 'Carter, Jimmy', 135879, 'Reagan, Ronald', 130112, 303287)
# (1980, 'Idaho', 'Carter, Jimmy', 110192, 'Reagan, Ronald', 290699, 437431)
# (1980, 'Illinois', 'Carter, Jimmy', 1981413, 'Reagan, Ronald', 2358049, 4749721)
# (1980, 'Indiana', 'Carter, Jimmy', 844197, 'Reagan, Ronald', 1255656, 2242033)
# (1980, 'Iowa', 'Carter, Jimmy', 508672, 'Reagan, Ronald', 676026, 1317661)
# (1980, 'Kansas', 'Carter, Jimmy', 326150, 'Reagan, Ronald', 566812, 979795)
# (1980, 'Kentucky', 'Carter, Jimmy', 617417, 'Reagan, Ronald', 635274, 1295627)
# (1980, 'Louisiana', 'Carter, Jimmy', 708453, 'Reagan, Ronald', 792853, 1548591)
# (1980, 'Maine', 'Carter, Jimmy', 220974, 'Reagan, Ronald', 238522, 523011)
# (1980, 'Maryland', 'Carter, Jimmy', 726161, 'Reagan, Ronald', 680606, 1540496)
# (1980, 'Massachusetts', 'Carter, Jimmy', 1053802, 'Reagan, Ronald', 1057631, 2524090)
# (1980, 'Michigan', 'Carter, Jimmy', 1661532, 'Reagan, Ronald', 1915225, 3909725)
# (1980, 'Minnesota', 'Carter, Jimmy', 954173, 'Reagan, Ronald', 873268, 2051916)
# (1980, 'Mississippi', 'Carter, Jimmy', 429281, 'Reagan, Ronald', 441089, 891750)
# (1980, 'Missouri', 'Carter, Jimmy', 931182, 'Reagan, Ronald', 1074181, 2099824)
# (1980, 'Montana', 'Carter, Jimmy', 118032, 'Reagan, Ronald', 206814, 363952)
# (1980, 'Nebraska', 'Carter, Jimmy', 166424, 'Reagan, Ronald', 419214, 639533)
# (1980, 'Nevada', 'Carter, Jimmy', 66666, 'Reagan, Ronald', 155017, 243692)
# (1980, 'New Hampshire', 'Carter, Jimmy', 108864, 'Reagan, Ronald', 221705, 383990)
# (1980, 'New Jersey', 'Carter, Jimmy', 1147364, 'Reagan, Ronald', 1546557, 2975684)
# (1980, 'New Mexico', 'Carter, Jimmy', 167826, 'Reagan, Ronald', 250779, 456237)
# (1980, 'New York', 'Carter, Jimmy', 2728372, 'Reagan, Ronald', 2637700, 6201959)
# (1980, 'North Carolina', 'Carter, Jimmy', 875635, 'Reagan, Ronald', 915018, 1855833)
# (1980, 'North Dakota', 'Carter, Jimmy', 79189, 'Reagan, Ronald', 193695, 301116)
# (1980, 'Ohio', 'Carter, Jimmy', 1752414, 'Reagan, Ronald', 2206545, 4283603)
# (1980, 'Oklahoma', 'Carter, Jimmy', 402026, 'Reagan, Ronald', 695570, 1149708)
# (1980, 'Oregon', 'Carter, Jimmy', 456890, 'Reagan, Ronald', 571044, 1181516)
# (1980, 'Pennsylvania', 'Carter, Jimmy', 1937540, 'Reagan, Ronald', 2261872, 4561501)
# (1980, 'Rhode Island', 'Carter, Jimmy', 198342, 'Reagan, Ronald', 154793, 415967)
# (1980, 'South Carolina', 'Carter, Jimmy', 428220, 'Reagan, Ronald', 439277, 888258)
# (1980, 'South Dakota', 'Carter, Jimmy', 103855, 'Reagan, Ronald', 198343, 327703)
# (1980, 'Tennessee', 'Carter, Jimmy', 783051, 'Reagan, Ronald', 787761, 1617616)
# (1980, 'Texas', 'Carter, Jimmy', 1881147, 'Reagan, Ronald', 2510705, 4541636)
# (1980, 'Utah', 'Carter, Jimmy', 124266, 'Reagan, Ronald', 439687, 604152)
# (1980, 'Vermont', 'Carter, Jimmy', 81952, 'Reagan, Ronald', 94628, 213299)
# (1980, 'Virginia', 'Carter, Jimmy', 752174, 'Reagan, Ronald', 989609, 1866032)
# (1980, 'Washington', 'Carter, Jimmy', 650193, 'Reagan, Ronald', 865244, 1742394)
# (1980, 'West Virginia', 'Carter, Jimmy', 367462, 'Reagan, Ronald', 334206, 737715)
# (1980, 'Wisconsin', 'Carter, Jimmy', 981584, 'Reagan, Ronald', 1088845, 2273221)
# (1980, 'Wyoming', 'Carter, Jimmy', 49427, 'Reagan, Ronald', 110700, 176713)
# (1984, 'Alabama', 'Mondale, Walter', 551899, 'Reagan, Ronald', 872849, 1441713)
# (1984, 'Alaska', 'Mondale, Walter', 62007, 'Reagan, Ronald', 138377, 207605)
# (1984, 'Arizona', 'Mondale, Walter', 333854, 'Reagan, Ronald', 681416, 1025897)
# (1984, 'Arkansas', 'Mondale, Walter', 338646, 'Reagan, Ronald', 534774, 884406)
# (1984, 'California', 'Mondale, Walter', 3922519, 'Reagan, Ronald', 5467009, 9505041)
# (1984, 'Colorado', 'Mondale, Walter', 454975, 'Reagan, Ronald', 821817, 1295380)
# (1984, 'Connecticut', 'Mondale, Walter', 569597, 'Reagan, Ronald', 890877, 1466900)
# (1984, 'Delaware', 'Mondale, Walter', 101656, 'Reagan, Ronald', 152190, 254572)
# (1984, 'District of Columbia', 'Mondale, Walter', 180408, 'Reagan, Ronald', 29009, 211288)
# (1984, 'Florida', 'Mondale, Walter', 1448816, 'Reagan, Ronald', 2730350, 4180051)
# (1984, 'Georgia', 'Mondale, Walter', 706628, 'Reagan, Ronald', 1068722, 1776103)
# (1984, 'Hawaii', 'Mondale, Walter', 147154, 'Reagan, Ronald', 185050, 335846)
# (1984, 'Idaho', 'Mondale, Walter', 108510, 'Reagan, Ronald', 297523, 411144)
# (1984, 'Illinois', 'Mondale, Walter', 2086499, 'Reagan, Ronald', 2707103, 4819088)
# (1984, 'Indiana', 'Mondale, Walter', 841481, 'Reagan, Ronald', 1377230, 2233069)
# (1984, 'Iowa', 'Mondale, Walter', 605620, 'Reagan, Ronald', 703088, 1319805)
# (1984, 'Kansas', 'Mondale, Walter', 333149, 'Reagan, Ronald', 677296, 1021991)
# (1984, 'Kentucky', 'Mondale, Walter', 539539, 'Reagan, Ronald', 821702, 1369345)
# (1984, 'Louisiana', 'Mondale, Walter', 651586, 'Reagan, Ronald', 1037299, 1706822)
# (1984, 'Maine', 'Mondale, Walter', 214515, 'Reagan, Ronald', 336500, 553144)
# (1984, 'Maryland', 'Mondale, Walter', 787935, 'Reagan, Ronald', 879918, 1675873)
# (1984, 'Massachusetts', 'Mondale, Walter', 1239606, 'Reagan, Ronald', 1310936, 2559383)
# (1984, 'Michigan', 'Mondale, Walter', 1529638, 'Reagan, Ronald', 2251571, 3801658)
# (1984, 'Minnesota', 'Mondale, Walter', 1036364, 'Reagan, Ronald', 1032603, 2084449)
# (1984, 'Mississippi', 'Mondale, Walter', 352192, 'Reagan, Ronald', 582377, 941104)
# (1984, 'Missouri', 'Mondale, Walter', 848583, 'Reagan, Ronald', 1274188, 2122771)
# (1984, 'Montana', 'Mondale, Walter', 146742, 'Reagan, Ronald', 232450, 384377)
# (1984, 'Nebraska', 'Mondale, Walter', 187866, 'Reagan, Ronald', 460054, 652090)
# (1984, 'Nevada', 'Mondale, Walter', 91655, 'Reagan, Ronald', 188770, 282717)
# (1984, 'New Hampshire', 'Mondale, Walter', 120347, 'Reagan, Ronald', 267050, 388904)
# (1984, 'New Jersey', 'Mondale, Walter', 1261323, 'Reagan, Ronald', 1933630, 3217862)
# (1984, 'New Mexico', 'Mondale, Walter', 201769, 'Reagan, Ronald', 307101, 514370)
# (1984, 'New York', 'Mondale, Walter', 3001285, 'Reagan, Ronald', 3376519, 6806810)
# (1984, 'North Carolina', 'Mondale, Walter', 824287, 'Reagan, Ronald', 1346481, 2175361)
# (1984, 'North Dakota', 'Mondale, Walter', 104429, 'Reagan, Ronald', 200336, 308971)
# (1984, 'Ohio', 'Mondale, Walter', 1825440, 'Reagan, Ronald', 2678559, 4563235)
# (1984, 'Oklahoma', 'Mondale, Walter', 385080, 'Reagan, Ronald', 861530, 1255676)
# (1984, 'Oregon', 'Mondale, Walter', 536479, 'Reagan, Ronald', 685700, 1226527)
# (1984, 'Pennsylvania', 'Mondale, Walter', 2228131, 'Reagan, Ronald', 2584323, 4844903)
# (1984, 'Rhode Island', 'Mondale, Walter', 197106, 'Reagan, Ronald', 212080, 410489)
# (1984, 'South Carolina', 'Mondale, Walter', 344459, 'Reagan, Ronald', 615539, 968529)
# (1984, 'South Dakota', 'Mondale, Walter', 116113, 'Reagan, Ronald', 200267, 317867)
# (1984, 'Tennessee', 'Mondale, Walter', 711714, 'Reagan, Ronald', 990212, 1711993)
# (1984, 'Texas', 'Mondale, Walter', 1949276, 'Reagan, Ronald', 3433428, 5397571)
# (1984, 'Utah', 'Mondale, Walter', 155369, 'Reagan, Ronald', 469105, 629656)
# (1984, 'Vermont', 'Mondale, Walter', 95730, 'Reagan, Ronald', 135865, 234561)
# (1984, 'Virginia', 'Mondale, Walter', 796250, 'Reagan, Ronald', 1337078, 2146635)
# (1984, 'Washington', 'Mondale, Walter', 798352, 'Reagan, Ronald', 1051670, 1874910)
# (1984, 'West Virginia', 'Mondale, Walter', 328125, 'Reagan, Ronald', 405483, 735742)
# (1984, 'Wisconsin', 'Mondale, Walter', 995740, 'Reagan, Ronald', 1198584, 2211689)
# (1984, 'Wyoming', 'Mondale, Walter', 53370, 'Reagan, Ronald', 133241, 188968)
# (1988, 'Alabama', 'Dukakis, Michael', 549506, 'Bush, George H.W.', 815576, 1378476)
# (1988, 'Alaska', 'Dukakis, Michael', 72584, 'Bush, George H.W.', 119251, 200116)
# (1988, 'Arizona', 'Dukakis, Michael', 454029, 'Bush, George H.W.', 702541, 1171873)
# (1988, 'Arkansas', 'Dukakis, Michael', 349237, 'Bush, George H.W.', 466578, 827738)
# (1988, 'California', 'Dukakis, Michael', 4702233, 'Bush, George H.W.', 5054917, 9887065)
# (1988, 'Colorado', 'Dukakis, Michael', 621453, 'Bush, George H.W.', 728177, 1372394)
# (1988, 'Connecticut', 'Dukakis, Michael', 676584, 'Bush, George H.W.', 750241, 1443394)
# (1988, 'Delaware', 'Dukakis, Michael', 108647, 'Bush, George H.W.', 139639, 249891)
# (1988, 'District of Columbia', 'Dukakis, Michael', 159407, 'Bush, George H.W.', 27590, 192877)
# (1988, 'Florida', 'Dukakis, Michael', 1656701, 'Bush, George H.W.', 2618885, 4302313)
# (1988, 'Georgia', 'Dukakis, Michael', 714792, 'Bush, George H.W.', 1081331, 1809672)
# (1988, 'Hawaii', 'Dukakis, Michael', 192364, 'Bush, George H.W.', 158625, 354461)
# (1988, 'Idaho', 'Dukakis, Michael', 147272, 'Bush, George H.W.', 253881, 408968)
# (1988, 'Illinois', 'Dukakis, Michael', 2215940, 'Bush, George H.W.', 2310939, 4559120)
# (1988, 'Indiana', 'Dukakis, Michael', 860643, 'Bush, George H.W.', 1297763, 2168621)
# (1988, 'Iowa', 'Dukakis, Michael', 670557, 'Bush, George H.W.', 545355, 1225614)
# (1988, 'Kansas', 'Dukakis, Michael', 422636, 'Bush, George H.W.', 554049, 993044)
# (1988, 'Kentucky', 'Dukakis, Michael', 580368, 'Bush, George H.W.', 734281, 1322517)
# (1988, 'Louisiana', 'Dukakis, Michael', 717460, 'Bush, George H.W.', 883702, 1628202)
# (1988, 'Maine', 'Dukakis, Michael', 243569, 'Bush, George H.W.', 307131, 555035)
# (1988, 'Maryland', 'Dukakis, Michael', 826304, 'Bush, George H.W.', 876167, 1714358)
# (1988, 'Massachusetts', 'Dukakis, Michael', 1401415, 'Bush, George H.W.', 1194635, 2632801)
# (1988, 'Michigan', 'Dukakis, Michael', 1675783, 'Bush, George H.W.', 1965486, 3669163)
# (1988, 'Minnesota', 'Dukakis, Michael', 1109471, 'Bush, George H.W.', 962337, 2096790)
# (1988, 'Mississippi', 'Dukakis, Michael', 363921, 'Bush, George H.W.', 557890, 931527)
# (1988, 'Missouri', 'Dukakis, Michael', 1001619, 'Bush, George H.W.', 1084953, 2093228)
# (1988, 'Montana', 'Dukakis, Michael', 168936, 'Bush, George H.W.', 190412, 365674)
# (1988, 'Nebraska', 'Dukakis, Michael', 259235, 'Bush, George H.W.', 397956, 661465)
# (1988, 'Nevada', 'Dukakis, Michael', 132738, 'Bush, George H.W.', 206040, 343133)
# (1988, 'New Hampshire', 'Dukakis, Michael', 163696, 'Bush, George H.W.', 281537, 450525)
# (1988, 'New Jersey', 'Dukakis, Michael', 1320352, 'Bush, George H.W.', 1743192, 3099553)
# (1988, 'New Mexico', 'Dukakis, Michael', 244497, 'Bush, George H.W.', 270341, 521387)
# (1988, 'New York', 'Dukakis, Michael', 3255487, 'Bush, George H.W.', 2838414, 6485683)
# (1988, 'North Carolina', 'Dukakis, Michael', 890167, 'Bush, George H.W.', 1237258, 2134370)
# (1988, 'North Dakota', 'Dukakis, Michael', 127739, 'Bush, George H.W.', 166559, 297261)
# (1988, 'Ohio', 'Dukakis, Michael', 1939629, 'Bush, George H.W.', 2416549, 4393585)
# (1988, 'Oklahoma', 'Dukakis, Michael', 483423, 'Bush, George H.W.', 678367, 1171036)
# (1988, 'Oregon', 'Dukakis, Michael', 616206, 'Bush, George H.W.', 560126, 1201694)
# (1988, 'Pennsylvania', 'Dukakis, Michael', 2194944, 'Bush, George H.W.', 2300087, 4536251)
# (1988, 'Rhode Island', 'Dukakis, Michael', 225123, 'Bush, George H.W.', 177761, 404622)
# (1988, 'South Carolina', 'Dukakis, Michael', 370554, 'Bush, George H.W.', 606443, 986009)
# (1988, 'South Dakota', 'Dukakis, Michael', 145560, 'Bush, George H.W.', 165415, 312991)
# (1988, 'Tennessee', 'Dukakis, Michael', 679794, 'Bush, George H.W.', 947233, 1636250)
# (1988, 'Texas', 'Dukakis, Michael', 2352748, 'Bush, George H.W.', 3036829, 5427410)
# (1988, 'Utah', 'Dukakis, Michael', 207343, 'Bush, George H.W.', 428442, 647008)
# (1988, 'Vermont', 'Dukakis, Michael', 115775, 'Bush, George H.W.', 124331, 243328)
# (1988, 'Virginia', 'Dukakis, Michael', 859799, 'Bush, George H.W.', 1309162, 2191609)
# (1988, 'Washington', 'Dukakis, Michael', 933516, 'Bush, George H.W.', 903835, 1865253)
# (1988, 'West Virginia', 'Dukakis, Michael', 341016, 'Bush, George H.W.', 310065, 653311)
# (1988, 'Wisconsin', 'Dukakis, Michael', 1126794, 'Bush, George H.W.', 1047499, 2191608)
# (1988, 'Wyoming', 'Dukakis, Michael', 67113, 'Bush, George H.W.', 106867, 176551)
# (1992, 'Alabama', 'Clinton, Bill', 690080, 'Bush, George H.W.', 804283, 1688060)
# (1992, 'Alaska', 'Clinton, Bill', 78294, 'Bush, George H.W.', 102000, 258506)
# (1992, 'Arizona', 'Clinton, Bill', 543050, 'Bush, George H.W.', 572086, 1486975)
# (1992, 'Arkansas', 'Clinton, Bill', 505823, 'Bush, George H.W.', 337324, 950653)
# (1992, 'California', 'Clinton, Bill', 5121325, 'Bush, George H.W.', 3630574, 11131721)
# (1992, 'Colorado', 'Clinton, Bill', 629681, 'Bush, George H.W.', 562850, 1569180)
# (1992, 'Connecticut', 'Clinton, Bill', 682318, 'Bush, George H.W.', 578313, 1616156)
# (1992, 'Delaware', 'Clinton, Bill', 126054, 'Bush, George H.W.', 102313, 289620)
# (1992, 'District of Columbia', 'Clinton, Bill', 192619, 'Bush, George H.W.', 20698, 227572)
# (1992, 'Florida', 'Clinton, Bill', 2071698, 'Bush, George H.W.', 2173310, 5313392)
# (1992, 'Georgia', 'Clinton, Bill', 1008966, 'Bush, George H.W.', 995252, 2321133)
# (1992, 'Hawaii', 'Clinton, Bill', 179310, 'Bush, George H.W.', 136822, 372842)
# (1992, 'Idaho', 'Clinton, Bill', 137013, 'Bush, George H.W.', 202645, 482114)
# (1992, 'Illinois', 'Clinton, Bill', 2453350, 'Bush, George H.W.', 1734096, 5050157)
# (1992, 'Indiana', 'Clinton, Bill', 848420, 'Bush, George H.W.', 989375, 2305871)
# (1992, 'Iowa', 'Clinton, Bill', 586353, 'Bush, George H.W.', 504891, 1354607)
# (1992, 'Kansas', 'Clinton, Bill', 390434, 'Bush, George H.W.', 449951, 1157236)
# (1992, 'Kentucky', 'Clinton, Bill', 665104, 'Bush, George H.W.', 617178, 1492900)
# (1992, 'Louisiana', 'Clinton, Bill', 815971, 'Bush, George H.W.', 733386, 1790017)
# (1992, 'Maine', 'Clinton, Bill', 263420, 'Bush, George H.W.', 206504, 679499)
# (1992, 'Maryland', 'Clinton, Bill', 988571, 'Bush, George H.W.', 707094, 1984580)
# (1992, 'Massachusetts', 'Clinton, Bill', 1318639, 'Bush, George H.W.', 805039, 2773664)
# (1992, 'Michigan', 'Clinton, Bill', 1871182, 'Bush, George H.W.', 1554940, 4274673)
# (1992, 'Minnesota', 'Clinton, Bill', 1020997, 'Bush, George H.W.', 747841, 2347948)
# (1992, 'Mississippi', 'Clinton, Bill', 400258, 'Bush, George H.W.', 487793, 981793)
# (1992, 'Missouri', 'Clinton, Bill', 1053873, 'Bush, George H.W.', 811159, 2391270)
# (1992, 'Montana', 'Clinton, Bill', 154507, 'Bush, George H.W.', 144207, 410583)
# (1992, 'Nebraska', 'Clinton, Bill', 216864, 'Bush, George H.W.', 343678, 737546)
# (1992, 'Nevada', 'Clinton, Bill', 189148, 'Bush, George H.W.', 175828, 506318)
# (1992, 'New Hampshire', 'Clinton, Bill', 209040, 'Bush, George H.W.', 202484, 537215)
# (1992, 'New Jersey', 'Clinton, Bill', 1436206, 'Bush, George H.W.', 1356865, 3343594)
# (1992, 'New Mexico', 'Clinton, Bill', 261617, 'Bush, George H.W.', 212824, 569986)
# (1992, 'New York', 'Clinton, Bill', 3346894, 'Bush, George H.W.', 2041690, 7079432)
# (1992, 'North Carolina', 'Clinton, Bill', 1114042, 'Bush, George H.W.', 1134661, 2611850)
# (1992, 'North Dakota', 'Clinton, Bill', 99168, 'Bush, George H.W.', 136244, 308133)
# (1992, 'Ohio', 'Clinton, Bill', 1984942, 'Bush, George H.W.', 1894310, 4939967)
# (1992, 'Oklahoma', 'Clinton, Bill', 473066, 'Bush, George H.W.', 592929, 1390359)
# (1992, 'Oregon', 'Clinton, Bill', 621314, 'Bush, George H.W.', 475757, 1462643)
# (1992, 'Pennsylvania', 'Clinton, Bill', 2239164, 'Bush, George H.W.', 1791841, 4959810)
# (1992, 'Rhode Island', 'Clinton, Bill', 213299, 'Bush, George H.W.', 131601, 453365)
# (1992, 'South Carolina', 'Clinton, Bill', 525514, 'Bush, George H.W.', 577507, 1228912)
# (1992, 'South Dakota', 'Clinton, Bill', 124888, 'Bush, George H.W.', 136718, 336254)
# (1992, 'Tennessee', 'Clinton, Bill', 933521, 'Bush, George H.W.', 841300, 1982638)
# (1992, 'Texas', 'Clinton, Bill', 2281815, 'Bush, George H.W.', 2496071, 6154018)
# (1992, 'Utah', 'Clinton, Bill', 183429, 'Bush, George H.W.', 322632, 743998)
# (1992, 'Vermont', 'Clinton, Bill', 133592, 'Bush, George H.W.', 88122, 289701)
# (1992, 'Virginia', 'Clinton, Bill', 1038650, 'Bush, George H.W.', 1150517, 2559129)
# (1992, 'Washington', 'Clinton, Bill', 993037, 'Bush, George H.W.', 731234, 2287565)
# (1992, 'West Virginia', 'Clinton, Bill', 331001, 'Bush, George H.W.', 241974, 683677)
# (1992, 'Wisconsin', 'Clinton, Bill', 1041066, 'Bush, George H.W.', 930855, 2531064)
# (1992, 'Wyoming', 'Clinton, Bill', 68160, 'Bush, George H.W.', 79347, 199884)
# (1996, 'Alabama', 'Clinton, Bill', 662165, 'Dole, Robert', 769044, 1534349)
# (1996, 'Alaska', 'Clinton, Bill', 80380, 'Dole, Robert', 122746, 241620)
# (1996, 'Arizona', 'Clinton, Bill', 653288, 'Dole, Robert', 622073, 1404405)
# (1996, 'Arkansas', 'Clinton, Bill', 475171, 'Dole, Robert', 325416, 884262)
# (1996, 'California', 'Clinton, Bill', 5119835, 'Dole, Robert', 3828381, 10019469)
# (1996, 'Colorado', 'Clinton, Bill', 671152, 'Dole, Robert', 691848, 1510702)
# (1996, 'Connecticut', 'Clinton, Bill', 735740, 'Dole, Robert', 483109, 1392614)
# (1996, 'Delaware', 'Clinton, Bill', 140355, 'Dole, Robert', 99062, 270810)
# (1996, 'District of Columbia', 'Clinton, Bill', 158220, 'Dole, Robert', 17339, 185726)
# (1996, 'Florida', 'Clinton, Bill', 2546870, 'Dole, Robert', 2244536, 5303154)
# (1996, 'Georgia', 'Clinton, Bill', 1053849, 'Dole, Robert', 1080843, 2298899)
# (1996, 'Hawaii', 'Clinton, Bill', 205012, 'Dole, Robert', 113943, 360120)
# (1996, 'Idaho', 'Clinton, Bill', 165443, 'Dole, Robert', 256595, 491711)
# (1996, 'Illinois', 'Clinton, Bill', 2341744, 'Dole, Robert', 1587021, 4311391)
# (1996, 'Indiana', 'Clinton, Bill', 887424, 'Dole, Robert', 1006693, 2135431)
# (1996, 'Iowa', 'Clinton, Bill', 620258, 'Dole, Robert', 492644, 1234075)
# (1996, 'Kansas', 'Clinton, Bill', 387659, 'Dole, Robert', 583245, 1074300)
# (1996, 'Kentucky', 'Clinton, Bill', 636614, 'Dole, Robert', 623283, 1388708)
# (1996, 'Louisiana', 'Clinton, Bill', 927837, 'Dole, Robert', 712586, 1783959)
# (1996, 'Maine', 'Clinton, Bill', 312788, 'Dole, Robert', 186378, 605897)
# (1996, 'Maryland', 'Clinton, Bill', 966207, 'Dole, Robert', 681530, 1780870)
# (1996, 'Massachusetts', 'Clinton, Bill', 1571509, 'Dole, Robert', 718058, 2556459)
# (1996, 'Michigan', 'Clinton, Bill', 1989653, 'Dole, Robert', 1481212, 3848844)
# (1996, 'Minnesota', 'Clinton, Bill', 1120380, 'Dole, Robert', 766395, 2192492)
# (1996, 'Mississippi', 'Clinton, Bill', 394022, 'Dole, Robert', 439838, 893857)
# (1996, 'Missouri', 'Clinton, Bill', 1025935, 'Dole, Robert', 890016, 2158065)
# (1996, 'Montana', 'Clinton, Bill', 167922, 'Dole, Robert', 179652, 407083)
# (1996, 'Nebraska', 'Clinton, Bill', 236761, 'Dole, Robert', 363467, 677415)
# (1996, 'Nevada', 'Clinton, Bill', 203974, 'Dole, Robert', 199244, 464279)
# (1996, 'New Hampshire', 'Clinton, Bill', 246166, 'Dole, Robert', 196486, 496597)
# (1996, 'New Jersey', 'Clinton, Bill', 1652361, 'Dole, Robert', 1103099, 3075860)
# (1996, 'New Mexico', 'Clinton, Bill', 273495, 'Dole, Robert', 232751, 556074)
# (1996, 'New York', 'Clinton, Bill', 3649630, 'Dole, Robert', 1738707, 6439129)
# (1996, 'North Carolina', 'Clinton, Bill', 1107849, 'Dole, Robert', 1225938, 2515807)
# (1996, 'North Dakota', 'Clinton, Bill', 106905, 'Dole, Robert', 125050, 266411)
# (1996, 'Ohio', 'Clinton, Bill', 2148222, 'Dole, Robert', 1859883, 4534434)
# (1996, 'Oklahoma', 'Clinton, Bill', 488105, 'Dole, Robert', 582315, 1206713)
# (1996, 'Oregon', 'Clinton, Bill', 649641, 'Dole, Robert', 538152, 1377760)
# (1996, 'Pennsylvania', 'Clinton, Bill', 2215819, 'Dole, Robert', 1801169, 4501307)
# (1996, 'Rhode Island', 'Clinton, Bill', 233050, 'Dole, Robert', 104683, 390247)
# (1996, 'South Carolina', 'Clinton, Bill', 506152, 'Dole, Robert', 573339, 1150182)
# (1996, 'South Dakota', 'Clinton, Bill', 139333, 'Dole, Robert', 150543, 323826)
# (1996, 'Tennessee', 'Clinton, Bill', 909146, 'Dole, Robert', 863530, 1894105)
# (1996, 'Texas', 'Clinton, Bill', 2459683, 'Dole, Robert', 2736167, 5611644)
# (1996, 'Utah', 'Clinton, Bill', 221633, 'Dole, Robert', 361911, 665629)
# (1996, 'Vermont', 'Clinton, Bill', 137894, 'Dole, Robert', 80352, 258449)
# (1996, 'Virginia', 'Clinton, Bill', 1091060, 'Dole, Robert', 1138350, 2416642)
# (1996, 'Washington', 'Clinton, Bill', 1123323, 'Dole, Robert', 840712, 2253837)
# (1996, 'West Virginia', 'Clinton, Bill', 327812, 'Dole, Robert', 233946, 636459)
# (1996, 'Wisconsin', 'Clinton, Bill', 1071971, 'Dole, Robert', 845029, 2196169)
# (1996, 'Wyoming', 'Clinton, Bill', 77934, 'Dole, Robert', 105388, 211571)
# (2000, 'Alabama', 'Gore, Al', 692611, 'Bush, George W.', 941173, 1666272)
# (2000, 'Alaska', 'Gore, Al', 79004, 'Bush, George W.', 167398, 285560)
# (2000, 'Arizona', 'Gore, Al', 685341, 'Bush, George W.', 781652, 1532016)
# (2000, 'Arkansas', 'Gore, Al', 422768, 'Bush, George W.', 472940, 921781)
# (2000, 'California', 'Gore, Al', 5861203, 'Bush, George W.', 4567429, 10965822)
# (2000, 'Colorado', 'Gore, Al', 738227, 'Bush, George W.', 883748, 1741368)
# (2000, 'Connecticut', 'Gore, Al', 816015, 'Bush, George W.', 561094, 1459525)
# (2000, 'Delaware', 'Gore, Al', 180068, 'Bush, George W.', 137288, 327529)
# (2000, 'District of Columbia', 'Gore, Al', 171923, 'Bush, George W.', 18073, 201894)
# (2000, 'Florida', 'Gore, Al', 2912253, 'Bush, George W.', 2912790, 5963110)
# (2000, 'Georgia', 'Gore, Al', 1116230, 'Bush, George W.', 1419720, 2583208)
# (2000, 'Hawaii', 'Gore, Al', 205286, 'Bush, George W.', 137845, 367951)
# (2000, 'Idaho', 'Gore, Al', 138637, 'Bush, George W.', 336937, 501615)
# (2000, 'Illinois', 'Gore, Al', 2589026, 'Bush, George W.', 2019421, 4742108)
# (2000, 'Indiana', 'Gore, Al', 901980, 'Bush, George W.', 1245836, 2199302)
# (2000, 'Iowa', 'Gore, Al', 638517, 'Bush, George W.', 634373, 1353022)
# (2000, 'Kansas', 'Gore, Al', 399276, 'Bush, George W.', 622332, 1072216)
# (2000, 'Kentucky', 'Gore, Al', 638923, 'Bush, George W.', 872520, 1544106)
# (2000, 'Louisiana', 'Gore, Al', 792344, 'Bush, George W.', 927871, 1765656)
# (2000, 'Maine', 'Gore, Al', 319951, 'Bush, George W.', 286616, 651817)
# (2000, 'Maryland', 'Gore, Al', 1144008, 'Bush, George W.', 813827, 2025212)
# (2000, 'Massachusetts', 'Gore, Al', 1616487, 'Bush, George W.', 878502, 2733964)
# (2000, 'Michigan', 'Gore, Al', 2170418, 'Bush, George W.', 1953139, 4232501)
# (2000, 'Minnesota', 'Gore, Al', 1168266, 'Bush, George W.', 1109659, 2438685)
# (2000, 'Mississippi', 'Gore, Al', 404614, 'Bush, George W.', 572844, 994184)
# (2000, 'Missouri', 'Gore, Al', 1111138, 'Bush, George W.', 1189924, 2359892)
# (2000, 'Montana', 'Gore, Al', 137126, 'Bush, George W.', 240178, 410986)
# (2000, 'Nebraska', 'Gore, Al', 231780, 'Bush, George W.', 433862, 697019)
# (2000, 'Nevada', 'Gore, Al', 279978, 'Bush, George W.', 301575, 609426)
# (2000, 'New Hampshire', 'Gore, Al', 266348, 'Bush, George W.', 273559, 569081)
# (2000, 'New Jersey', 'Gore, Al', 1788850, 'Bush, George W.', 1284173, 3187226)
# (2000, 'New Mexico', 'Gore, Al', 286783, 'Bush, George W.', 286417, 598605)
# (2000, 'New York', 'Gore, Al', 3942215, 'Bush, George W.', 2258577, 6960215)
# (2000, 'North Carolina', 'Gore, Al', 1257692, 'Bush, George W.', 1631163, 2914990)
# (2000, 'North Dakota', 'Gore, Al', 95284, 'Bush, George W.', 174852, 288256)
# (2000, 'Ohio', 'Gore, Al', 2183628, 'Bush, George W.', 2350363, 4701998)
# (2000, 'Oklahoma', 'Gore, Al', 474276, 'Bush, George W.', 744337, 1234229)
# (2000, 'Oregon', 'Gore, Al', 720342, 'Bush, George W.', 713577, 1533950)
# (2000, 'Pennsylvania', 'Gore, Al', 2485967, 'Bush, George W.', 2281127, 4912185)
# (2000, 'Rhode Island', 'Gore, Al', 249508, 'Bush, George W.', 130555, 409112)
# (2000, 'South Carolina', 'Gore, Al', 566037, 'Bush, George W.', 786892, 1383902)
# (2000, 'South Dakota', 'Gore, Al', 118804, 'Bush, George W.', 190700, 316269)
# (2000, 'Tennessee', 'Gore, Al', 981720, 'Bush, George W.', 1061949, 2076181)
# (2000, 'Texas', 'Gore, Al', 2433746, 'Bush, George W.', 3799639, 6407637)
# (2000, 'Utah', 'Gore, Al', 203053, 'Bush, George W.', 515096, 770754)
# (2000, 'Vermont', 'Gore, Al', 149022, 'Bush, George W.', 119775, 294308)
# (2000, 'Virginia', 'Gore, Al', 1217290, 'Bush, George W.', 1437490, 2739447)
# (2000, 'Washington', 'Gore, Al', 1247652, 'Bush, George W.', 1108864, 2487433)
# (2000, 'West Virginia', 'Gore, Al', 295497, 'Bush, George W.', 336475, 648124)
# (2000, 'Wisconsin', 'Gore, Al', 1242987, 'Bush, George W.', 1237279, 2598607)
# (2000, 'Wyoming', 'Gore, Al', 60481, 'Bush, George W.', 147947, 213726)
# (2004, 'Alabama', 'Kerry, John', 693933, 'Bush, George W.', 1176394, 1883415)
# (2004, 'Alaska', 'Kerry, John', 111025, 'Bush, George W.', 190889, 312598)
# (2004, 'Arizona', 'Kerry, John', 893524, 'Bush, George W.', 1104294, 2012585)
# (2004, 'Arkansas', 'Kerry, John', 469953, 'Bush, George W.', 572898, 1054945)
# (2004, 'California', 'Kerry, John', 6745485, 'Bush, George W.', 5509826, 12421353)
# (2004, 'Colorado', 'Kerry, John', 1001732, 'Bush, George W.', 1101255, 2129630)
# (2004, 'Connecticut', 'Kerry, John', 857488, 'Bush, George W.', 693826, 1578769)
# (2004, 'Delaware', 'Kerry, John', 200152, 'Bush, George W.', 171660, 375190)
# (2004, 'District of Columbia', 'Kerry, John', 202970, 'Bush, George W.', 21256, 227586)
# (2004, 'Florida', 'Kerry, John', 3583544, 'Bush, George W.', 3964522, 7609810)
# (2004, 'Georgia', 'Kerry, John', 1366149, 'Bush, George W.', 1914254, 3301875)
# (2004, 'Hawaii', 'Kerry, John', 231708, 'Bush, George W.', 194191, 429013)
# (2004, 'Idaho', 'Kerry, John', 181098, 'Bush, George W.', 409235, 598376)
# (2004, 'Illinois', 'Kerry, John', 2891550, 'Bush, George W.', 2345946, 5274322)
# (2004, 'Indiana', 'Kerry, John', 969011, 'Bush, George W.', 1479438, 2468002)
# (2004, 'Iowa', 'Kerry, John', 741898, 'Bush, George W.', 751957, 1506908)
# (2004, 'Kansas', 'Kerry, John', 434993, 'Bush, George W.', 736456, 1187756)
# (2004, 'Kentucky', 'Kerry, John', 712733, 'Bush, George W.', 1069439, 1795882)
# (2004, 'Louisiana', 'Kerry, John', 820299, 'Bush, George W.', 1102169, 1943106)
# (2004, 'Maine', 'Kerry, John', 396842, 'Bush, George W.', 330201, 740752)
# (2004, 'Maryland', 'Kerry, John', 1334493, 'Bush, George W.', 1024703, 2384238)
# (2004, 'Massachusetts', 'Kerry, John', 1803800, 'Bush, George W.', 1071109, 2927455)
# (2004, 'Michigan', 'Kerry, John', 2479183, 'Bush, George W.', 2313746, 4839252)
# (2004, 'Minnesota', 'Kerry, John', 1445014, 'Bush, George W.', 1346695, 2828387)
# (2004, 'Mississippi', 'Kerry, John', 457766, 'Bush, George W.', 672660, 1139824)
# (2004, 'Missouri', 'Kerry, John', 1259171, 'Bush, George W.', 1455713, 2731364)
# (2004, 'Montana', 'Kerry, John', 173710, 'Bush, George W.', 266063, 450434)
# (2004, 'Nebraska', 'Kerry, John', 254328, 'Bush, George W.', 512814, 778186)
# (2004, 'Nevada', 'Kerry, John', 397190, 'Bush, George W.', 418690, 829587)
# (2004, 'New Hampshire', 'Kerry, John', 340511, 'Bush, George W.', 331237, 678287)
# (2004, 'New Jersey', 'Kerry, John', 1911430, 'Bush, George W.', 1670003, 3611691)
# (2004, 'New Mexico', 'Kerry, John', 370942, 'Bush, George W.', 376930, 756304)
# (2004, 'New York', 'Kerry, John', 4180755, 'Bush, George W.', 2806993, 7448266)
# (2004, 'North Carolina', 'Kerry, John', 1525849, 'Bush, George W.', 1961166, 3501007)
# (2004, 'North Dakota', 'Kerry, John', 111052, 'Bush, George W.', 196651, 312833)
# (2004, 'Ohio', 'Kerry, John', 2741165, 'Bush, George W.', 2859764, 5627903)
# (2004, 'Oklahoma', 'Kerry, John', 503966, 'Bush, George W.', 959792, 1463758)
# (2004, 'Oregon', 'Kerry, John', 943163, 'Bush, George W.', 866831, 1836782)
# (2004, 'Pennsylvania', 'Kerry, John', 2938095, 'Bush, George W.', 2793847, 5769590)
# (2004, 'Rhode Island', 'Kerry, John', 259760, 'Bush, George W.', 169046, 437134)
# (2004, 'South Carolina', 'Kerry, John', 661669, 'Bush, George W.', 937974, 1617700)
# (2004, 'South Dakota', 'Kerry, John', 149244, 'Bush, George W.', 232584, 388215)
# (2004, 'Tennessee', 'Kerry, John', 1036477, 'Bush, George W.', 1384375, 2437319)
# (2004, 'Texas', 'Kerry, John', 2832704, 'Bush, George W.', 4526917, 7410749)
# (2004, 'Utah', 'Kerry, John', 241199, 'Bush, George W.', 663742, 927844)
# (2004, 'Vermont', 'Kerry, John', 184067, 'Bush, George W.', 121180, 312309)
# (2004, 'Virginia', 'Kerry, John', 1454742, 'Bush, George W.', 1716959, 3195415)
# (2004, 'Washington', 'Kerry, John', 1510201, 'Bush, George W.', 1304894, 2859084)
# (2004, 'West Virginia', 'Kerry, John', 326541, 'Bush, George W.', 423778, 755792)
# (2004, 'Wisconsin', 'Kerry, John', 1489504, 'Bush, George W.', 1478120, 2997007)
# (2004, 'Wyoming', 'Kerry, John', 70776, 'Bush, George W.', 167629, 243861)
# (2008, 'Alabama', 'Obama, Barack H.', 813479, 'McCain, John', 1266546, 2099819)
# (2008, 'Alaska', 'Obama, Barack H.', 123594, 'McCain, John', 193841, 326197)
# (2008, 'Arizona', 'Obama, Barack H.', 1034707, 'McCain, John', 1230111, 2293475)
# (2008, 'Arkansas', 'Obama, Barack H.', 422310, 'McCain, John', 638017, 1086617)
# (2008, 'California', 'Obama, Barack H.', 8274473, 'McCain, John', 5011781, 13561900)
# (2008, 'Colorado', 'Obama, Barack H.', 1288576, 'McCain, John', 1073589, 2401361)
# (2008, 'Connecticut', 'Obama, Barack H.', 997772, 'McCain, John', 629428, 1646792)
# (2008, 'Delaware', 'Obama, Barack H.', 255459, 'McCain, John', 152374, 412412)
# (2008, 'District of Columbia', 'Obama, Barack H.', 245800, 'McCain, John', 17367, 265853)
# (2008, 'Florida', 'Obama, Barack H.', 4282074, 'McCain, John', 4045624, 8390744)
# (2008, 'Georgia', 'Obama, Barack H.', 1844123, 'McCain, John', 2048759, 3924486)
# (2008, 'Hawaii', 'Obama, Barack H.', 325871, 'McCain, John', 120566, 456064)
# (2008, 'Idaho', 'Obama, Barack H.', 236440, 'McCain, John', 403012, 655122)
# (2008, 'Illinois', 'Obama, Barack H.', 3419348, 'McCain, John', 2031179, 5522371)
# (2008, 'Indiana', 'Obama, Barack H.', 1374039, 'McCain, John', 1345648, 2751054)
# (2008, 'Iowa', 'Obama, Barack H.', 828940, 'McCain, John', 682379, 1537123)
# (2008, 'Kansas', 'Obama, Barack H.', 514765, 'McCain, John', 699655, 1235872)
# (2008, 'Kentucky', 'Obama, Barack H.', 751985, 'McCain, John', 1048462, 1826620)
# (2008, 'Louisiana', 'Obama, Barack H.', 782989, 'McCain, John', 1148275, 1960761)
# (2008, 'Maine', 'Obama, Barack H.', 421923, 'McCain, John', 295273, 731163)
# (2008, 'Maryland', 'Obama, Barack H.', 1629467, 'McCain, John', 959862, 2631596)
# (2008, 'Massachusetts', 'Obama, Barack H.', 1904097, 'McCain, John', 1108854, 3102995)
# (2008, 'Michigan', 'Obama, Barack H.', 2872579, 'McCain, John', 2048639, 5001596)
# (2008, 'Minnesota', 'Obama, Barack H.', 1573354, 'McCain, John', 1275409, 2910369)
# (2008, 'Mississippi', 'Obama, Barack H.', 554662, 'McCain, John', 724597, 1289865)
# (2008, 'Missouri', 'Obama, Barack H.', 1441911, 'McCain, John', 1445814, 2925205)
# (2008, 'Montana', 'Obama, Barack H.', 231667, 'McCain, John', 242763, 490109)
# (2008, 'Nebraska', 'Obama, Barack H.', 333319, 'McCain, John', 452979, 801281)
# (2008, 'Nevada', 'Obama, Barack H.', 533736, 'McCain, John', 412827, 967848)
# (2008, 'New Hampshire', 'Obama, Barack H.', 384826, 'McCain, John', 316534, 710970)
# (2008, 'New Jersey', 'Obama, Barack H.', 2215422, 'McCain, John', 1613207, 3868237)
# (2008, 'New Mexico', 'Obama, Barack H.', 472422, 'McCain, John', 346832, 830158)
# (2008, 'New York', 'Obama, Barack H.', 4645332, 'McCain, John', 2418323, 7722019)
# (2008, 'North Carolina', 'Obama, Barack H.', 2142651, 'McCain, John', 2128474, 4310851)
# (2008, 'North Dakota', 'Obama, Barack H.', 141278, 'McCain, John', 168601, 316621)
# (2008, 'Ohio', 'Obama, Barack H.', 2940044, 'McCain, John', 2677820, 5708350)
# (2008, 'Oklahoma', 'Obama, Barack H.', 502496, 'McCain, John', 960165, 1462661)
# (2008, 'Oregon', 'Obama, Barack H.', 1037291, 'McCain, John', 738475, 1827864)
# (2008, 'Pennsylvania', 'Obama, Barack H.', 3276363, 'McCain, John', 2655885, 6013272)
# (2008, 'Rhode Island', 'Obama, Barack H.', 296571, 'McCain, John', 165391, 471766)
# (2008, 'South Carolina', 'Obama, Barack H.', 862449, 'McCain, John', 1034896, 1920969)
# (2008, 'South Dakota', 'Obama, Barack H.', 170924, 'McCain, John', 203054, 381975)
# (2008, 'Tennessee', 'Obama, Barack H.', 1087437, 'McCain, John', 1479178, 2599749)
# (2008, 'Texas', 'Obama, Barack H.', 3528633, 'McCain, John', 4479328, 8077795)
# (2008, 'Utah', 'Obama, Barack H.', 327670, 'McCain, John', 596030, 952370)
# (2008, 'Vermont', 'Obama, Barack H.', 219262, 'McCain, John', 98974, 325046)
# (2008, 'Virginia', 'Obama, Barack H.', 1959532, 'McCain, John', 1725005, 3723260)
# (2008, 'Washington', 'Obama, Barack H.', 1750848, 'McCain, John', 1229216, 3036878)
# (2008, 'West Virginia', 'Obama, Barack H.', 303857, 'McCain, John', 397466, 713451)
# (2008, 'Wisconsin', 'Obama, Barack H.', 1677211, 'McCain, John', 1262393, 2983417)
# (2008, 'Wyoming', 'Obama, Barack H.', 82868, 'McCain, John', 164958, 254904)
# (2012, 'Alabama', 'Obama, Barack H.', 795696, 'Romney, Mitt', 1255925, 2074338)
# (2012, 'Alaska', 'Obama, Barack H.', 122640, 'Romney, Mitt', 164676, 300495)
# (2012, 'Arizona', 'Obama, Barack H.', 1025232, 'Romney, Mitt', 1233654, 2299254)
# (2012, 'Arkansas', 'Obama, Barack H.', 394409, 'Romney, Mitt', 647744, 1069468)
# (2012, 'California', 'Obama, Barack H.', 7854285, 'Romney, Mitt', 4839958, 13038547)
# (2012, 'Colorado', 'Obama, Barack H.', 1323101, 'Romney, Mitt', 1185243, 2569516)
# (2012, 'Connecticut', 'Obama, Barack H.', 905083, 'Romney, Mitt', 634892, 1558204)
# (2012, 'Delaware', 'Obama, Barack H.', 242584, 'Romney, Mitt', 165484, 413890)
# (2012, 'District of Columbia', 'Obama, Barack H.', 267070, 'Romney, Mitt', 21381, 293764)
# (2012, 'Florida', 'Obama, Barack H.', 4237756, 'Romney, Mitt', 4163447, 8474179)
# (2012, 'Georgia', 'Obama, Barack H.', 1773827, 'Romney, Mitt', 2078688, 3897839)
# (2012, 'Hawaii', 'Obama, Barack H.', 306658, 'Romney, Mitt', 121015, 437159)
# (2012, 'Idaho', 'Obama, Barack H.', 212787, 'Romney, Mitt', 420911, 652274)
# (2012, 'Illinois', 'Obama, Barack H.', 3019512, 'Romney, Mitt', 2135216, 5242014)
# (2012, 'Indiana', 'Obama, Barack H.', 1152887, 'Romney, Mitt', 1420543, 2624534)
# (2012, 'Iowa', 'Obama, Barack H.', 822544, 'Romney, Mitt', 730617, 1582180)
# (2012, 'Kansas', 'Obama, Barack H.', 440726, 'Romney, Mitt', 692634, 1159971)
# (2012, 'Kentucky', 'Obama, Barack H.', 679370, 'Romney, Mitt', 1087190, 1797212)
# (2012, 'Louisiana', 'Obama, Barack H.', 809141, 'Romney, Mitt', 1152262, 1994065)
# (2012, 'Maine', 'Obama, Barack H.', 401306, 'Romney, Mitt', 292276, 724758)
# (2012, 'Maryland', 'Obama, Barack H.', 1677844, 'Romney, Mitt', 971869, 2707327)
# (2012, 'Massachusetts', 'Obama, Barack H.', 1921290, 'Romney, Mitt', 1188314, 3184196)
# (2012, 'Michigan', 'Obama, Barack H.', 2564569, 'Romney, Mitt', 2115256, 4730961)
# (2012, 'Minnesota', 'Obama, Barack H.', 1546167, 'Romney, Mitt', 1320225, 2936561)
# (2012, 'Mississippi', 'Obama, Barack H.', 562949, 'Romney, Mitt', 710746, 1285584)
# (2012, 'Missouri', 'Obama, Barack H.', 1223796, 'Romney, Mitt', 1482440, 2757323)
# (2012, 'Montana', 'Obama, Barack H.', 201839, 'Romney, Mitt', 267928, 484048)
# (2012, 'Nebraska', 'Obama, Barack H.', 302081, 'Romney, Mitt', 475064, 794379)
# (2012, 'Nevada', 'Obama, Barack H.', 531373, 'Romney, Mitt', 463567, 1014918)
# (2012, 'New Hampshire', 'Obama, Barack H.', 369561, 'Romney, Mitt', 329918, 710972)
# (2012, 'New Jersey', 'Obama, Barack H.', 2122786, 'Romney, Mitt', 1478088, 3638499)
# (2012, 'New Mexico', 'Obama, Barack H.', 415335, 'Romney, Mitt', 335788, 783758)
# (2012, 'New York', 'Obama, Barack H.', 4324228, 'Romney, Mitt', 2223397, 7116784)
# (2012, 'North Carolina', 'Obama, Barack H.', 2178391, 'Romney, Mitt', 2270395, 4505372)
# (2012, 'North Dakota', 'Obama, Barack H.', 124966, 'Romney, Mitt', 188320, 322932)
# (2012, 'Ohio', 'Obama, Barack H.', 2827621, 'Romney, Mitt', 2661407, 5580822)
# (2012, 'Oklahoma', 'Obama, Barack H.', 443547, 'Romney, Mitt', 891325, 1334872)
# (2012, 'Oregon', 'Obama, Barack H.', 970488, 'Romney, Mitt', 754175, 1789270)
# (2012, 'Pennsylvania', 'Obama, Barack H.', 2990274, 'Romney, Mitt', 2680434, 5742040)
# (2012, 'Rhode Island', 'Obama, Barack H.', 279677, 'Romney, Mitt', 157204, 446049)
# (2012, 'South Carolina', 'Obama, Barack H.', 865941, 'Romney, Mitt', 1071645, 1964118)
# (2012, 'South Dakota', 'Obama, Barack H.', 145039, 'Romney, Mitt', 210610, 363815)
# (2012, 'Tennessee', 'Obama, Barack H.', 960709, 'Romney, Mitt', 1462330, 2458577)
# (2012, 'Texas', 'Obama, Barack H.', 3308124, 'Romney, Mitt', 4569843, 7993851)
# (2012, 'Utah', 'Obama, Barack H.', 251813, 'Romney, Mitt', 740600, 1017440)
# (2012, 'Vermont', 'Obama, Barack H.', 199239, 'Romney, Mitt', 92698, 299290)
# (2012, 'Virginia', 'Obama, Barack H.', 1971820, 'Romney, Mitt', 1822522, 3854489)
# (2012, 'Washington', 'Obama, Barack H.', 1755396, 'Mitt, Romney', 1290670, 3125516)
# (2012, 'West Virginia', 'Obama, Barack H.', 238269, 'Romney, Mitt', 417655, 670438)
# (2012, 'Wisconsin', 'Obama, Barack H.', 1620985, 'Romney, Mitt', 1410966, 3071434)
# (2012, 'Wyoming', 'Obama, Barack H.', 69286, 'Romney, Mitt', 170962, 250701)
# (2016, 'Alabama', 'Clinton, Hillary', 729547, 'Trump, Donald J.', 1318255, 2123372)
# (2016, 'Alaska', 'Clinton, Hillary', 116454, 'Trump, Donald J.', 163387, 318608)
# (2016, 'Arizona', 'Clinton, Hillary', 1161167, 'Trump, Donald J.', 1252401, 2573165)
# (2016, 'Arkansas', 'Clinton, Hillary', 380494, 'Trump, Donald J.', 684872, 1130635)
# (2016, 'California', 'Clinton, Hillary', 8753788, 'Trump, Donald J.', 4483810, 14181595)
# (2016, 'Colorado', 'Clinton, Hillary', 1338870, 'Trump, Donald J.', 1202484, 2780220)
# (2016, 'Connecticut', 'Clinton, Hillary', 897572, 'Trump, Donald J.', 673215, 1644920)
# (2016, 'Delaware', 'Clinton, Hillary', 235603, 'Trump, Donald J.', 185127, 441590)
# (2016, 'District of Columbia', 'Clinton, Hillary', 282830, 'Trump, Donald J.', 12723, 312575)
# (2016, 'Florida', 'Clinton, Hillary', 4504975, 'Trump, Donald J.', 4617886, 9420039)
# (2016, 'Georgia', 'Clinton, Hillary', 1877963, 'Trump, Donald J.', 2089104, 4114732)
# (2016, 'Hawaii', 'Clinton, Hillary', 266891, 'Trump, Donald J.', 128847, 437664)
# (2016, 'Idaho', 'Clinton, Hillary', 189765, 'Trump, Donald J.', 409055, 690255)
# (2016, 'Illinois', 'Clinton, Hillary', 3090729, 'Trump, Donald J.', 2146015, 5536424)
# (2016, 'Indiana', 'Clinton, Hillary', 1033126, 'Trump, Donald J.', 1557286, 2734958)
# (2016, 'Iowa', 'Clinton, Hillary', 653669, 'Trump, Donald J.', 800983, 1565580)
# (2016, 'Kansas', 'Clinton, Hillary', 427005, 'Trump, Donald J.', 671018, 1184402)
# (2016, 'Kentucky', 'Clinton, Hillary', 628854, 'Trump, Donald J.', 1202971, 1924149)
# (2016, 'Louisiana', 'Clinton, Hillary', 780154, 'Trump, Donald J.', 1178638, 2029032)
# (2016, 'Maine', 'Clinton, Hillary', 357735, 'Trump, Donald J.', 335593, 771892)
# (2016, 'Maryland', 'Clinton, Hillary', 1677928, 'Trump, Donald J.', 943169, 2781446)
# (2016, 'Massachusetts', 'Clinton, Hillary', 1995196, 'Trump, Donald J.', 1090893, 3378821)
# (2016, 'Michigan', 'Clinton, Hillary', 2268839, 'Trump, Donald J.', 2279543, 4799284)
# (2016, 'Minnesota', 'Clinton, Hillary', 1367705, 'Trump, Donald J.', 1322949, 2944782)
# (2016, 'Mississippi', 'Clinton, Hillary', 485131, 'Trump, Donald J.', 700714, 1209357)
# (2016, 'Missouri', 'Clinton, Hillary', 1071068, 'Trump, Donald J.', 1594511, 2808605)
# (2016, 'Montana', 'Clinton, Hillary', 177709, 'Trump, Donald J.', 279240, 494526)
# (2016, 'Nebraska', 'Clinton, Hillary', 284494, 'Trump, Donald J.', 495961, 844227)
# (2016, 'Nevada', 'Clinton, Hillary', 539260, 'Trump, Donald J.', 512058, 1125385)
# (2016, 'New Hampshire', 'Clinton, Hillary', 348526, 'Trump, Donald J.', 345790, 744296)
# (2016, 'New Jersey', 'Clinton, Hillary', 2148278, 'Trump, Donald J.', 1601933, 3874046)
# (2016, 'New Mexico', 'Clinton, Hillary', 385234, 'Trump, Donald J.', 319667, 798319)
# (2016, 'New York', 'Clinton, Hillary', 4379789, 'Trump, Donald J.', 2527142, 7802084)
# (2016, 'North Carolina', 'Clinton, Hillary', 2189316, 'Trump, Donald J.', 2362631, 4741564)
# (2016, 'North Dakota', 'Clinton, Hillary', 93758, 'Trump, Donald J.', 216794, 344360)
# (2016, 'Ohio', 'Clinton, Hillary', 2394164, 'Trump, Donald J.', 2841005, 5496487)
# (2016, 'Oklahoma', 'Clinton, Hillary', 420375, 'Trump, Donald J.', 949136, 1452992)
# (2016, 'Oregon', 'Clinton, Hillary', 1002106, 'Trump, Donald J.', 782403, 2001336)
# (2016, 'Pennsylvania', 'Clinton, Hillary', 2926441, 'Trump, Donald J.', 2970733, 6115402)
# (2016, 'Rhode Island', 'Clinton, Hillary', 252525, 'Trump, Donald J.', 180543, 464144)
# (2016, 'South Carolina', 'Clinton, Hillary', 855373, 'Trump, Donald J.', 1155389, 2103027)
# (2016, 'South Dakota', 'Clinton, Hillary', 117458, 'Trump, Donald J.', 227721, 370093)
# (2016, 'Tennessee', 'Clinton, Hillary', 870695, 'Trump, Donald J.', 1522925, 2508027)
# (2016, 'Texas', 'Clinton, Hillary', 3877868, 'Trump, Donald J.', 4685047, 8969226)
# (2016, 'Utah', 'Clinton, Hillary', 310674, 'Trump, Donald J.', 515211, 1131317)
# (2016, 'Vermont', 'Clinton, Hillary', 178573, 'Trump, Donald J.', 95369, 320467)
# (2016, 'Virginia', 'Clinton, Hillary', 1981473, 'Trump, Donald J.', 1769443, 3982752)
# (2016, 'Washington', 'Clinton, Hillary', 1742718, 'Trump, Donald J.', 1221747, 3317019)
# (2016, 'West Virginia', 'Clinton, Hillary', 188794, 'Trump, Donald J.', 489371, 713051)
# (2016, 'Wisconsin', 'Clinton, Hillary', 1382536, 'Trump, Donald J.', 1405284, 2976150)
# (2016, 'Wyoming', 'Clinton, Hillary', 55973, 'Trump, Donald J.', 174419, 258788)

# %%
c.close()
conn.close()
